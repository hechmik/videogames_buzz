# %% [markdown]
# # Imports

# %%
import datetime
import json
import requests
import time

# %%
keys = json.loads(open("keys.json").read())

# %%
twitch_client_ID = keys['Twitch']['Client-ID']

# %% [markdown]
# # Twitch

# %%
header = {'Client-ID': twitch_client_ID}

# %% [markdown]
# ### Example

# %%
params = (('game_id', '33214'),)

# %%
response = requests.get('https://api.twitch.tv/helix/streams', headers=header, params=params)

# %%
response.json()
# Out:
# {'data': [{'community_ids': [],
#    'game_id': '33214',
#    'id': '34044740208',
#    'language': 'en',
#    'started_at': '2019-05-09T06:11:34Z',
#    'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039',
#     '2a14b52e-d459-4c92-be11-5d86b898f6b6'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_dakotaz-{width}x{height}.jpg',
#    'title': 'Season 9 Party with CDNThe3rd & HighDistortion [THE BOYS ARE BACK IN TOWN] - BRING YOUR FOOD AND DRINKS!',
#    'type': 'live',
#    'user_id': '39298218',
#    'user_name': 'dakotaz',
#    'viewer_count': 34602},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045548752',
#    'language': 'fr',
#    'started_at': '2019-05-09T09:05:32Z',
#    'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_gotaga-{width}x{height}.jpg',
#    'title': '[FR] GOTAGA ► Nouvelle saison HYPE !',
#    'type': 'live',
#    'user_id': '24147592',
#    'user_name': 'Gotaga',
#    'viewer_count': 16212},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34040314016',
#    'language': 'en',
#    'started_at': '2019-05-08T21:58:59Z',
#    'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_chap-{width}x{height}.jpg',
#    'title': 'Epic gave me a spray! | 24hr Stream Attempt | CODE:CHAP',
#    'type': 'live',
#    'user_id': '192678094',
#    'user_name': 'Chap',
#    'viewer_count': 14678},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045358512',
#    'language': 'en',
#    'started_at': '2019-05-09T08:24:40Z',
#    'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_cloakzy-{width}x{height}.jpg',
#    'title': 'Season 9 is going to bring back fortnite :)',
#    'type': 'live',
#    'user_id': '81687332',
#    'user_name': 'cloakzy',
#    'viewer_count': 10463},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045647056',
#    'language': 'de',
#    'started_at': '2019-05-09T09:23:02Z',
#    'tag_ids': ['9166ad14-41f1-4b04-a3b8-c8eb838c6be6'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_trymacs-{width}x{height}.jpg',
#    'title': '12 Stunden Stream?! Season 9: Alles kaufen, Alles Leveln! ',
#    'type': 'live',
#    'user_id': '64342766',
#    'user_name': 'Trymacs',
#    'viewer_count': 9198},
#   {'community_ids': ['4cc11eec-b7c2-4ada-8364-5a91d537e4bf'],
#    'game_id': '33214',
#    'id': '34046010608',
#    'language': 'it',
#    'started_at': '2019-05-09T10:20:15Z',
#    'tag_ids': ['5b9935eb-1e9a-4217-98ad-62bda5cff0d1'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_pow3rtv-{width}x{height}.jpg',
#    'title': 'MARATONA SEASON 9',
#    'type': 'live',
#    'user_id': '38499199',
#    'user_name': 'POW3Rtv',
#    'viewer_count': 7899},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045548784',
#    'language': 'en',
#    'started_at': '2019-05-09T09:05:32Z',
#    'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039',
#     '2a14b52e-d459-4c92-be11-5d86b898f6b6'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_cdnthe3rd-{width}x{height}.jpg',
#    'title': 'Reacting to #FortniteSeason9 w/ DK and HD | We\'ve been "Unvaulted" | #LGLoyal | [+] | Socials: IG/Twitter/YT: @CDNThe3r',
#    'type': 'live',
#    'user_id': '14408894',
#    'user_name': 'CDNThe3rd',
#    'viewer_count': 6870},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34044401728',
#    'language': 'en',
#    'started_at': '2019-05-09T05:06:23Z',
#    'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_mrfreshasian-{width}x{height}.jpg',
#    'title': 'Duos w/ Muselk | NEW SEASON! | USE CODE: Fresh | !socials !newvid !whycode !record',
#    'type': 'live',
#    'user_id': '38594688',
#    'user_name': 'mrfreshasian',
#    'viewer_count': 6859},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045688736',
#    'language': 'ar',
#    'started_at': '2019-05-09T09:28:02Z',
#    'tag_ids': ['73cc486a-e56b-41ed-a1df-7afedbc84f6f'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_rakanoolive-{width}x{height}.jpg',
#    'title': 'CODE : Rakanoo | 🙂 الموسم التاسع ',
#    'type': 'live',
#    'user_id': '119638640',
#    'user_name': 'RakanooLive',
#    'viewer_count': 5990},
#   {'community_ids': ['015516d8-18dc-417f-8b3d-6774f4a4e871',
#     '01d41280-9332-4f54-b77a-a20f577beade',
#     '558ffafb-6f75-44ff-8cb7-a4f045d2399f'],
#    'game_id': '33214',
#    'id': '34044181632',
#    'language': 'en',
#    'started_at': '2019-05-09T04:29:02Z',
#    'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_kingrichard-{width}x{height}.jpg',
#    'title': 'They Gave Me A Skin THo [+] Vibes | !youtube !prime | #NRGfam',
#    'type': 'live',
#    'user_id': '66691674',
#    'user_name': 'KingRichard',
#    'viewer_count': 4580},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045224560',
#    'language': 'fr',
#    'started_at': '2019-05-09T07:55:05Z',
#    'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_lebouseuh-{width}x{height}.jpg',
#    'title': 'SAISON 9 HYPE ! mode pigeon activé',
#    'type': 'live',
#    'user_id': '96562014',
#    'user_name': 'LeBouseuh',
#    'viewer_count': 3748},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34046227360',
#    'language': 'ru',
#    'started_at': '2019-05-09T10:57:28Z',
#    'tag_ids': ['0569b171-2a2b-476e-a596-5bdfb45a1327'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_jamside-{width}x{height}.jpg',
#    'title': '!instagram !vk !code !colblind',
#    'type': 'live',
#    'user_id': '101204178',
#    'user_name': 'Jamside',
#    'viewer_count': 3087},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34046384960',
#    'language': 'en',
#    'started_at': '2019-05-09T11:22:11Z',
#    'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_symfuhny-{width}x{height}.jpg',
#    'title': 'NEW SEASON: Use Code Sym for battle pass',
#    'type': 'live',
#    'user_id': '31688366',
#    'user_name': 'Symfuhny',
#    'viewer_count': 2991},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045377184',
#    'language': 'en',
#    'started_at': '2019-05-09T08:29:08Z',
#    'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_loeya-{width}x{height}.jpg',
#    'title': 'SEASON 9 - Code: LOEYA when purchasing battlepass!!',
#    'type': 'live',
#    'user_id': '166279350',
#    'user_name': 'Loeya',
#    'viewer_count': 2587},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34046040320',
#    'language': 'de',
#    'started_at': '2019-05-09T10:25:30Z',
#    'tag_ids': ['9166ad14-41f1-4b04-a3b8-c8eb838c6be6'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_mckytv-{width}x{height}.jpg',
#    'title': 'Fortnite ohne Pumpgun!? -  SEASON 9 ONLINE ',
#    'type': 'live',
#    'user_id': '101572475',
#    'user_name': 'mckyTV',
#    'viewer_count': 2354},
#   {'community_ids': ['558ffafb-6f75-44ff-8cb7-a4f045d2399f',
#     '8ea1e94f-4015-4f38-bd7e-745d8f42539a'],
#    'game_id': '33214',
#    'id': '34045132400',
#    'language': 'en',
#    'started_at': '2019-05-09T07:35:16Z',
#    'tag_ids': ['ff56eeeb-99ed-4a60-93fc-0b3f05d8661e',
#     '1eba3cfe-51cc-460a-8259-bc8bb987f904',
#     '6ea6bca4-4712-4ab9-a906-e3336a9d8039',
#     '2a14b52e-d459-4c92-be11-5d86b898f6b6'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_highdistortion-{width}x{height}.jpg',
#    'title': 'TSM HighDistortion | SEASON 9 | Creator Code: HD | !Social !youtube',
#    'type': 'live',
#    'user_id': '84752541',
#    'user_name': 'HighDistortion',
#    'viewer_count': 2086},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045043856',
#    'language': 'fr',
#    'started_at': '2019-05-09T07:15:52Z',
#    'tag_ids': ['6f655045-9989-4ef7-8f85-1edcec42d648'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_solaryfortnite-{width}x{height}.jpg',
#    'title': 'mzQQQ HYPE DECOUVERTE DE LA SAISON 9',
#    'type': 'live',
#    'user_id': '198506129',
#    'user_name': 'SolaryFortnite',
#    'viewer_count': 1603},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045555072',
#    'language': 'de',
#    'started_at': '2019-05-09T09:06:53Z',
#    'tag_ids': ['9166ad14-41f1-4b04-a3b8-c8eb838c6be6'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_painlivestream-{width}x{height}.jpg',
#    'title': 'SEASON 9 ',
#    'type': 'live',
#    'user_id': '61243967',
#    'user_name': 'PainLivestream',
#    'viewer_count': 1494},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045805136',
#    'language': 'it',
#    'started_at': '2019-05-09T09:45:23Z',
#    'tag_ids': ['5b9935eb-1e9a-4217-98ad-62bda5cff0d1',
#     '2a14b52e-d459-4c92-be11-5d86b898f6b6'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_cicciogamer89-{width}x{height}.jpg',
#    'title': 'FORTNITE : Codice Creatore : cicciogamer89',
#    'type': 'live',
#    'user_id': '31987213',
#    'user_name': 'Cicciogamer89',
#    'viewer_count': 1485},
#   {'community_ids': [],
#    'game_id': '33214',
#    'id': '34045235968',
#    'language': 'en',
#    'started_at': '2019-05-09T07:57:26Z',
#    'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#    'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_loserfruit-{width}x{height}.jpg',
#    'title': 'Fortnite Season 9 waiting room...CODE LUFU also that skin kinda looks like me :3',
#    'type': 'live',
#    'user_id': '41245072',
#    'user_name': 'Loserfruit',
#    'viewer_count': 1277}],
#  'pagination': {'cursor': 'eyJiIjpudWxsLCJhIjp7Ik9mZnNldCI6MjB9fQ'}}

# %% [markdown]
# ### Get top games (max 100 per request)

# %%
def print_response(response, start = 0):
    '''
    prints the response in a more readable way.
    'start' specifies the first number of the list
    '''
    for i in range(len(response.json()['data'])):
        print('{:2d} {:6s} :  {}'.format(i + 1 + start, 
                                      response.json()['data'][i]['id'],
                                      response.json()['data'][i]['name']))

# %%
response = requests.get('https://api.twitch.tv/helix/games/top?first=100', headers=header)

# %%
response.json()['data']
# Out:
# [{'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Fortnite-{width}x{height}.jpg',
#   'id': '33214',
#   'name': 'Fortnite'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Dota%202-{width}x{height}.jpg',
#   'id': '29595',
#   'name': 'Dota 2'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/League%20of%20Legends-{width}x{height}.jpg',
#   'id': '21779',
#   'name': 'League of Legends'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Just%20Chatting-{width}x{height}.jpg',
#   'id': '509658',
#   'name': 'Just Chatting'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Grand%20Theft%20Auto%20V-{width}x{height}.jpg',
#   'id': '32982',
#   'name': 'Grand Theft Auto V'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Hearthstone-{width}x{height}.jpg',
#   'id': '138585',
#   'name': 'Hearthstone'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Counter-Strike:%20Global%20Offensive-{width}x{height}.jpg',
#   'id': '32399',
#   'name': 'Counter-Strike: Global Offensive'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/PLAYERUNKNOWN%27S%20BATTLEGROUNDS-{width}x{height}.jpg',
#   'id': '493057',
#   'name': "PLAYERUNKNOWN'S BATTLEGROUNDS"},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Overwatch-{width}x{height}.jpg',
#   'id': '488552',
#   'name': 'Overwatch'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Auto%20Chess-{width}x{height}.jpg',
#   'id': '511748',
#   'name': 'Auto Chess'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/World%20of%20Warcraft-{width}x{height}.jpg',
#   'id': '18122',
#   'name': 'World of Warcraft'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Dead%20by%20Daylight-{width}x{height}.jpg',
#   'id': '491487',
#   'name': 'Dead by Daylight'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Apex%20Legends-{width}x{height}.jpg',
#   'id': '511224',
#   'name': 'Apex Legends'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Lunar:%20Dragon%20Song-{width}x{height}.jpg',
#   'id': '14958',
#   'name': 'Lunar: Dragon Song'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/StarCraft-{width}x{height}.jpg',
#   'id': '11989',
#   'name': 'StarCraft'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/FIFA%2019-{width}x{height}.jpg',
#   'id': '506103',
#   'name': 'FIFA 19'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Tom%20Clancy%27s%20Rainbow%20Six:%20Siege-{width}x{height}.jpg',
#   'id': '460630',
#   'name': "Tom Clancy's Rainbow Six: Siege"},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Slots-{width}x{height}.jpg',
#   'id': '498566',
#   'name': 'Slots'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Mordhau-{width}x{height}.jpg',
#   'id': '498859',
#   'name': 'Mordhau'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Travel%20&%20Outdoors-{width}x{height}.jpg',
#   'id': '509672',
#   'name': 'Travel & Outdoors'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Magic:%20The%20Gathering-{width}x{height}.jpg',
#   'id': '2748',
#   'name': 'Magic: The Gathering'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Poker-{width}x{height}.jpg',
#   'id': '488190',
#   'name': 'Poker'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Call%20of%20Duty:%20Black%20Ops%204-{width}x{height}.jpg',
#   'id': '504462',
#   'name': 'Call of Duty: Black Ops 4'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/StarCraft%20II-{width}x{height}.jpg',
#   'id': '490422',
#   'name': 'StarCraft II'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Music%20&%20Performing%20Arts-{width}x{height}.jpg',
#   'id': '26936',
#   'name': 'Music & Performing Arts'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Escape%20From%20Tarkov-{width}x{height}.jpg',
#   'id': '491931',
#   'name': 'Escape From Tarkov'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Old%20School%20RuneScape-{width}x{height}.jpg',
#   'id': '459931',
#   'name': 'Old School RuneScape'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Minecraft-{width}x{height}.jpg',
#   'id': '27471',
#   'name': 'Minecraft'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Path%20of%20Exile-{width}x{height}.jpg',
#   'id': '29307',
#   'name': 'Path of Exile'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Talk%20Shows%20&%20Podcasts-{width}x{height}.jpg',
#   'id': '417752',
#   'name': 'Talk Shows & Podcasts'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/World%20of%20Tanks-{width}x{height}.jpg',
#   'id': '27546',
#   'name': 'World of Tanks'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Art-{width}x{height}.jpg',
#   'id': '509660',
#   'name': 'Art'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Destiny%202-{width}x{height}.jpg',
#   'id': '497057',
#   'name': 'Destiny 2'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Overcooked%21%202-{width}x{height}.jpg',
#   'id': '506458',
#   'name': 'Overcooked! 2'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Black%20Desert%20Online-{width}x{height}.jpg',
#   'id': '386821',
#   'name': 'Black Desert Online'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/My%20Summer%20Car-{width}x{height}.jpg',
#   'id': '493125',
#   'name': 'My Summer Car'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/ASMR-{width}x{height}.jpg',
#   'id': '509659',
#   'name': 'ASMR'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Games%20+%20Demos-{width}x{height}.jpg',
#   'id': '66082',
#   'name': 'Games + Demos'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Close%20to%20the%20Sun-{width}x{height}.jpg',
#   'id': '498484',
#   'name': 'Close to the Sun'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Days%20Gone-{width}x{height}.jpg',
#   'id': '497456',
#   'name': 'Days Gone'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/FINAL%20FANTASY%20XIV%20Online-{width}x{height}.jpg',
#   'id': '24241',
#   'name': 'FINAL FANTASY XIV Online'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Mount%20&%20Blade:%20Warband-{width}x{height}.jpg',
#   'id': '23166',
#   'name': 'Mount & Blade: Warband'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/World%20War%20Z-{width}x{height}.jpg',
#   'id': '500633',
#   'name': 'World War Z'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Super%20Mario%20Maker-{width}x{height}.jpg',
#   'id': '490608',
#   'name': 'Super Mario Maker'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Street%20Fighter%20V-{width}x{height}.jpg',
#   'id': '488615',
#   'name': 'Street Fighter V'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Heroes%20of%20the%20Storm-{width}x{height}.jpg',
#   'id': '32959',
#   'name': 'Heroes of the Storm'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Divinity:%20Original%20Sin%20II-{width}x{height}.jpg',
#   'id': '490644',
#   'name': 'Divinity: Original Sin II'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/The%20Long%20Dark-{width}x{height}.jpg',
#   'id': '418016',
#   'name': 'The Long Dark'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Monster%20Hunter%20World-{width}x{height}.jpg',
#   'id': '497467',
#   'name': 'Monster Hunter World'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Tom%20Clancy%27s%20The%20Division%202-{width}x{height}.jpg',
#   'id': '504463',
#   'name': "Tom Clancy's The Division 2"},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/World%20of%20Warships-{width}x{height}.jpg',
#   'id': '32502',
#   'name': 'World of Warships'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Rocket%20League-{width}x{height}.jpg',
#   'id': '30921',
#   'name': 'Rocket League'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/The%20Elder%20Scrolls%20Online-{width}x{height}.jpg',
#   'id': '65654',
#   'name': 'The Elder Scrolls Online'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Lineage%20II-{width}x{height}.jpg',
#   'id': '8901',
#   'name': 'Lineage II'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Rust-{width}x{height}.jpg',
#   'id': '263490',
#   'name': 'Rust'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Tibia-{width}x{height}.jpg',
#   'id': '19619',
#   'name': 'Tibia'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Darkest%20Dungeon-{width}x{height}.jpg',
#   'id': '458353',
#   'name': 'Darkest Dungeon'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Diablo-{width}x{height}.jpg',
#   'id': '5492',
#   'name': 'Diablo'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Sea%20of%20Thieves-{width}x{height}.jpg',
#   'id': '490377',
#   'name': 'Sea of Thieves'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Mortal%20Kombat%2011-{width}x{height}.jpg',
#   'id': '510578',
#   'name': 'Mortal Kombat 11'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Retro-{width}x{height}.jpg',
#   'id': '27284',
#   'name': 'Retro'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Warcraft%20III:%20The%20Frozen%20Throne-{width}x{height}.jpg',
#   'id': '12924',
#   'name': 'Warcraft III: The Frozen Throne'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/RuneScape-{width}x{height}.jpg',
#   'id': '2083',
#   'name': 'RuneScape'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Cities:%20Skylines-{width}x{height}.jpg',
#   'id': '461449',
#   'name': 'Cities: Skylines'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Epic%20Seven-{width}x{height}.jpg',
#   'id': '510056',
#   'name': 'Epic Seven'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/ARK-{width}x{height}.jpg',
#   'id': '489635',
#   'name': 'ARK'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Slay%20the%20Spire-{width}x{height}.jpg',
#   'id': '496902',
#   'name': 'Slay the Spire'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Return%20of%20the%20Obra%20Dinn-{width}x{height}.jpg',
#   'id': '460501',
#   'name': 'Return of the Obra Dinn'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Shadowverse-{width}x{height}.jpg',
#   'id': '492925',
#   'name': 'Shadowverse'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Eryi%27s%20Action-{width}x{height}.jpg',
#   'id': '413449',
#   'name': "Eryi's Action"},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Chess-{width}x{height}.jpg',
#   'id': '743',
#   'name': 'Chess'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Zanki%20Zero-{width}x{height}.jpg',
#   'id': '499041',
#   'name': 'Zanki Zero'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Smite-{width}x{height}.jpg',
#   'id': '32507',
#   'name': 'Smite'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Warframe-{width}x{height}.jpg',
#   'id': '66170',
#   'name': 'Warframe'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Tetris%2099-{width}x{height}.jpg',
#   'id': '511396',
#   'name': 'Tetris 99'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Super%20Smash%20Bros.%20Ultimate-{width}x{height}.jpg',
#   'id': '504461',
#   'name': 'Super Smash Bros. Ultimate'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Project%20Zomboid-{width}x{height}.jpg',
#   'id': '31339',
#   'name': 'Project Zomboid'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Gwent:%20The%20Witcher%20Card%20Game-{width}x{height}.jpg',
#   'id': '493217',
#   'name': 'Gwent: The Witcher Card Game'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/VRChat-{width}x{height}.jpg',
#   'id': '499003',
#   'name': 'VRChat'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Borderlands%202-{width}x{height}.jpg',
#   'id': '32345',
#   'name': 'Borderlands 2'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Grim%20Dawn-{width}x{height}.jpg',
#   'id': '26881',
#   'name': 'Grim Dawn'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Sekiro:%20Shadows%20Die%20Twice-{width}x{height}.jpg',
#   'id': '506415',
#   'name': 'Sekiro: Shadows Die Twice'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Jikkyou%20Powerful%20Pro%20Yakyuu%202018-{width}x{height}.jpg',
#   'id': '503076',
#   'name': 'Jikkyou Powerful Pro Yakyuu 2018'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Mario%20Kart%208-{width}x{height}.jpg',
#   'id': '369588',
#   'name': 'Mario Kart 8'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Dark%20Souls%20III-{width}x{height}.jpg',
#   'id': '490292',
#   'name': 'Dark Souls III'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Grand%20Theft%20Auto:%20San%20Andreas-{width}x{height}.jpg',
#   'id': '6521',
#   'name': 'Grand Theft Auto: San Andreas'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Pokemon:%20Let%27s%20Go,%20Pikachu%21/Eevee%21-{width}x{height}.jpg',
#   'id': '506237',
#   'name': "Pokemon: Let's Go, Pikachu!/Eevee!"},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Kartrider-{width}x{height}.jpg',
#   'id': '491334',
#   'name': 'Kartrider'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Swag%20&%20Sorcery-{width}x{height}.jpg',
#   'id': '510509',
#   'name': 'Swag & Sorcery'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Imperator:%20Rome-{width}x{height}.jpg',
#   'id': '508297',
#   'name': 'Imperator: Rome'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/osu%21-{width}x{height}.jpg',
#   'id': '21465',
#   'name': 'osu!'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Tekken%207-{width}x{height}.jpg',
#   'id': '461067',
#   'name': 'Tekken 7'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./The%20Elder%20Scrolls:%20Legends-{width}x{height}.jpg',
#   'id': '490349',
#   'name': 'The Elder Scrolls: Legends'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Battletoads-{width}x{height}.jpg',
#   'id': '19358',
#   'name': 'Battletoads'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Don%27t%20Starve%20Together-{width}x{height}.jpg',
#   'id': '488634',
#   'name': "Don't Starve Together"},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/DayZ-{width}x{height}.jpg',
#   'id': '65632',
#   'name': 'DayZ'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/NBA%202K19-{width}x{height}.jpg',
#   'id': '506383',
#   'name': 'NBA 2K19'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/Dino%20Crisis-{width}x{height}.jpg',
#   'id': '10945',
#   'name': 'Dino Crisis'},
#  {'box_art_url': 'https://static-cdn.jtvnw.net/ttv-boxart/./Princess%20Connect%21%20Re:%20Dive-{width}x{height}.jpg',
#   'id': '503988',
#   'name': 'Princess Connect! Re: Dive'}]

# %% [markdown]
# For some reason it actually returns the first 99 games, instead of 100:

# %%
len(response.json()['data'])
# Out:
# 99

# %%
print_response(response)
# Out:
#  1 33214  :  Fortnite
#  2 29595  :  Dota 2
#  3 21779  :  League of Legends
#  4 509658 :  Just Chatting
#  5 32982  :  Grand Theft Auto V
#  6 138585 :  Hearthstone
#  7 32399  :  Counter-Strike: Global Offensive
#  8 493057 :  PLAYERUNKNOWN'S BATTLEGROUNDS
#  9 488552 :  Overwatch
# 10 511748 :  Auto Chess
# 11 18122  :  World of Warcraft
# 12 491487 :  Dead by Daylight
# 13 511224 :  Apex Legends
# 14 14958  :  Lunar: Dragon Song
# 15 11989  :  StarCraft
# 16 506103 :  FIFA 19
# 17 460630 :  Tom Clancy's Rainbow Six: Siege
# 18 498566 :  Slots
# 19 498859 :  Mordhau
# 20 509672 :  Travel & Outdoors
# 21 2748   :  Magic: The Gathering
# 22 488190 :  Poker
# 23 504462 :  Call of Duty: Black Ops 4
# 24 490422 :  StarCraft II
# 25 26936  :  Music & Performing Arts
# 26 491931 :  Escape From Tarkov
# 27 459931 :  Old School RuneScape
# 28 27471  :  Minecraft
# 29 29307  :  Path of Exile
# 30 417752 :  Talk Shows & Podcasts
# 31 27546  :  World of Tanks
# 32 509660 :  Art
# 33 497057 :  Destiny 2
# 34 506458 :  Overcooked! 2
# 35 386821 :  Black Desert Online
# 36 493125 :  My Summer Car
# 37 509659 :  ASMR
# 38 66082  :  Games + Demos
# 39 498484 :  Close to the Sun
# 40 497456 :  Days Gone
# 41 24241  :  FINAL FANTASY XIV Online
# 42 23166  :  Mount & Blade: Warband
# 43 500633 :  World War Z
# 44 490608 :  Super Mario Maker
# 45 488615 :  Street Fighter V
# 46 32959  :  Heroes of the Storm
# 47 490644 :  Divinity: Original Sin II
# 48 418016 :  The Long Dark
# 49 497467 :  Monster Hunter World
# 50 504463 :  Tom Clancy's The Division 2
# 51 32502  :  World of Warships
# 52 30921  :  Rocket League
# 53 65654  :  The Elder Scrolls Online
# 54 8901   :  Lineage II
# 55 263490 :  Rust
# 56 19619  :  Tibia
# 57 458353 :  Darkest Dungeon
# 58 5492   :  Diablo
# 59 490377 :  Sea of Thieves
# 60 510578 :  Mortal Kombat 11
# 61 27284  :  Retro
# 62 12924  :  Warcraft III: The Frozen Throne
# 63 2083   :  RuneScape
# 64 461449 :  Cities: Skylines
# 65 510056 :  Epic Seven
# 66 489635 :  ARK
# 67 496902 :  Slay the Spire
# 68 460501 :  Return of the Obra Dinn
# 69 492925 :  Shadowverse
# 70 413449 :  Eryi's Action
# 71 743    :  Chess
# 72 499041 :  Zanki Zero
# 73 32507  :  Smite
# 74 66170  :  Warframe
# 75 511396 :  Tetris 99
# 76 504461 :  Super Smash Bros. Ultimate
# 77 31339  :  Project Zomboid
# 78 493217 :  Gwent: The Witcher Card Game
# 79 499003 :  VRChat
# 80 32345  :  Borderlands 2
# 81 26881  :  Grim Dawn
# 82 506415 :  Sekiro: Shadows Die Twice
# 83 503076 :  Jikkyou Powerful Pro Yakyuu 2018
# 84 369588 :  Mario Kart 8
# 85 490292 :  Dark Souls III
# 86 6521   :  Grand Theft Auto: San Andreas
# 87 506237 :  Pokemon: Let's Go, Pikachu!/Eevee!
# 88 491334 :  Kartrider
# 89 510509 :  Swag & Sorcery
# 90 508297 :  Imperator: Rome
# 91 21465  :  osu!
# 92 461067 :  Tekken 7
# 93 490349 :  The Elder Scrolls: Legends
# 94 19358  :  Battletoads
# 95 488634 :  Don't Starve Together
# 96 65632  :  DayZ
# 97 506383 :  NBA 2K19
# 98 10945  :  Dino Crisis
# 99 503988 :  Princess Connect! Re: Dive

# %% [markdown]
# ### Use pagination cursor to get more results

# %% [markdown]
# We can get only the top 100 (99) streams in a single request, but we can specify 'after = [pagination cursor]' to get more.

# %% [markdown]
# (The requests that specify the 'after' part actually return 100 results)

# %%
response = requests.get('https://api.twitch.tv/helix/games/top?first=100', headers=header)

# the pagination is
pag = response.json()['pagination']['cursor']

response2 = requests.get(
    'https://api.twitch.tv/helix/games/top?after={}&first=100'.format(pag),
    headers=header)

# %%
print_response(response)
# Out:
#  1 33214  :  Fortnite
#  2 29595  :  Dota 2
#  3 21779  :  League of Legends
#  4 509658 :  Just Chatting
#  5 32982  :  Grand Theft Auto V
#  6 138585 :  Hearthstone
#  7 32399  :  Counter-Strike: Global Offensive
#  8 493057 :  PLAYERUNKNOWN'S BATTLEGROUNDS
#  9 488552 :  Overwatch
# 10 511748 :  Auto Chess
# 11 18122  :  World of Warcraft
# 12 491487 :  Dead by Daylight
# 13 511224 :  Apex Legends
# 14 14958  :  Lunar: Dragon Song
# 15 11989  :  StarCraft
# 16 506103 :  FIFA 19
# 17 460630 :  Tom Clancy's Rainbow Six: Siege
# 18 498859 :  Mordhau
# 19 509672 :  Travel & Outdoors
# 20 498566 :  Slots
# 21 488190 :  Poker
# 22 2748   :  Magic: The Gathering
# 23 504462 :  Call of Duty: Black Ops 4
# 24 490422 :  StarCraft II
# 25 26936  :  Music & Performing Arts
# 26 491931 :  Escape From Tarkov
# 195 493815 :  Oxygen Not Included
# 196 23020  :  ROBLOX
# 197 32634  :  Pokémon Trading Card Game Online
# 198 369075 :  A Hat in Time
# 199 509590 :  Do Not Feed the Monkeys

# %% [markdown]
# ### Get top n games

# %%
def print_games_list(l):
    '''
    l must be a list of games dicts, with keys "name" and "id".
    the function prints l.
    '''
    for i in range(len(l)):
            print('{:2d} {:6s} :  {}'.format(i + 1, l[i]['id'], l[i]['name']))

# %%
def res_pag(response):
    '''
    returns pagination cursor of a response
    '''
    return response.json()['pagination']['cursor']

# %%
# old version with less control on numer of games

def get_n_top_games_OLD(n, header):
    '''
    returns the ordered list of top games (dicts), with length between n and (n + 99)
    headers is the header of the request (specifying the Client-ID)
    '''
    responses = [] # list of games
    
    res = requests.get('https://api.twitch.tv/helix/games/top?first=100', headers=header)
    responses.extend(res.json()['data'])
           
    while len(responses) < n:
        res = requests.get('https://api.twitch.tv/helix/games/top?after={}&first=100'.format(res_pag(res)), headers=header)
        responses.extend(res.json()['data'])
    
    return responses

# %%
# newer version, possibly we could make it better by making it wait if we surpass the 30 requests per minute limit
# for some reason if n <= 15 it returns one more game

def get_n_top_games(n, header, exactly_n = False):
    '''
    returns the ordered list of top n-1 games (dicts)
    headers is the header of the request (specifying the Client-ID)
    if exactly_n == True, the function returns the list of top n games
        by default this is false as it performs one additional request just to get a single game
    '''
    responses = [] # list of games
    
    m = n // 100
    q = n % 100
        
    if m == 0:
        # if n is less than or equal to 100, just gets the first n games
        res = requests.get(
            'https://api.twitch.tv/helix/games/top?first={}'.format(n),
            headers=header)
        responses.extend(res.json()['data'])
    else:
        # get the first 99 games:
        res = requests.get(
            'https://api.twitch.tv/helix/games/top?first=100',
            headers=header)
        responses.extend(res.json()['data']) 

        # loop to get the remaining (m-1)*100 games
        m -= 1
        while m > 0:
            res = requests.get(
                'https://api.twitch.tv/helix/games/top?after={}&first=100'.format(res_pag(res)),
                headers=header)
            responses.extend(res.json()['data'])
            m -= 1

        # now m = 0, we get the last q games if q > 0
        if q > 0:
            res = requests.get(
                'https://api.twitch.tv/helix/games/top?after={}&first={}'.format(res_pag(res), q),
                headers=header)
            responses.extend(res.json()['data'])

    if exactly_n:
        # get the last game
        res = requests.get(
            'https://api.twitch.tv/helix/games/top?after={}&first={}'.format(res_pag(res), 1),
            headers=header)
        responses.extend(res.json()['data'])
    
    return responses

# %%
t = get_n_top_games(150, header, exactly_n = True)

# %%
print_games_list(t)
# Out:
#  1 33214  :  Fortnite
#  2 29595  :  Dota 2
#  3 21779  :  League of Legends
#  4 509658 :  Just Chatting
#  5 32982  :  Grand Theft Auto V
#  6 138585 :  Hearthstone
#  7 32399  :  Counter-Strike: Global Offensive
#  8 493057 :  PLAYERUNKNOWN'S BATTLEGROUNDS
#  9 488552 :  Overwatch
# 10 511748 :  Auto Chess
# 11 18122  :  World of Warcraft
# 12 491487 :  Dead by Daylight
# 13 511224 :  Apex Legends
# 14 14958  :  Lunar: Dragon Song
# 15 11989  :  StarCraft
# 16 506103 :  FIFA 19
# 102 505884 :  PUBG MOBILE
# 103 509670 :  Science & Technology
# 104 19976  :  MapleStory
# 105 2798   :  Heroes of Might and Magic III: The Shadow of Death
# 106 12482  :  The Legend of Zelda: Majora's Mask
# 107 492618 :  Lords Mobile
# 108 417528 :  Albion Online
# 109 490100 :  Lost Ark Online
# 110 506413 :  Forza Horizon 4
# 111 15229  :  Ragnarok Online
# 112 491403 :  Eternal
# 113 509110 :  Risk of Rain 2
# 114 504954 :  Ring Of Elysium
# 115 19554  :  iRacing.com
# 116 497462 :  Tropico 6
# 117 504199 :  Battlefield V
# 118 497385 :  Dragon Ball FighterZ
# 119 497434 :  Total War: Warhammer II
# 120 2692   :  Super Mario 64
# 121 490382 :  For Honor
# 122 66366  :  War Thunder
# 123 490771 :  Battle Brothers
# 124 271231 :  M.U.G.E.N
# 125 369252 :  The Sims 4
# 126 459327 :  Hearts of Iron IV
# 127 509511 :  Marbles On Stream
# 128 31336  :  Metin 2
# 129 490868 :  Resident Evil 2
# 130 510825 :  ATLAS
# 131 505646 :  Train Valley 2
# 132 489111 :  Summoners War: Sky Arena
# 133 508948 :  Raid: Shadow Legends
# 134 509667 :  Food & Drink
# 135 499634 :  Crypto
# 136 499125 :  Mashinky
# 137 490744 :  Stardew Valley
# 138 19357  :  Guild Wars 2
# 139 509481 :  Twitch Sings
# 140 29099  :  BioShock Infinite
# 141 9618   :  Pokémon Trading Card Game
# 142 29143  :  Catherine
# 143 505845 :  Realm Royale
# 144 503932 :  Last Epoch
# 145 493048 :  Fate/Grand Order
# 146 271304 :  7 Days to Die
# 147 460379 :  Peria Chronicles
# 148 313558 :  Diablo III: Reaper of Souls
# 149 71375  :  Star Citizen
# 150 110758 :  The Legend of Zelda: Breath of the Wild

# %% [markdown]
# ### Number of viewers of a game

# %% [markdown]
# First, get top streams for a game (max 100, but we could make a pagination thing like before)

# %%
response = requests.get('https://api.twitch.tv/helix/streams?game_id=504461&first=20', headers=header)

# %%
response.json()['data']
# Out:
# [{'community_ids': ['4b28ac67-3d3c-4997-ab60-a17e95044af0',
#    '558ffafb-6f75-44ff-8cb7-a4f045d2399f',
#    '5c5a67db-215f-4c38-82c5-454d9983cfb5'],
#   'game_id': '504461',
#   'id': '34045000976',
#   'language': 'en',
#   'started_at': '2019-05-09T07:06:21Z',
#   'tag_ids': ['1eba3cfe-51cc-460a-8259-bc8bb987f904',
#    '3280c8d8-64c0-45f7-aeaa-189928b0e82c',
#    '2b2a4874-8a3c-4995-b9e2-2a0bce1eb536',
#    '6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_keitarotime-{width}x{height}.jpg',
#   'title': 'TSM Tweek, PG Cosmos, Cilvanis, Judge',
#   'type': 'live',
#   'user_id': '3396422',
#   'user_name': 'KeitaroTime',
#   'viewer_count': 306},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34045031408',
#   'language': 'en',
#   'started_at': '2019-05-09T07:12:59Z',
#   'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_vgtv_ultimate-{width}x{height}.jpg',
#   'title': '24/7 ULTIMATE: DPG18 - PG | Esam [L] (Pikachu) Vs. PG | MVD (Snake) SSBU Grand Finals',
#   'type': 'live',
#   'user_id': '275473782',
#   'user_name': 'VGTV_Ultimate',
#   'viewer_count': 138},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34037508880',
#   'language': 'fr',
#   'started_at': '2019-05-08T17:55:16Z',
#   'tag_ids': ['77017b7b-6b98-4f0d-bd39-3ba96b66ec7a',
#    'ef4f33d5-a6cb-4935-bc1d-97c818a1e39e',
#    'ff56eeeb-99ed-4a60-93fc-0b3f05d8661e',
#    '1eba3cfe-51cc-460a-8259-bc8bb987f904',
#    '6f655045-9989-4ef7-8f85-1edcec42d648'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_ogamingtv-{width}x{height}.jpg',
#   'title': '[REDIFF] Enki - Soirée Smash avec OursOuzbek (Top Ken FR) ',
#   'type': 'live',
#   'user_id': '27528066',
#   'user_name': 'OGamingTV',
#   'viewer_count': 52},
#  {'community_ids': ['ce59ea08-5464-487f-86d2-806411108ba1',
#    'e6d9c53e-390f-4a62-ae64-f3c1be3691c5',
#    'eb736bd3-9308-4f44-ab59-681402446afb'],
#   'game_id': '504461',
#   'id': '34045386832',
#   'language': 'en',
#   'started_at': '2019-05-09T08:31:22Z',
#   'tag_ids': ['ff56eeeb-99ed-4a60-93fc-0b3f05d8661e',
#    '1eba3cfe-51cc-460a-8259-bc8bb987f904',
#    'ac763b17-7bea-4632-9eb4-d106689ff409',
#    '3280c8d8-64c0-45f7-aeaa-189928b0e82c',
#    '8486f56b-8677-44f7-8004-000295391524',
#    '6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_tyr808-{width}x{height}.jpg',
#   'title': 'VIEWER ARENA! | !challenge | to join! ( bit.ly/tyr808humble )',
#   'type': 'live',
#   'user_id': '30119945',
#   'user_name': 'Tyr808',
#   'viewer_count': 48},
#  {'community_ids': ['848d95be-90b3-44a5-b143-6e373754c382',
#    'aabb1a4b-4681-4115-9806-391fca12b2a4',
#    'd84ab75c-5da6-495d-b6fc-d6fdf2974d5e'],
#   'game_id': '504461',
#   'id': '34045474448',
#   'language': 'de',
#   'started_at': '2019-05-09T08:50:33Z',
#   'tag_ids': ['e90b5f6e-4c6e-4003-885b-4d0d5adeb580',
#    'e659959d-392f-44c5-83a5-fb959cdbaccc',
#    'ef4f33d5-a6cb-4935-bc1d-97c818a1e39e',
#    '62bc5436-6f91-446d-9651-da008da4e4bb',
#    '1eba3cfe-51cc-460a-8259-bc8bb987f904',
#    '9166ad14-41f1-4b04-a3b8-c8eb838c6be6'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_thesakatis-{width}x{height}.jpg',
#   'title': '[PUBLIC] Smash&Chill ID:FP2SH - !Shirt - !Discord - !Price -',
#   'type': 'live',
#   'user_id': '53601322',
#   'user_name': 'TheSakatiS',
#   'viewer_count': 46},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34043056176',
#   'language': 'en',
#   'started_at': '2019-05-09T02:07:44Z',
#   'tag_ids': ['1eba3cfe-51cc-460a-8259-bc8bb987f904',
#    'ac763b17-7bea-4632-9eb4-d106689ff409',
#    '6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_xcadril-{width}x{height}.jpg',
#   'title': 'Super Quad Smash Bros (TV)',
#   'type': 'live',
#   'user_id': '165192633',
#   'user_name': 'XCadril',
#   'viewer_count': 24},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34046178352',
#   'language': 'ko',
#   'started_at': '2019-05-09T10:49:18Z',
#   'tag_ids': ['ab2975e3-b9ca-4b1a-a93e-fb61a5d5c3a4'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_bananasoup-{width}x{height}.jpg',
#   'title': '불금전야 | 19/05/09 | 격주간 대난투 얼티밋 대회 | feat. payoen, Guma, Bakcdorr',
#   'type': 'live',
#   'user_id': '94830212',
#   'user_name': '바나나스프',
#   'viewer_count': 21},
#  {'community_ids': ['9b644607-486d-4de5-9f3a-a0cf74528474'],
#   'game_id': '504461',
#   'id': '34046222192',
#   'language': 'de',
#   'started_at': '2019-05-09T10:56:39Z',
#   'tag_ids': ['bb5e7234-380e-48ad-a59c-03e51274e478',
#    '9166ad14-41f1-4b04-a3b8-c8eb838c6be6'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_liveforlifetv-{width}x{height}.jpg',
#   'title': 'Aktuell: deinRoXas - Charity Stream | Next Up: M4ndyTV ab 16 Uhr | #TheMysteryBox',
#   'type': 'live',
#   'user_id': '152941448',
#   'user_name': 'LiveForLifeTV',
#   'viewer_count': 20},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34045491856',
#   'language': 'fr',
#   'started_at': '2019-05-09T08:54:09Z',
#   'tag_ids': ['64d9afa6-139a-48d5-ab4e-51d0a92b22de',
#    'e90b5f6e-4c6e-4003-885b-4d0d5adeb580',
#    'ac763b17-7bea-4632-9eb4-d106689ff409',
#    'f4b7fa12-9f16-439f-a6b9-87efe9ecf3ba',
#    'cee0e0bb-60b1-46a8-be53-ba46c05727b3',
#    '6f655045-9989-4ef7-8f85-1edcec42d648'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_zepae_-{width}x{height}.jpg',
#   'title': '[FR] !join Tempête de Dab . Twitch ou Youtube ?',
#   'type': 'live',
#   'user_id': '107338465',
#   'user_name': 'Zepae_',
#   'viewer_count': 19},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34045277952',
#   'language': 'ko',
#   'started_at': '2019-05-09T08:05:40Z',
#   'tag_ids': ['96b6073f-450d-4248-8ed4-988e28f3f759',
#    'ac763b17-7bea-4632-9eb4-d106689ff409',
#    'ab2975e3-b9ca-4b1a-a93e-fb61a5d5c3a4'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_omiggu-{width}x{height}.jpg',
#   'title': '[대난투]요리 다 식어서 시참',
#   'type': 'live',
#   'user_id': '169388401',
#   'user_name': '오미꾸',
#   'viewer_count': 17},
#  {'community_ids': ['4cb36321-ccac-4bd6-81b4-b3aba85b819a'],
#   'game_id': '504461',
#   'id': '34045906960',
#   'language': 'ja',
#   'started_at': '2019-05-09T10:02:34Z',
#   'tag_ids': ['6ba1d230-e52f-4d81-b1e0-41f25a8a9f5d'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_takoman_0112-{width}x{height}.jpg',
#   'title': '久しぶりにスマブラ(非公式レート戦)',
#   'type': 'live',
#   'user_id': '122679733',
#   'user_name': 'タコマン',
#   'viewer_count': 15},
#  {'community_ids': ['0638bbc3-add3-4c28-a1bf-9d0019631568',
#    '3d5c2141-34ff-4a51-86ee-f0b572af89fb',
#    'b87a1265-83b0-4cdc-89b2-3e3d84235961'],
#   'game_id': '504461',
#   'id': '34045198864',
#   'language': 'en',
#   'started_at': '2019-05-09T07:49:18Z',
#   'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_nitemarephoenix-{width}x{height}.jpg',
#   'title': 'Random Battles for Random Folks',
#   'type': 'live',
#   'user_id': '39091589',
#   'user_name': 'NitemarePhoenix',
#   'viewer_count': 11},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34046464880',
#   'language': 'en',
#   'started_at': '2019-05-09T11:34:57Z',
#   'tag_ids': ['e659959d-392f-44c5-83a5-fb959cdbaccc',
#    '67259b26-ff83-444e-9d3c-faab390df16f',
#    '3280c8d8-64c0-45f7-aeaa-189928b0e82c',
#    '1b70fcca-0579-446a-90d1-075c9ce62309',
#    'ff56eeeb-99ed-4a60-93fc-0b3f05d8661e',
#    '6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_baka_densetsu670-{width}x{height}.jpg',
#   'title': '🐧 🐧Smashing and Juggling🐧🐧 🎼(!loots !giveaway !freesub !merch !ticket) 🎶 🎶 🎶',
#   'type': 'live',
#   'user_id': '142869507',
#   'user_name': 'baka_densetsu670',
#   'viewer_count': 10},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34046224272',
#   'language': 'en',
#   'started_at': '2019-05-09T10:56:59Z',
#   'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_ajbake2013-{width}x{height}.jpg',
#   'title': 'check your fight face and STEP INTO THE RING!  ARENA ID: D08D5 PWORD: 1234',
#   'type': 'live',
#   'user_id': '135404566',
#   'user_name': 'ajbake2013',
#   'viewer_count': 10},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34046412832',
#   'language': 'fr',
#   'started_at': '2019-05-09T11:26:45Z',
#   'tag_ids': ['62bc5436-6f91-446d-9651-da008da4e4bb',
#    'ff56eeeb-99ed-4a60-93fc-0b3f05d8661e',
#    'cc8d5abb-39c9-4942-a1ee-e1558512119e',
#    '6f655045-9989-4ef7-8f85-1edcec42d648'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_asmonacoesports-{width}x{height}.jpg',
#   'title': 'FR ➡️ Enki en live sur #SSBU !',
#   'type': 'live',
#   'user_id': '177396557',
#   'user_name': 'ASMonacoEsports',
#   'viewer_count': 9},
#  {'community_ids': ['0b9d06f9-fe5f-4f69-a4c3-2a9ee5604fb7',
#    '93a89f30-a7d0-485c-bc0f-d1d16055b7a6',
#    'dbec2d31-b2ad-49d0-9803-a752a0ef67fe'],
#   'game_id': '504461',
#   'id': '34045757344',
#   'language': 'en',
#   'started_at': '2019-05-09T09:37:37Z',
#   'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_zer0iced-{width}x{height}.jpg',
#   'title': '[U.K] 💀Round 1. Fight.💀',
#   'type': 'live',
#   'user_id': '43746033',
#   'user_name': 'Zer0iced',
#   'viewer_count': 8},
#  {'community_ids': ['848d95be-90b3-44a5-b143-6e373754c382',
#    'ff1e77af-551d-4993-945c-f8ceaa2a2829'],
#   'game_id': '504461',
#   'id': '34045206768',
#   'language': 'en',
#   'started_at': '2019-05-09T07:51:09Z',
#   'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_senpaijello-{width}x{height}.jpg',
#   'title': "Open Arena's come join!? ID: 4855V PS: 5154",
#   'type': 'live',
#   'user_id': '43760343',
#   'user_name': 'SenpaiJello',
#   'viewer_count': 8},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34044782704',
#   'language': 'en',
#   'started_at': '2019-05-09T06:20:14Z',
#   'tag_ids': ['13c95a9e-a17d-4225-b199-d08cb8e66f40',
#    '6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_maplemage-{width}x{height}.jpg',
#   'title': 'Smash Bros Ultimate. Elite Quickplay (me win, me learning link)',
#   'type': 'live',
#   'user_id': '26177997',
#   'user_name': 'Maplemage',
#   'viewer_count': 7},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34046277536',
#   'language': 'en',
#   'started_at': '2019-05-09T11:04:50Z',
#   'tag_ids': ['6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_xanderwels-{width}x{height}.jpg',
#   'title': 'Smash with the GF... What could go wrong?!?! :D | ID: DK83R PW: 1471',
#   'type': 'live',
#   'user_id': '122788883',
#   'user_name': 'XanderWels',
#   'viewer_count': 6},
#  {'community_ids': [],
#   'game_id': '504461',
#   'id': '34044714672',
#   'language': 'en',
#   'started_at': '2019-05-09T06:06:07Z',
#   'tag_ids': ['1eba3cfe-51cc-460a-8259-bc8bb987f904',
#    '3280c8d8-64c0-45f7-aeaa-189928b0e82c',
#    'ff56eeeb-99ed-4a60-93fc-0b3f05d8661e',
#    'e1a43486-eee5-4f36-9ee6-76e72af00180',
#    '2920fbf2-293e-4753-8ec7-b69dba5392d0',
#    '6ea6bca4-4712-4ab9-a906-e3336a9d8039'],
#   'thumbnail_url': 'https://static-cdn.jtvnw.net/previews-ttv/live_user_thesuchlel-{width}x{height}.jpg',
#   'title': '(Come by and chat) Arena battles (Ganon Cannon)',
#   'type': 'live',
#   'user_id': '44768693',
#   'user_name': 'TheSuchLel',
#   'viewer_count': 6}]

# %% [markdown]
# We have 30 points per minute to use for requests (https://dev.twitch.tv/docs/api/guide/).
#
# We can access the number of points remaining every time we make a request:

# %%
response.headers['Ratelimit-Remaining']
# Out:
# '29'

# %% [markdown]
# Now, viewer count for a game. (Is there a better way to sum over the 'viewer_count' field?)

# %%
sum([response.json()['data'][i]['viewer_count'] for i in range(len(response.json()['data']))  ])
# Out:
# 781

# %% [markdown]
# (Maybe the following:)

# %%
import pandas as pd

# %%
df = pd.DataFrame(response.json()['data'])
sum(df['viewer_count'])
# Out:
# 781

# %% [markdown]
# (Comparison:)

# %%
# %%time
for i in range(900):
    sum([response.json()['data'][i]['viewer_count'] for i in range(len(response.json()['data']))])
# Out:
# Wall time: 1.66 s

# %%
# %%time
for i in range(900):
    df = pd.DataFrame(response.json()['data'])
    sum(df['viewer_count'])
    
# this one seems slightly better if repeated
# Out:
# Wall time: 979 ms

# %%
# I wrote the try - except thing in case errors occur (e.g. 'too many requests'), in which case 
# 'res.json()['data'] does not exist

def get_views(game_id, n = 100):
    '''
    returns total number of view for game which id is game_id, for the top n <= 100 streams
    '''
    res = requests.get('https://api.twitch.tv/helix/streams?game_id={}&first={}'.format(game_id, n), headers=header)
    try:
        df = pd.DataFrame(res.json()['data'])
        s = sum(df['viewer_count'])
        #s = sum([res.json()['data'][i]['viewer_count'] for i in range(len(res.json()['data']))])
    except: 
        s = res.json()
    return s, res

# %%
v = get_views(504461)

# %%
v[0]
# Out:
# 797

# %%
# If we make too many requests (the limit is 30 per minute), the function waits a minute

def integrate_view_count(game_list, print_progress = False):
    '''
    integrates the list outputted by the function get_n_top_games() with the number of views for each game
    if print_progress = True it prints the progress
    '''
    len_game_list = len(game_list)
    for i in range(len_game_list):
        res = get_views(game_list[i]['id'], 100)
        game_list[i]['view_count'] = res[0]
        
        games_left = len_game_list - i - 1
        limit = int(res[1].headers['Ratelimit-Remaining'])
        if print_progress: print('Games left: {}\tPoints left: {}'.format(games_left, limit))
        
        if (limit == 0) and (games_left != 0):
            if print_progress: print('Processed {} games.\nHave to wait a minute...'.format(i+1))
            for j in range(60):
                if print_progress: print(60 - j)
                time.sleep(1)

# %%
t = get_n_top_games(99, header)

# %%
t = t[0:20] # just to make it quicker

# %%
integrate_view_count(t, True)
# Out:
# Games left: 19	Points left: 29
# Games left: 18	Points left: 28
# Games left: 17	Points left: 27
# Games left: 16	Points left: 26
# Games left: 15	Points left: 25
# Games left: 14	Points left: 24
# Games left: 13	Points left: 24
# Games left: 12	Points left: 23
# Games left: 11	Points left: 22
# Games left: 10	Points left: 21
# Games left: 9	Points left: 20
# Games left: 8	Points left: 19
# Games left: 7	Points left: 19
# Games left: 6	Points left: 18
# Games left: 5	Points left: 17
# Games left: 4	Points left: 16
# Games left: 3	Points left: 15
# Games left: 2	Points left: 15
# Games left: 1	Points left: 14
# Games left: 0	Points left: 13

# %%
for i in range(len(t)):
    print('{} {} {} {}'.format(i+1,t[i]['id'], t[i]['name'], t[i]['view_count']))
# Out:
# 1 33214 Fortnite 165961
# 2 29595 Dota 2 146784
# 3 21779 League of Legends 82111
# 4 509658 Just Chatting 65553
# 5 32982 Grand Theft Auto V 51379
# 6 138585 Hearthstone 37590
# 7 32399 Counter-Strike: Global Offensive 26293
# 8 493057 PLAYERUNKNOWN'S BATTLEGROUNDS 17658
# 9 488552 Overwatch 13995
# 10 511748 Auto Chess 15540
# 11 18122 World of Warcraft 13300
# 12 491487 Dead by Daylight 12509
# 13 511224 Apex Legends 7646
# 14 11989 StarCraft 9302
# 15 14958 Lunar: Dragon Song 9211
# 16 506103 FIFA 19 7257
# 17 460630 Tom Clancy's Rainbow Six: Siege 6025
# 18 509672 Travel & Outdoors 6262
# 19 498859 Mordhau 6056
# 20 498566 Slots 5580

# %% [markdown]
# ### Test v5 Api (deprecated)

# %% [markdown]
# With the API v5 we get the total viewer count directly, without having to query (the top 100) streams and summing over view count.

# %%
header_v5 = {
    'Accept': 'application/vnd.twitchtv.v5+json',
    'Client-ID': twitch_client_ID,
}

# %%
def print_games_list_v5(l):
    '''
    l must be a list of games dicts, with keys "name" and "id".
    the function prints l.
    '''
    for i in range(len(l)):
            print('{:2d} {:6d} :  {:40s} {} '.format(i + 1, l[i]['game']['_id'], l[i]['game']['name'], l[i]['viewers']))

# %% [markdown]
