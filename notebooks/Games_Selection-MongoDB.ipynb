# %%
from bson.son import SON

# %%
from pymongo import MongoClient
import re
import sys
import json
import pandas as pd
import numpy as np

# %%
sys.path.insert(0, '../scripts')

# %%
import uniformer

# %% [markdown]
# ## Connect to remote mongodb

# %%
from sshtunnel import SSHTunnelForwarder
import pymongo

# %%
with open('../keys.json') as k:
    keys = json.loads(k.read())
    MONGO_HOST = keys["SSH"]["MONGO_HOST"] # i.e. 10.9.13.14
    MONGO_DB = keys["SSH"]["MONGO_DB"] # i.e. dm_project 
    MONGO_USER = keys["SSH"]["MONGO_USER"] # i.e. studente
    MONGO_PASS = keys["SSH"]["MONGO_PASS"] # i.e. la password della vm

server = SSHTunnelForwarder(
    MONGO_HOST,
    ssh_username=MONGO_USER,
    ssh_password=MONGO_PASS,
    remote_bind_address=('127.0.0.1', 27017)
)

# %%
server.start() # remember to stop

# %%
client = pymongo.MongoClient('127.0.0.1', server.local_bind_port) # server.local_bind_port is assigned local port
db = client[MONGO_DB]

# %%
db.list_collection_names()
# Out:
# ['system.indexes', 'twitch', 'twitter', 'vgchartz']

# %%
games_coll = db.twitch

# %% [markdown]
# ## Top N games on twitch (collected between 28/05 and 30/05)

# %% [markdown]
# Just to check: how many times data from twitch has been collected between 28 and 30 May. We gather all the timestamps

# %%
pipeline = [{ "$match" : {'$and' : [
                {'timestamp' : {'$gt' : '2019-05-28'}},
                {'timestamp' : {'$lt' : '2019-05-30'}}
            ]}}, {"$project":
             {'_id': 0,
              'time':'$timestamp'} }]

# %%
tsmps = list(games_coll.aggregate(pipeline))

# %%
len(tsmps)/ 48
# Out:
# 20.0

# %% [markdown]
# Data has been collected every 3 minutes, so 20 times each hour is correct.

# %%
pipeline = [{"$unwind": "$data"},
            { "$match" : {'$and' : [
                {'timestamp' : {'$gt' : '2019-05-28'}},
                {'timestamp' : {'$lt' : '2019-05-30'}}
            ]}},
            { "$group": {"_id": {"name": "$data.game.name",
                                 "norm_name" : "$data.game.norm_name",
                                 "unary_name" : "$data.game.unary_name",
                                 "twitch_id" : "$data.game._id"},
                         "avgViewers": { "$avg": '$data.viewers'}}},
           {"$sort": SON([("avgViewers", -1), ("_id", -1)])}]

# %%
top_twitch = list(db.twitch.aggregate(pipeline))

# %%
top_twitch[0:3]
# Out:
# [{'_id': {'name': 'Fortnite',
#    'norm_name': 'fortnite',
#    'unary_name': 'fortnite',
#    'twitch_id': 33214},
#   'avgViewers': 126368.478125},
#  {'_id': {'name': 'League of Legends',
#    'norm_name': 'league of legends',
#    'unary_name': 'league of legends',
#    'twitch_id': 21779},
#   'avgViewers': 117746.63333333333},
#  {'_id': {'name': 'Grand Theft Auto V',
#    'norm_name': 'grand theft auto v',
#    'unary_name': 'grand theft auto v',
#    'twitch_id': 32982},
#   'avgViewers': 94222.24895833334}]

# %%
top_twitch = [
    {'name' : elem['_id']['name'],
     'norm_name' : elem['_id']['norm_name'],
     'unary_name' : elem['_id']['unary_name'],
     'twitch_id' : elem['_id']['twitch_id'],
     'avgViewers' : elem['avgViewers']
    } for elem in top_twitch
]

# %%
top_twitch[0:3]
# Out:
# [{'name': 'Fortnite',
#   'norm_name': 'fortnite',
#   'unary_name': 'fortnite',
#   'twitch_id': 33214,
#   'avgViewers': 126368.478125},
#  {'name': 'League of Legends',
#   'norm_name': 'league of legends',
#   'unary_name': 'league of legends',
#   'twitch_id': 21779,
#   'avgViewers': 117746.63333333333},
#  {'name': 'Grand Theft Auto V',
#   'norm_name': 'grand theft auto v',
#   'unary_name': 'grand theft auto v',
#   'twitch_id': 32982,
#   'avgViewers': 94222.24895833334}]

# %%
top_twitch_df = pd.DataFrame(top_twitch)
top_twitch_df.head()
# Out:
#       avgViewers                name           norm_name  twitch_id  \
# 0  126368.478125            Fortnite            fortnite      33214
# 1  117746.633333   League of Legends   league of legends      21779
# 2   94222.248958  Grand Theft Auto V  grand theft auto v      32982
# 3   79284.045833       Just Chatting       just chatting     509658
# 4   68005.006250              Dota 2             dota ii      29595
#
#            unary_name
# 0            fortnite
# 1   league of legends
# 2  grand theft auto v
# 3       just chatting
# 4             dota ii

# %% [markdown]
# # Top N games on Vgchartz from Mongo DB

# %% [markdown]
# It is necessary to execute the Notebook "Save Top N games on MongoDB" before executing the next code chunks

# %%
top_games_vg = db.vgchartz

# %% [markdown]
# Quick check for seeing if everything was loaded correctly

# %%
top_games_vg.find_one()
# Out:
# {'_id': ObjectId('5d13adcef0bd0623b0487cfe'),
#  'Rank': 1,
#  'Name': 'Wii Sports',
#  'Platform': 'Wii',
#  'Year': 2006.0,
#  'href_Genre': 'http://www.vgchartz.com/game/2667/wii-sports/?region=All',
#  'Publisher': 'Nintendo  ',
#  'Developer': 'Nintendo EAD  ',
#  'Critic_Score': 7.7,
#  'User_Score': nan,
#  'NA_Sales': 41.36,
#  'PAL_Sales': 29.02,
#  'JP_Sales': 3.77,
#  'Other_Sales': 8.51,
#  'Global_Sales': 82.65}

# %% [markdown]
# Vgchartz returns the global sales data for each game and for each Platform. Therefore the game "Grand Theft Auto V" will appear several times. Let's find out if this is correct.

# %%
gtaV_occurences = top_games_vg.find({"Name": "Grand Theft Auto V"})
for game in gtaV_occurences:
    print(game)
# Out:
# {'_id': ObjectId('5d13adcef0bd0623b0487d0f'), 'Rank': 20, 'Name': 'Grand Theft Auto V', 'Platform': 'PS3', 'Year': 2013.0, 'href_Genre': 'http://www.vgchartz.com/game/65884/grand-theft-auto-v/?region=All', 'Publisher': 'Rockstar Games  ', 'Developer': 'Rockstar North  ', 'Critic_Score': 9.4, 'User_Score': nan, 'NA_Sales': 6.37, 'PAL_Sales': 9.85, 'JP_Sales': 0.99, 'Other_Sales': 3.12, 'Global_Sales': 20.32}
# {'_id': ObjectId('5d13adcef0bd0623b0487d10'), 'Rank': 21, 'Name': 'Grand Theft Auto V', 'Platform': 'PS4', 'Year': 2014.0, 'href_Genre': 'http://www.vgchartz.com/game/83196/grand-theft-auto-v/?region=All', 'Publisher': 'Rockstar Games  ', 'Developer': 'Rockstar North  ', 'Critic_Score': 9.7, 'User_Score': nan, 'NA_Sales': 6.06, 'PAL_Sales': 9.71, 'JP_Sales': 0.6, 'Other_Sales': 3.02, 'Global_Sales': 19.39}
# {'_id': ObjectId('5d13adcef0bd0623b0487d1c'), 'Rank': 34, 'Name': 'Grand Theft Auto V', 'Platform': 'X360', 'Year': 2013.0, 'href_Genre': 'http://www.vgchartz.com/game/65883/grand-theft-auto-v/?region=All', 'Publisher': 'Rockstar Games  ', 'Developer': 'Rockstar North  ', 'Critic_Score': nan, 'User_Score': nan, 'NA_Sales': 9.06, 'PAL_Sales': 5.33, 'JP_Sales': 0.06, 'Other_Sales': 1.42, 'Global_Sales': 15.86}
# {'_id': ObjectId('5d13adcef0bd0623b0487d39'), 'Rank': 63, 'Name': 'Grand Theft Auto V', 'Platform': 'PC', 'Year': 2015.0, 'href_Genre': 'http://www.vgchartz.com/game/83197/grand-theft-auto-v/?region=All', 'Publisher': 'Rockstar Games  ', 'Developer': 'Rockstar North  ', 'Critic_Score': nan, 'User_Score': nan, 'NA_Sales': 0.48, 'PAL_Sales': 0.76, 'JP_Sales': nan, 'Other_Sales': 0.1, 'Global_Sales': 1.33}
# {'_id': ObjectId('5d13adcef0bd0623b0487d64'), 'Rank': 108, 'Name': 'Grand Theft Auto V', 'Platform': 'XOne', 'Year': 2014.0, 'href_Genre': 'http://www.vgchartz.com/game/73074/grand-theft-auto-v/?region=All', 'Publisher': 'Rockstar Games  ', 'Developer': 'Rockstar North  ', 'Critic_Score': 9.0, 'User_Score': 9.0, 'NA_Sales': 4.7, 'PAL_Sales': 3.25, 'JP_Sales': 0.01, 'Other_Sales': 0.76, 'Global_Sales': 8.72}

# %% [markdown]
# As imagined there is one data entry for each platform. We are interested in the "whole" game performance, therefore we will perform the following actions:
# - Group by the games according to their name.
# - Sum all the global sales
# - Average the Critic Score
# - Average the User Score
# - Store all Platforms: as in the GTA V case many games were released for different platforms, therefore it is important to not lose this info after the group by
# - Store all the game developers: it is possible that the games that were released for different platforms were developed by different software houses, therefore it is importat to not lose this info after the group by

# %%
# Works only for MongoDB 3.4 and later versions
"""vgchartz_pipeline = [
     { "$addFields": {
         "Critic_Score_norm": {"$cond": 
             { "if": { "$eq": [ "$Critic_Score", np.nan ] }, 
                   "then": "null", 
                   "else": "$Critic_Score" }},
         "User_Score_norm": {"$cond": 
             { "if": { "$eq": [ "$User_Score", np.nan ] }, 
                   "then": "null", 
                   "else": "$User_Score" }}
        }
     }, 
    { "$group": {
        "_id": "$Name",
        "Name": {"$first":"$Name"}, #This is necessary because every variable assignment should be done using group operators
        "Global_sales_all_platform": {"$sum": "$Global_Sales"},
        "Year": {"$first": "$Year"},
        "Critic_score": {"$avg":"$Critic_Score_norm"},
        "User_score": {"$avg":"$User_Score_norm"},
        "Publishers": {"$push": {"$concat":["$Publisher"]}},
        "Developers": {"$push": {"$concat":["$Developer"]}},
        "Platforms": {"$push": {"$concat":["$Platform"]}}
        }
    },
    { "$project": { "_id": 0 } },
    {"$sort": {"Global_sales_all_platform": -1} }]
top_vgchartz = list(top_games_vg.aggregate(vgchartz_pipeline))"""
# Out:
# 'vgchartz_pipeline = [\n     { "$addFields": {\n         "Critic_Score_norm": {"$cond": \n             { "if": { "$eq": [ "$Critic_Score", np.nan ] }, \n                   "then": "null", \n                   "else": "$Critic_Score" }},\n         "User_Score_norm": {"$cond": \n             { "if": { "$eq": [ "$User_Score", np.nan ] }, \n                   "then": "null", \n                   "else": "$User_Score" }}\n        }\n     }, \n    { "$group": {\n        "_id": "$Name",\n        "Name": {"$first":"$Name"}, #This is necessary because every variable assignment should be done using group operators\n        "Global_sales_all_platform": {"$sum": "$Global_Sales"},\n        "Year": {"$first": "$Year"},\n        "Critic_score": {"$avg":"$Critic_Score_norm"},\n        "User_score": {"$avg":"$User_Score_norm"},\n        "Publishers": {"$push": {"$concat":["$Publisher"]}},\n        "Developers": {"$push": {"$concat":["$Developer"]}},\n        "Platforms": {"$push": {"$concat":["$Platform"]}}\n        }\n    },\n    { "$project": { "_id": 0 } },\n    {"$sort": {"Global_sales_all_platform": -1} }]\ntop_vgchartz = list(top_games_vg.aggregate(vgchartz_pipeline))'

# %%
vgchartz_pipeline = [ 
    { "$group": {
        "_id": "$Name",
        "Name": {"$first":"$Name"}, #This is necessary because every variable assignment should be done using group operators
        "Global_sales_all_platform": {"$sum": "$Global_Sales"},
        "Year": {"$first": "$Year"},
        "Critic_score": {"$addToSet":"$Critic_Score"},
        "User_score": {"$addToSet":"$User_Score"},
        "Publishers": {"$push": {"$concat":["$Publisher"]}},
        "Developers": {"$push": {"$concat":["$Developer"]}},
        "Platforms": {"$push": {"$concat":["$Platform"]}}
        }
    },
    {"$sort": {"Global_sales_all_platform": -1} }]
top_vgchartz = list(top_games_vg.aggregate(vgchartz_pipeline))

# %%
vgchartz_df = pd.DataFrame.from_dict(top_vgchartz)
vgchartz_df.head(5)
# Out:
#            Critic_score                                         Developers  \
# 0                 [7.7]                                   [Nintendo EAD  ]
# 1  [9.0, nan, 9.7, 9.4]  [Rockstar North  , Rockstar North  , Rockstar ...
# 2                [10.0]                                   [Nintendo EAD  ]
# 3                 [8.2]                                   [Nintendo EAD  ]
# 4                 [nan]              [Bullet Proof Software  , Nintendo  ]
#
#    Global_sales_all_platform                Name                   Platforms  \
# 0                      82.65          Wii Sports                       [Wii]
# 1                      65.62  Grand Theft Auto V  [PS3, PS4, X360, PC, XOne]
# 2                      40.24   Super Mario Bros.                       [NES]
# 3                      35.98      Mario Kart Wii                       [Wii]
# 4                      35.84              Tetris                   [GB, NES]
#
#                                           Publishers  User_score    Year  \
# 0                                       [Nintendo  ]       [nan]  2006.0
# 1  [Rockstar Games  , Rockstar Games  , Rockstar ...  [9.0, nan]  2013.0
# 2                                       [Nintendo  ]       [8.2]  1985.0
# 3                                       [Nintendo  ]       [9.1]  2008.0
# 4                           [Nintendo  , Nintendo  ]       [nan]  1989.0
#
#                   _id
# 0          Wii Sports
# 1  Grand Theft Auto V
# 2   Super Mario Bros.
# 3      Mario Kart Wii
# 4              Tetris

# %%
vgchartz_df['Critic_score'] = vgchartz_df['Critic_score'].apply(lambda x: np.nanmean(x))
vgchartz_df.head(5)
# Out:
#    Critic_score                                         Developers  \
# 0      7.700000                                   [Nintendo EAD  ]
# 1      9.366667  [Rockstar North  , Rockstar North  , Rockstar ...
# 2     10.000000                                   [Nintendo EAD  ]
# 3      8.200000                                   [Nintendo EAD  ]
# 4           NaN              [Bullet Proof Software  , Nintendo  ]
#
#    Global_sales_all_platform                Name                   Platforms  \
# 0                      82.65          Wii Sports                       [Wii]
# 1                      65.62  Grand Theft Auto V  [PS3, PS4, X360, PC, XOne]
# 2                      40.24   Super Mario Bros.                       [NES]
# 3                      35.98      Mario Kart Wii                       [Wii]
# 4                      35.84              Tetris                   [GB, NES]
#
#                                           Publishers  User_score    Year  \
# 0                                       [Nintendo  ]       [nan]  2006.0
# 1  [Rockstar Games  , Rockstar Games  , Rockstar ...  [9.0, nan]  2013.0
# 2                                       [Nintendo  ]       [8.2]  1985.0
# 3                                       [Nintendo  ]       [9.1]  2008.0
# 4                           [Nintendo  , Nintendo  ]       [nan]  1989.0
#
#                   _id
# 0          Wii Sports
# 1  Grand Theft Auto V
# 2   Super Mario Bros.
# 3      Mario Kart Wii
# 4              Tetris

# %%
vgchartz_df['User_score'] = vgchartz_df['User_score'].apply(lambda x: np.nanmean(x))
vgchartz_df.head(5)
# Out:
#    Critic_score                                         Developers  \
# 0      7.700000                                   [Nintendo EAD  ]
# 1      9.366667  [Rockstar North  , Rockstar North  , Rockstar ...
# 2     10.000000                                   [Nintendo EAD  ]
# 3      8.200000                                   [Nintendo EAD  ]
# 4           NaN              [Bullet Proof Software  , Nintendo  ]
#
#    Global_sales_all_platform                Name                   Platforms  \
# 0                      82.65          Wii Sports                       [Wii]
# 1                      65.62  Grand Theft Auto V  [PS3, PS4, X360, PC, XOne]
# 2                      40.24   Super Mario Bros.                       [NES]
# 3                      35.98      Mario Kart Wii                       [Wii]
# 4                      35.84              Tetris                   [GB, NES]
#
#                                           Publishers  User_score    Year  \
# 0                                       [Nintendo  ]         NaN  2006.0
# 1  [Rockstar Games  , Rockstar Games  , Rockstar ...         9.0  2013.0
# 2                                       [Nintendo  ]         8.2  1985.0
# 3                                       [Nintendo  ]         9.1  2008.0
# 4                           [Nintendo  , Nintendo  ]         NaN  1989.0
#
#                   _id
# 0          Wii Sports
# 1  Grand Theft Auto V
# 2   Super Mario Bros.
# 3      Mario Kart Wii
# 4              Tetris

# %%
vgchartz_df['Developers'] = vgchartz_df['Developers'].apply(lambda x: set(x))
vgchartz_df.head(5)
# Out:
#    Critic_score                             Developers  \
# 0      7.700000                       {Nintendo EAD  }
# 1      9.366667                     {Rockstar North  }
# 2     10.000000                       {Nintendo EAD  }
# 3      8.200000                       {Nintendo EAD  }
# 4           NaN  {Nintendo  , Bullet Proof Software  }
#
#    Global_sales_all_platform                Name                   Platforms  \
# 0                      82.65          Wii Sports                       [Wii]
# 1                      65.62  Grand Theft Auto V  [PS3, PS4, X360, PC, XOne]
# 2                      40.24   Super Mario Bros.                       [NES]
# 3                      35.98      Mario Kart Wii                       [Wii]
# 4                      35.84              Tetris                   [GB, NES]
#
#                                           Publishers  User_score    Year  \
# 0                                       [Nintendo  ]         NaN  2006.0
# 1  [Rockstar Games  , Rockstar Games  , Rockstar ...         9.0  2013.0
# 2                                       [Nintendo  ]         8.2  1985.0
# 3                                       [Nintendo  ]         9.1  2008.0
# 4                           [Nintendo  , Nintendo  ]         NaN  1989.0
#
#                   _id
# 0          Wii Sports
# 1  Grand Theft Auto V
# 2   Super Mario Bros.
# 3      Mario Kart Wii
# 4              Tetris

# %%
vgchartz_df['Publishers'] = vgchartz_df['Publishers'].apply(lambda x: set(x))
vgchartz_df.head(5)
# Out:
#    Critic_score                             Developers  \
# 0      7.700000                       {Nintendo EAD  }
# 1      9.366667                     {Rockstar North  }
# 2     10.000000                       {Nintendo EAD  }
# 3      8.200000                       {Nintendo EAD  }
# 4           NaN  {Nintendo  , Bullet Proof Software  }
#
#    Global_sales_all_platform                Name                   Platforms  \
# 0                      82.65          Wii Sports                       [Wii]
# 1                      65.62  Grand Theft Auto V  [PS3, PS4, X360, PC, XOne]
# 2                      40.24   Super Mario Bros.                       [NES]
# 3                      35.98      Mario Kart Wii                       [Wii]
# 4                      35.84              Tetris                   [GB, NES]
#
#            Publishers  User_score    Year                 _id
# 0        {Nintendo  }         NaN  2006.0          Wii Sports
# 1  {Rockstar Games  }         9.0  2013.0  Grand Theft Auto V
# 2        {Nintendo  }         8.2  1985.0   Super Mario Bros.
# 3        {Nintendo  }         9.1  2008.0      Mario Kart Wii
# 4        {Nintendo  }         NaN  1989.0              Tetris

# %% [markdown]
# # Join Vgchartz and Twitch Data

# %% [markdown]
# Let's join the data and see the first 25 games

# %%
merged_df = pd.merge(vgchartz_df, top_twitch_df,  left_on = 'Name', right_on = 'name', how = 'outer')
merged_df[['Name', 'twitch_id', 'norm_name', 'name']].loc[0:24]
# Out:
#                                   Name  twitch_id  \
# 0                           Wii Sports    12232.0
# 1                   Grand Theft Auto V    32982.0
# 2                    Super Mario Bros.   509508.0
# 3                       Mario Kart Wii    18871.0
# 4                               Tetris     1736.0
# 5                            Minecraft    27471.0
# 6                    Wii Sports Resort    19259.0
# 7   Pokémon Red / Green / Blue Version        NaN
# 8              Call of Duty: Black Ops    23894.0
# 9       Call of Duty: Modern Warfare 3    31551.0
# 10               New Super Mario Bros.     7534.0
# 11          Call of Duty: Black Ops II    34134.0
# 12                            Wii Play     8660.0
# 13                Call of Duty: Ghosts   118200.0
# 14           New Super Mario Bros. Wii    24238.0
# 15                           Duck Hunt     2530.0
# 16           Call of Duty: Black Ops 3        NaN
# 17      Call of Duty: Modern Warfare 2        NaN
# 18                          Nintendogs        NaN
# 19       Grand Theft Auto: San Andreas     6521.0
# 20                       Mario Kart DS     5993.0
# 21       Pokémon Gold / Silver Version        NaN
# 22                             Wii Fit        NaN
# 23                 Grand Theft Auto IV    18707.0
# 24                  Kinect Adventures!        NaN
#
#                           norm_name                            name
# 0                        wii sports                      Wii Sports
# 1                grand theft auto v              Grand Theft Auto V
# 2                 super mario bros.               Super Mario Bros.
# 3                    mario kart wii                  Mario Kart Wii
# 4                            tetris                          Tetris
# 5                         minecraft                       Minecraft
# 6                 wii sports resort               Wii Sports Resort
# 7                               NaN                             NaN
# 8            call of duty black ops         Call of Duty: Black Ops
# 9   call of duty modern warfare iii  Call of Duty: Modern Warfare 3
# 10            new super mario bros.           New Super Mario Bros.
# 11        call of duty black ops ii      Call of Duty: Black Ops II
# 12                         wii play                        Wii Play
# 13              call of duty ghosts            Call of Duty: Ghosts
# 14        new super mario bros. wii       New Super Mario Bros. Wii
# 15                        duck hunt                       Duck Hunt
# 16                              NaN                             NaN
# 17                              NaN                             NaN
# 18                              NaN                             NaN
# 19     grand theft auto san andreas   Grand Theft Auto: San Andreas
# 20                    mario kart ds                   Mario Kart DS
# 21                              NaN                             NaN
# 22                              NaN                             NaN
# 23              grand theft auto iv             Grand Theft Auto IV
# 24                              NaN                             NaN

# %% [markdown]
# As you can see there may be no match between the two dataframes. In order to find more matches we try to transform the names in both dataframes into the same format, by lowering the name, deleting some punctuation and converting arabic numbers to roman. This has already been done to the Twitch data, resultinng in the field 'norm_name', so we just need to do this for the vgchartz df.

# %%
top_twitch_df.head(5)
# Out:
#       avgViewers                name           norm_name  twitch_id  \
# 0  126368.478125            Fortnite            fortnite      33214
# 1  117746.633333   League of Legends   league of legends      21779
# 2   94222.248958  Grand Theft Auto V  grand theft auto v      32982
# 3   79284.045833       Just Chatting       just chatting     509658
# 4   68005.006250              Dota 2             dota ii      29595
#
#            unary_name
# 0            fortnite
# 1   league of legends
# 2  grand theft auto v
# 3       just chatting
# 4             dota ii

# %% [markdown]
# We will use a specific custom function that will "normalize" the names.

# %%
vgchartz_df['Norm_name_vgchartz'] = vgchartz_df['Name'].apply(lambda x: uniformer.uniform(x))

# %%
merged_df = pd.merge(vgchartz_df, top_twitch_df,  left_on = 'Norm_name_vgchartz', right_on = 'norm_name', how = 'outer').loc[0:50]
merged_df[['Norm_name_vgchartz', 'norm_name', 'Name', 'name', 'twitch_id']].head(10)
# Out:
#                    Norm_name_vgchartz                        norm_name  \
# 0                          wii sports                       wii sports
# 1                  grand theft auto v               grand theft auto v
# 2                   super mario bros.                super mario bros.
# 3                      mario kart wii                   mario kart wii
# 4                              tetris                           tetris
# 5                           minecraft                        minecraft
# 6                   wii sports resort                wii sports resort
# 7  pokémon red / green / blue version                              NaN
# 8              call of duty black ops           call of duty black ops
# 9     call of duty modern warfare iii  call of duty modern warfare iii
#
#                                  Name                            name  \
# 0                          Wii Sports                      Wii Sports
# 1                  Grand Theft Auto V              Grand Theft Auto V
# 2                   Super Mario Bros.               Super Mario Bros.
# 3                      Mario Kart Wii                  Mario Kart Wii
# 4                              Tetris                          Tetris
# 5                           Minecraft                       Minecraft
# 6                   Wii Sports Resort               Wii Sports Resort
# 7  Pokémon Red / Green / Blue Version                             NaN
# 8             Call of Duty: Black Ops         Call of Duty: Black Ops
# 9      Call of Duty: Modern Warfare 3  Call of Duty: Modern Warfare 3
#
#    twitch_id
# 0    12232.0
# 1    32982.0
# 2   509508.0
# 3    18871.0
# 4     1736.0
# 5    27471.0
# 6    19259.0
# 7        NaN
# 8    23894.0
# 9    31551.0

# %% [markdown]
# Let's check which matches are still missing:

# %%
merged_df[merged_df['norm_name'].isna()][['Norm_name_vgchartz']]
# Out:
#                              Norm_name_vgchartz
# 7            pokémon red / green / blue version
# 17               call of duty modern warfare ii
# 18                                   nintendogs
# 21                pokémon gold / silver version
# 22                                      wii fit
# 24                           kinect adventures!
# 25                                 wii fit plus
# 29  brain age train your brain in minutes a day
# 33              pokémon diamond / pearl version
# 45              pokémon ruby / sapphire version
# 48                                    fifa xiii
# 50   brain age 2 more training in minutes a day

# %% [markdown]
# - pokemon red / green / blue is called different

# %%
top_twitch_df[top_twitch_df['norm_name'].str.contains('pokémon red')]
# Out:
#       avgViewers              name         norm_name  twitch_id  \
# 1096    31.33956  Pokémon Red/Blue  pokémon red/blue       3623
#
#             unary_name
# 1096  pokémon red/blue

# %%
vgchartz_df.loc[vgchartz_df.Norm_name_vgchartz == "pokémon red / green / blue version", "Norm_name_vgchartz"] = 'pokémon red/blue'

# %% [markdown]
# - call of duty modern warfare ii is called slightly different

# %%
top_twitch_df[top_twitch_df['norm_name'].str.contains('modern warfare')]
# Out:
#       avgViewers                                     name  \
# 436   165.033684                         Modern Warfare 2
# 556   109.727561  Call of Duty: Modern Warfare Remastered
# 1128   29.654709           Call of Duty: Modern Warfare 3
# 1196   27.126836           Call of Duty 4: Modern Warfare
# 1365   21.397849             Call of Duty: Modern Warfare
# 7550    0.507289  Call of Duty: Modern Warfare: Mobilized
#
#                                    norm_name  twitch_id  \
# 436                        modern warfare ii      22393
# 556   call of duty modern warfare remastered     494155
# 1128         call of duty modern warfare iii      31551
# 1196           call of duty 4 modern warfare       1964
# 1365             call of duty modern warfare     512710
# 7550   call of duty modern warfare mobilized      24951
#
#                                   unary_name
# 436                        modern warfare ii
# 556   call of duty modern warfare remastered
# 1128         call of duty modern warfare iii
# 1196           call of duty 4 modern warfare
# 1365             call of duty modern warfare
# 7550   call of duty modern warfare mobilized

# %%
vgchartz_df.loc[vgchartz_df.Norm_name_vgchartz == "call of duty modern warfare ii", "Norm_name_vgchartz"] = 'modern warfare ii'

# %% [markdown]
# - nintendogs is not on twitch

# %%
top_twitch_df[top_twitch_df['norm_name'].str.contains('nintend')]
# Out:
#        avgViewers                                          name  \
# 54    3212.307692                                 Nintendo Land
# 107   1207.275362                  Monopoly for Nintendo Switch
# 1713    14.360825            Super Smash Bros. for Nintendo 3DS
# 2527     7.700000   Pokémon for Nintendo Switch (Working Title)
# 2734     6.835443                          Nintendo Fan Network
# 3679     4.273973    Taiko no Tatsujin: Nintendo Switch Version
# 4756     2.709091                     Nintendo Labo Variety Kit
# 4989     2.444444  Dragon Quest Heroes I・II for Nintendo Switch
# 5082     2.333333                 Nintendo DSi Instrument Tuner
#
#                                          norm_name  twitch_id  \
# 54                                   nintendo land      65960
# 107                   monopoly for nintendo switch     496604
# 1713            super smash bros. for nintendo 3ds     489023
# 2527   pokémon for nintendo switch (working title)     497451
# 2734                          nintendo fan network     491512
# 3679     taiko no tatsujin nintendo switch version     504454
# 4756                     nintendo labo variety kit     502913
# 4989  dragon quest heroes i・ii for nintendo switch     495059
# 5082                 nintendo dsi instrument tuner      25237
#
#                                         unary_name
# 54                                   nintendo land
# 107                   monopoly for nintendo switch
# 1713            super smash bros. for nintendo 3ds
# 2527   pokémon for nintendo switch (working title)
# 2734                          nintendo fan network
# 3679     taiko no tatsujin nintendo switch version
# 4756                     nintendo labo variety kit
# 4989  dragon quest heroes i・ii for nintendo switch
# 5082                 nintendo dsi instrument tuner

# %% [markdown]
# - wii fit/ wii fit plus are not on twitch

# %%
top_twitch_df[top_twitch_df['norm_name'].str.contains('wii')]
# Out:
#       avgViewers                                  name  \
# 602    93.326776                        Mario Kart Wii
# 740    63.221985                    Call of Duty: WWII
# 806    54.773810  Strategic Command WWII: World at War
# 1445   19.032258     PokéPark Wii: Pikachu's Adventure
# 1969   11.296296                       Wii Sports Club
# 2043   10.728448             New Super Mario Bros. Wii
# 3391    4.881188                            Wii Sports
# 4243    3.333333                           Wii Party U
# 4434    3.050657           Super Smash Bros. for Wii U
# 6149    1.500000      Mario Kart Wii U (Working Title)
# 6315    1.351852                     Wii Sports Resort
# 6492    1.200000      Taiko no Tatsujin: Wii U Version
# 7245    0.833333                              Wii Play
#
#                                 norm_name  twitch_id  \
# 602                        mario kart wii      18871
# 740                     call of duty wwii     496712
# 806   strategic command wwii world at war     510548
# 1445     poképark wii pikachu's adventure      28024
# 1969                      wii sports club     408033
# 2043            new super mario bros. wii      24238
# 3391                           wii sports      12232
# 4243                          wii party u     110751
# 4434          super smash bros. for wii u     488353
# 6149     mario kart wii u (working title)     110753
# 6315                    wii sports resort      19259
# 6492      taiko no tatsujin wii u version     460064
# 7245                             wii play       8660
#
#                                unary_name
# 602                        mario kart wii
# 740                     call of duty wwii
# 806   strategic command wwii world at war
# 1445     poképark wii pikachu's adventure
# 1969                      wii sports club
# 2043            new super mario bros. wii
# 3391                           wii sports
# 4243                          wii party u
# 4434          super smash bros. for wii u
# 6149     mario kart wii u (working title)
# 6315                    wii sports resort
# 6492      taiko no tatsujin wii u version
# 7245                             wii play

# %% [markdown]
# - kinect adventures is not on twitch

# %%
top_twitch_df[top_twitch_df['norm_name'].str.contains('kinect')]
# Out:
#       avgViewers                                   name  \
# 3569    4.483871           Kinect Disneyland Adventures
# 5502    2.000000  Kinect Rush: A Disney/Pixar Adventure
# 5942    1.666667                Harry Potter for Kinect
# 6972    1.000000                   Fruit Ninja Kinect 2
#
#                                  norm_name  twitch_id  \
# 3569          kinect disneyland adventures      31884
# 5502  kinect rush a disney/pixar adventure      32939
# 5942               harry potter for kinect      65831
# 6972                 fruit ninja kinect ii     461397
#
#                                 unary_name
# 3569          kinect disneyland adventures
# 5502  kinect rush a disney/pixar adventure
# 5942               harry potter for kinect
# 6972                 fruit ninja kinect ii

# %% [markdown]
# - brain age/ brain age 2 are not on twitch

# %%
top_twitch_df[top_twitch_df['norm_name'].str.contains('brain')]
# Out:
#       avgViewers                     name                norm_name  twitch_id  \
# 1544   17.117647              Brain / Out              brain / out     496037
# 2466    8.000000               Brain Lord               brain lord       1447
# 5343    2.097087  The Island of Dr. Brain  the island of dr. brain      16134
#
#                    unary_name
# 1544              brain / out
# 2466               brain lord
# 5343  the island of dr. brain

# %% [markdown]
# Solving the remaining Pokemon discrepancies:

# %%
top_twitch_df[top_twitch_df['norm_name'].str.contains('ruby')]
# Out:
#       avgViewers                               name  \
# 582   100.829940              Pokémon Ruby/Sapphire
# 1600   16.106299  Pokémon Omega Ruby/Alpha Sapphire
# 5969    1.636364   Pokémon Pinball: Ruby & Sapphire
#
#                               norm_name  twitch_id  \
# 582               pokémon ruby/sapphire       9287
# 1600  pokémon omega ruby/alpha sapphire     460327
# 5969    pokémon pinball ruby & sapphire       8075
#
#                              unary_name
# 582               pokémon ruby/sapphire
# 1600  pokémon omega ruby/alpha sapphire
# 5969    pokémon pinball ruby & sapphire

# %%
vgchartz_df.loc[vgchartz_df.Norm_name_vgchartz == "pokémon ruby / sapphire version", 'Norm_name_vgchartz'] = 'pokémon ruby/sapphire'

# %%
top_twitch_df[top_twitch_df['norm_name'].str.contains('pearl')]
# Out:
#       avgViewers                   name              norm_name  twitch_id  \
# 1549   17.008197  Pokémon Diamond/Pearl  pokémon diamond/pearl       2993
#
#                  unary_name
# 1549  pokémon diamond/pearl

# %%
vgchartz_df.loc[vgchartz_df.Norm_name_vgchartz == "pokémon diamond / pearl version", "Norm_name_vgchartz"] = 'pokémon diamond/pearl'

# %%
top_twitch_df[top_twitch_df['norm_name'].str.contains('pokémon gold')]
# Out:
#       avgViewers                 name            norm_name  twitch_id  \
# 1114   30.186462  Pokémon Gold/Silver  pokémon gold/silver       7528
#
#                unary_name
# 1114  pokémon gold/silver

# %%
vgchartz_df.loc[vgchartz_df.Norm_name_vgchartz == "pokémon gold / silver version", "Norm_name_vgchartz"] = 'pokémon gold/silver'

# %% [markdown]
# - Let's see if Fifa 13 is available on twitch

# %%
top_twitch_df[top_twitch_df['norm_name'].str.contains('fifa')]
# Out:
#         avgViewers             name          norm_name  twitch_id  \
# 20    10657.876042          FIFA 19           fifa xix     506103
# 245     416.171717   FIFA Soccer 97  fifa soccer xcvii       3107
# 368     217.278912          FIFA 11            fifa xi      28500
# 379     203.572939          FIFA 17          fifa xvii     493091
# 601      93.448649          FIFA 15            fifa xv     460402
# 641      82.997126    FIFA Online 4     fifa online iv     504798
# 1173     28.109560          FIFA 18         fifa xviii     495589
# 4785      2.666667   FIFA Soccer 13   fifa soccer xiii      32443
# 5521      2.000000        FIFA 2000            fifa mm      26486
# 5747      1.835821          FIFA 16           fifa xvi     489608
# 6120      1.507246   FIFA Soccer 09     fifa soccer ix      19207
# 6602      1.117647          FIFA 10             fifa x      24123
# 6620      1.107143    FIFA Online 3    fifa online iii     491191
# 6984      1.000000   FIFA Soccer 07    fifa soccer vii         42
# 6985      1.000000  FIFA Manager 08  fifa manager viii      26339
# 7203      0.875000          FIFA 99          fifa xcix      14628
# 7551      0.505051      FIFA Mobile        fifa mobile     496320
# 8439      0.000000          FIFA 14           fifa xiv     369095
#
#                                              unary_name
# 20                             fifa iiiiiiiiiiiiiiiiiii
# 245   fifa soccer iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 368                                    fifa iiiiiiiiiii
# 379                              fifa iiiiiiiiiiiiiiiii
# 601                                fifa iiiiiiiiiiiiiii
# 641                                    fifa online iiii
# 1173                            fifa iiiiiiiiiiiiiiiiii
# 4785                          fifa soccer iiiiiiiiiiiii
# 5521  fifa iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 5747                              fifa iiiiiiiiiiiiiiii
# 6120                              fifa soccer iiiiiiiii
# 6602                                    fifa iiiiiiiiii
# 6620                                    fifa online iii
# 6984                                fifa soccer iiiiiii
# 6985                              fifa manager iiiiiiii
# 7203  fifa iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 7551                                        fifa mobile
# 8439                                fifa iiiiiiiiiiiiii

# %%
vgchartz_df.loc[vgchartz_df.Norm_name_vgchartz == "fifa xiii", "Norm_name_vgchartz"] = 'fifa soccer xiii'

# %% [markdown]
# Now the main discrepancies are solved, let's rejoin the datasets

# %% [markdown]
# ## Merge data

# %%
top_twitch_vgchartz = pd.merge(vgchartz_df, top_twitch_df,  left_on = 'Norm_name_vgchartz', right_on = 'norm_name', how = 'outer').loc[0:50]

# %%
top_twitch_vgchartz.head(25)
# Out:
#     Critic_score                                         Developers  \
# 0       7.700000                                   {Nintendo EAD  }
# 1       9.366667                                 {Rockstar North  }
# 2      10.000000                                   {Nintendo EAD  }
# 3       8.200000                                   {Nintendo EAD  }
# 4            NaN              {Nintendo  , Bullet Proof Software  }
# 5       7.700000  {Mojang  , 4J Studios  , Other Ocean Interacti...
# 6       8.000000                                   {Nintendo EAD  }
# 7       9.400000                                     {Game Freak  }
# 8       8.100000                            {Treyarch  , n-Space  }
# 9       7.500000                                  {Infinity Ward  }
# 10      9.100000                                   {Nintendo EAD  }
# 11      8.600000                                       {Treyarch  }
# 12      5.900000                                   {Nintendo EAD  }
# 13      7.733333                                  {Infinity Ward  }
# 14      8.600000                                   {Nintendo EAD  }
# 15           NaN                                  {Nintendo R&D1  }
# 16           NaN                                       {Treyarch  }
# 17      9.250000                                  {Infinity Ward  }
# 18      8.400000                                   {Nintendo EAD  }
# 19      9.366667                      {Unknown  , Rockstar North  }
# 20      9.100000                                   {Nintendo EAD  }
# 21      9.200000                                     {Game Freak  }
# 22      7.900000                                   {Nintendo EAD  }
# 23      9.600000             {Rockstar Toronto  , Rockstar North  }
# 24      6.700000                            {Good Science Studio  }
#
#     Global_sales_all_platform                                Name  \
# 0                       82.65                          Wii Sports
# 1                       65.62                  Grand Theft Auto V
# 2                       40.24                   Super Mario Bros.
# 3                       35.98                      Mario Kart Wii
# 4                       35.84                              Tetris
# 5                       33.83                           Minecraft
# 6                       32.90                   Wii Sports Resort
# 7                       31.37  Pokémon Red / Green / Blue Version
# 8                       30.99             Call of Duty: Black Ops
# 9                       30.71      Call of Duty: Modern Warfare 3
# 10                      29.85               New Super Mario Bros.
# 11                      29.59          Call of Duty: Black Ops II
# 12                      28.92                            Wii Play
# 13                      28.80                Call of Duty: Ghosts
# 14                      28.51           New Super Mario Bros. Wii
# 15                      28.31                           Duck Hunt
# 16                      26.72           Call of Duty: Black Ops 3
# 17                      25.02      Call of Duty: Modern Warfare 2
# 18                      24.68                          Nintendogs
# 19                      23.87       Grand Theft Auto: San Andreas
# 20                      23.26                       Mario Kart DS
# 21                      23.10       Pokémon Gold / Silver Version
# 22                      22.70                             Wii Fit
# 23                      22.53                 Grand Theft Auto IV
# 24                      22.10                  Kinect Adventures!
#
#                                      Platforms  \
# 0                                        [Wii]
# 1                   [PS3, PS4, X360, PC, XOne]
# 2                                        [NES]
# 3                                        [Wii]
# 4                                    [GB, NES]
# 5   [X360, PS4, PS3, XOne, PSV, NS, WiiU, 3DS]
# 6                                        [Wii]
# 7                                         [GB]
# 8                     [X360, PS3, PC, Wii, DS]
# 9                         [X360, PS3, PC, Wii]
# 10                                        [DS]
# 11                       [X360, PS3, PC, WiiU]
# 12                                       [Wii]
# 13            [X360, PS3, PS4, XOne, PC, WiiU]
# 14                                       [Wii]
# 15                                       [NES]
# 16                  [PS4, XOne, X360, PS3, PC]
# 17                             [X360, PS3, PC]
# 18                                        [DS]
# 19                     [PS2, XB, PC, XBL, PS3]
# 20                                        [DS]
# 21                                        [GB]
# 22                                       [Wii]
# 23                             [X360, PS3, PC]
# 24                                      [X360]
#
#                                            Publishers  User_score    Year  \
# 0                                        {Nintendo  }         NaN  2006.0
# 1                                  {Rockstar Games  }         9.0  2013.0
# 2                                        {Nintendo  }         8.2  1985.0
# 3                                        {Nintendo  }         9.1  2008.0
# 4                                        {Nintendo  }         NaN  1989.0
# 5   {Sony Computer Entertainment America  , Micros...         NaN  2013.0
# 6                                        {Nintendo  }         8.8  2009.0
# 7                                        {Nintendo  }         NaN  1998.0
# 8                                      {Activision  }         NaN  2010.0
# 9                                      {Activision  }         NaN  2011.0
# 10                                       {Nintendo  }         8.1  2006.0
# 11                                     {Activision  }         NaN  2012.0
# 12                                       {Nintendo  }         4.5  2007.0
# 13                                     {Activision  }         NaN  2013.0
# 14                                       {Nintendo  }         9.2  2009.0
# 15                                       {Nintendo  }         NaN  1985.0
# 16                                     {Activision  }         NaN  2015.0
# 17                                     {Activision  }         9.0  2009.0
# 18                                       {Nintendo  }         NaN  2005.0
# 19                                 {Rockstar Games  }         NaN  2004.0
# 20                                       {Nintendo  }         9.4  2005.0
# 21                                       {Nintendo  }         NaN  2000.0
# 22                                       {Nintendo  }         NaN  2008.0
# 23                                 {Rockstar Games  }         9.0  2008.0
# 24                         {Microsoft Game Studios  }         NaN  2010.0
#
#                                    _id               Norm_name_vgchartz  \
# 0                           Wii Sports                       wii sports
# 1                   Grand Theft Auto V               grand theft auto v
# 2                    Super Mario Bros.                super mario bros.
# 3                       Mario Kart Wii                   mario kart wii
# 4                               Tetris                           tetris
# 5                            Minecraft                        minecraft
# 6                    Wii Sports Resort                wii sports resort
# 7   Pokémon Red / Green / Blue Version                 pokémon red/blue
# 8              Call of Duty: Black Ops           call of duty black ops
# 9       Call of Duty: Modern Warfare 3  call of duty modern warfare iii
# 10               New Super Mario Bros.            new super mario bros.
# 11          Call of Duty: Black Ops II        call of duty black ops ii
# 12                            Wii Play                         wii play
# 13                Call of Duty: Ghosts              call of duty ghosts
# 14           New Super Mario Bros. Wii        new super mario bros. wii
# 15                           Duck Hunt                        duck hunt
# 16           Call of Duty: Black Ops 3       call of duty black ops iii
# 17      Call of Duty: Modern Warfare 2                modern warfare ii
# 18                          Nintendogs                       nintendogs
# 19       Grand Theft Auto: San Andreas     grand theft auto san andreas
# 20                       Mario Kart DS                    mario kart ds
# 21       Pokémon Gold / Silver Version              pokémon gold/silver
# 22                             Wii Fit                          wii fit
# 23                 Grand Theft Auto IV              grand theft auto iv
# 24                  Kinect Adventures!               kinect adventures!
#
#       avgViewers                            name  \
# 0       4.881188                      Wii Sports
# 1   94222.248958              Grand Theft Auto V
# 2      49.296454               Super Mario Bros.
# 3      93.326776                  Mario Kart Wii
# 4      50.957424                          Tetris
# 5   12378.073958                       Minecraft
# 6       1.351852               Wii Sports Resort
# 7      31.339560                Pokémon Red/Blue
# 8     394.394931         Call of Duty: Black Ops
# 9      29.654709  Call of Duty: Modern Warfare 3
# 10     16.794595           New Super Mario Bros.
# 11    630.080851      Call of Duty: Black Ops II
# 12      0.833333                        Wii Play
# 13     20.071879            Call of Duty: Ghosts
# 14     10.728448       New Super Mario Bros. Wii
# 15      1.000000                       Duck Hunt
# 16    244.281381     Call of Duty: Black Ops III
# 17    165.033684                Modern Warfare 2
# 18           NaN                             NaN
# 19    434.606092   Grand Theft Auto: San Andreas
# 20      0.909091                   Mario Kart DS
# 21     30.186462             Pokémon Gold/Silver
# 22           NaN                             NaN
# 23     25.548611             Grand Theft Auto IV
# 24           NaN                             NaN
#
#                           norm_name  twitch_id  \
# 0                        wii sports    12232.0
# 1                grand theft auto v    32982.0
# 2                 super mario bros.   509508.0
# 3                    mario kart wii    18871.0
# 4                            tetris     1736.0
# 5                         minecraft    27471.0
# 6                 wii sports resort    19259.0
# 7                  pokémon red/blue     3623.0
# 8            call of duty black ops    23894.0
# 9   call of duty modern warfare iii    31551.0
# 10            new super mario bros.     7534.0
# 11        call of duty black ops ii    34134.0
# 12                         wii play     8660.0
# 13              call of duty ghosts   118200.0
# 14        new super mario bros. wii    24238.0
# 15                        duck hunt     2530.0
# 16       call of duty black ops iii   489401.0
# 17                modern warfare ii    22393.0
# 18                              NaN        NaN
# 19     grand theft auto san andreas     6521.0
# 20                    mario kart ds     5993.0
# 21              pokémon gold/silver     7528.0
# 22                              NaN        NaN
# 23              grand theft auto iv    18707.0
# 24                              NaN        NaN
#
#                          unary_name
# 0                        wii sports
# 1                grand theft auto v
# 2                 super mario bros.
# 3                    mario kart wii
# 4                            tetris
# 5                         minecraft
# 6                 wii sports resort
# 7                  pokémon red/blue
# 8            call of duty black ops
# 9   call of duty modern warfare iii
# 10            new super mario bros.
# 11        call of duty black ops ii
# 12                         wii play
# 13              call of duty ghosts
# 14        new super mario bros. wii
# 15                        duck hunt
# 16       call of duty black ops iii
# 17                modern warfare ii
# 18                              NaN
# 19     grand theft auto san andreas
# 20                    mario kart ds
# 21              pokémon gold/silver
# 22                              NaN
# 23              grand theft auto iv
# 24                              NaN

# %% [markdown]
# ## Identifying the final list of 50 games

# %% [markdown]
# We have decided to monitor the following data:
# - Top 25 games from vgchartz (excluding the ones that aren't on twitch)
# - Top 25 games from twitch (excluding the ones that were previously selected)

# %% [markdown]
# ### Select top 25 from vgchartz

# %%
top_25_vgchartz = top_twitch_vgchartz[top_twitch_vgchartz.norm_name.notnull()].reset_index().loc[0:24]

# %%
top_25_vgchartz
# Out:
#     index  Critic_score                                         Developers  \
# 0       0      7.700000                                   {Nintendo EAD  }
# 1       1      9.366667                                 {Rockstar North  }
# 2       2     10.000000                                   {Nintendo EAD  }
# 3       3      8.200000                                   {Nintendo EAD  }
# 4       4           NaN              {Nintendo  , Bullet Proof Software  }
# 5       5      7.700000  {Mojang  , 4J Studios  , Other Ocean Interacti...
# 6       6      8.000000                                   {Nintendo EAD  }
# 7       7      9.400000                                     {Game Freak  }
# 8       8      8.100000                            {Treyarch  , n-Space  }
# 9       9      7.500000                                  {Infinity Ward  }
# 10     10      9.100000                                   {Nintendo EAD  }
# 11     11      8.600000                                       {Treyarch  }
# 12     12      5.900000                                   {Nintendo EAD  }
# 13     13      7.733333                                  {Infinity Ward  }
# 14     14      8.600000                                   {Nintendo EAD  }
# 15     15           NaN                                  {Nintendo R&D1  }
# 16     16           NaN                                       {Treyarch  }
# 17     17      9.250000                                  {Infinity Ward  }
# 18     19      9.366667                      {Unknown  , Rockstar North  }
# 19     20      9.100000                                   {Nintendo EAD  }
# 20     21      9.200000                                     {Game Freak  }
# 21     23      9.600000             {Rockstar Toronto  , Rockstar North  }
# 22     26      8.625000        {Sledgehammer Games  , High Moon Studios  }
# 23     27      8.500000                                   {Nintendo EAD  }
# 24     28      9.025000    {Bethesda Game Studios  , Bethesda Softworks  }
#
#     Global_sales_all_platform                                Name  \
# 0                       82.65                          Wii Sports
# 1                       65.62                  Grand Theft Auto V
# 2                       40.24                   Super Mario Bros.
# 3                       35.98                      Mario Kart Wii
# 4                       35.84                              Tetris
# 5                       33.83                           Minecraft
# 6                       32.90                   Wii Sports Resort
# 7                       31.37  Pokémon Red / Green / Blue Version
# 8                       30.99             Call of Duty: Black Ops
# 9                       30.71      Call of Duty: Modern Warfare 3
# 10                      29.85               New Super Mario Bros.
# 11                      29.59          Call of Duty: Black Ops II
# 12                      28.92                            Wii Play
# 13                      28.80                Call of Duty: Ghosts
# 14                      28.51           New Super Mario Bros. Wii
# 15                      28.31                           Duck Hunt
# 16                      26.72           Call of Duty: Black Ops 3
# 17                      25.02      Call of Duty: Modern Warfare 2
# 18                      23.87       Grand Theft Auto: San Andreas
# 19                      23.26                       Mario Kart DS
# 20                      23.10       Pokémon Gold / Silver Version
# 21                      22.53                 Grand Theft Auto IV
# 22                      21.78      Call of Duty: Advanced Warfare
# 23                      20.61                   Super Mario World
# 24                      20.51         The Elder Scrolls V: Skyrim
#
#                                      Platforms  \
# 0                                        [Wii]
# 1                   [PS3, PS4, X360, PC, XOne]
# 2                                        [NES]
# 3                                        [Wii]
# 4                                    [GB, NES]
# 5   [X360, PS4, PS3, XOne, PSV, NS, WiiU, 3DS]
# 6                                        [Wii]
# 7                                         [GB]
# 8                     [X360, PS3, PC, Wii, DS]
# 9                         [X360, PS3, PC, Wii]
# 10                                        [DS]
# 11                       [X360, PS3, PC, WiiU]
# 12                                       [Wii]
# 13            [X360, PS3, PS4, XOne, PC, WiiU]
# 14                                       [Wii]
# 15                                       [NES]
# 16                  [PS4, XOne, X360, PS3, PC]
# 17                             [X360, PS3, PC]
# 18                     [PS2, XB, PC, XBL, PS3]
# 19                                        [DS]
# 20                                        [GB]
# 21                             [X360, PS3, PC]
# 22                  [PS4, XOne, X360, PS3, PC]
# 23                                      [SNES]
# 24                         [X360, PS3, PC, NS]
#
#                                            Publishers  User_score    Year  \
# 0                                        {Nintendo  }         NaN  2006.0
# 1                                  {Rockstar Games  }         9.0  2013.0
# 2                                        {Nintendo  }         8.2  1985.0
# 3                                        {Nintendo  }         9.1  2008.0
# 4                                        {Nintendo  }         NaN  1989.0
# 5   {Sony Computer Entertainment America  , Micros...         NaN  2013.0
# 6                                        {Nintendo  }         8.8  2009.0
# 7                                        {Nintendo  }         NaN  1998.0
# 8                                      {Activision  }         NaN  2010.0
# 9                                      {Activision  }         NaN  2011.0
# 10                                       {Nintendo  }         8.1  2006.0
# 11                                     {Activision  }         NaN  2012.0
# 12                                       {Nintendo  }         4.5  2007.0
# 13                                     {Activision  }         NaN  2013.0
# 14                                       {Nintendo  }         9.2  2009.0
# 15                                       {Nintendo  }         NaN  1985.0
# 16                                     {Activision  }         NaN  2015.0
# 17                                     {Activision  }         9.0  2009.0
# 18                                 {Rockstar Games  }         NaN  2004.0
# 19                                       {Nintendo  }         9.4  2005.0
# 20                                       {Nintendo  }         NaN  2000.0
# 21                                 {Rockstar Games  }         9.0  2008.0
# 22                                     {Activision  }         NaN  2014.0
# 23                                       {Nintendo  }         NaN  1991.0
# 24                             {Bethesda Softworks  }         9.1  2011.0
#
#                                    _id               Norm_name_vgchartz  \
# 0                           Wii Sports                       wii sports
# 1                   Grand Theft Auto V               grand theft auto v
# 2                    Super Mario Bros.                super mario bros.
# 3                       Mario Kart Wii                   mario kart wii
# 4                               Tetris                           tetris
# 5                            Minecraft                        minecraft
# 6                    Wii Sports Resort                wii sports resort
# 7   Pokémon Red / Green / Blue Version                 pokémon red/blue
# 8              Call of Duty: Black Ops           call of duty black ops
# 9       Call of Duty: Modern Warfare 3  call of duty modern warfare iii
# 10               New Super Mario Bros.            new super mario bros.
# 11          Call of Duty: Black Ops II        call of duty black ops ii
# 12                            Wii Play                         wii play
# 13                Call of Duty: Ghosts              call of duty ghosts
# 14           New Super Mario Bros. Wii        new super mario bros. wii
# 15                           Duck Hunt                        duck hunt
# 16           Call of Duty: Black Ops 3       call of duty black ops iii
# 17      Call of Duty: Modern Warfare 2                modern warfare ii
# 18       Grand Theft Auto: San Andreas     grand theft auto san andreas
# 19                       Mario Kart DS                    mario kart ds
# 20       Pokémon Gold / Silver Version              pokémon gold/silver
# 21                 Grand Theft Auto IV              grand theft auto iv
# 22      Call of Duty: Advanced Warfare    call of duty advanced warfare
# 23                   Super Mario World                super mario world
# 24         The Elder Scrolls V: Skyrim       the elder scrolls v skyrim
#
#       avgViewers                            name  \
# 0       4.881188                      Wii Sports
# 1   94222.248958              Grand Theft Auto V
# 2      49.296454               Super Mario Bros.
# 3      93.326776                  Mario Kart Wii
# 4      50.957424                          Tetris
# 5   12378.073958                       Minecraft
# 6       1.351852               Wii Sports Resort
# 7      31.339560                Pokémon Red/Blue
# 8     394.394931         Call of Duty: Black Ops
# 9      29.654709  Call of Duty: Modern Warfare 3
# 10     16.794595           New Super Mario Bros.
# 11    630.080851      Call of Duty: Black Ops II
# 12      0.833333                        Wii Play
# 13     20.071879            Call of Duty: Ghosts
# 14     10.728448       New Super Mario Bros. Wii
# 15      1.000000                       Duck Hunt
# 16    244.281381     Call of Duty: Black Ops III
# 17    165.033684                Modern Warfare 2
# 18    434.606092   Grand Theft Auto: San Andreas
# 19      0.909091                   Mario Kart DS
# 20     30.186462             Pokémon Gold/Silver
# 21     25.548611             Grand Theft Auto IV
# 22      9.041176  Call of Duty: Advanced Warfare
# 23   1263.823591               Super Mario World
# 24   3966.290928     The Elder Scrolls V: Skyrim
#
#                           norm_name  twitch_id  \
# 0                        wii sports    12232.0
# 1                grand theft auto v    32982.0
# 2                 super mario bros.   509508.0
# 3                    mario kart wii    18871.0
# 4                            tetris     1736.0
# 5                         minecraft    27471.0
# 6                 wii sports resort    19259.0
# 7                  pokémon red/blue     3623.0
# 8            call of duty black ops    23894.0
# 9   call of duty modern warfare iii    31551.0
# 10            new super mario bros.     7534.0
# 11        call of duty black ops ii    34134.0
# 12                         wii play     8660.0
# 13              call of duty ghosts   118200.0
# 14        new super mario bros. wii    24238.0
# 15                        duck hunt     2530.0
# 16       call of duty black ops iii   489401.0
# 17                modern warfare ii    22393.0
# 18     grand theft auto san andreas     6521.0
# 19                    mario kart ds     5993.0
# 20              pokémon gold/silver     7528.0
# 21              grand theft auto iv    18707.0
# 22    call of duty advanced warfare   417973.0
# 23                super mario world     1229.0
# 24       the elder scrolls v skyrim    30028.0
#
#                          unary_name
# 0                        wii sports
# 1                grand theft auto v
# 2                 super mario bros.
# 3                    mario kart wii
# 4                            tetris
# 5                         minecraft
# 6                 wii sports resort
# 7                  pokémon red/blue
# 8            call of duty black ops
# 9   call of duty modern warfare iii
# 10            new super mario bros.
# 11        call of duty black ops ii
# 12                         wii play
# 13              call of duty ghosts
# 14        new super mario bros. wii
# 15                        duck hunt
# 16       call of duty black ops iii
# 17                modern warfare ii
# 18     grand theft auto san andreas
# 19                    mario kart ds
# 20              pokémon gold/silver
# 21              grand theft auto iv
# 22    call of duty advanced warfare
# 23                super mario world
# 24       the elder scrolls v skyrim

# %% [markdown]
# # Select top 25 games from Twitch

# %% [markdown]
# Extract the name from "top_25_vgchartz" and store them in the final list

# %%
top_50_games = set(top_25_vgchartz['name'])
len(top_50_games)
# Out:
# 25

# %% [markdown]
# Keep adding games from the twitch DF, ordered by avgViewers, until 50 games are stored

# %%
top_twitch_df.head()
# Out:
#       avgViewers                name           norm_name  twitch_id  \
# 0  126368.478125            Fortnite            fortnite      33214
# 1  117746.633333   League of Legends   league of legends      21779
# 2   94222.248958  Grand Theft Auto V  grand theft auto v      32982
# 3   79284.045833       Just Chatting       just chatting     509658
# 4   68005.006250              Dota 2             dota ii      29595
#
#            unary_name
# 0            fortnite
# 1   league of legends
# 2  grand theft auto v
# 3       just chatting
# 4             dota ii

# %%
index = 0
while len(top_50_games) < 50:
    game = top_twitch_df.loc[index]
    top_50_games.add(game['name'])
    index += 1

# %%
top_50_games
# Out:
# {'Apex Legends',
#  'Auto Chess',
#  'Bio Inc. Redemption',
#  'Call of Duty: Advanced Warfare',
#  'Call of Duty: Black Ops',
#  'Call of Duty: Black Ops 4',
#  'Call of Duty: Black Ops II',
#  'Call of Duty: Black Ops III',
#  'Call of Duty: Ghosts',
#  'Call of Duty: Modern Warfare 3',
#  'Clam Man',
#  'Counter-Strike: Global Offensive',
#  'Dead by Daylight',
#  'Death Stranding',
#  'Dota 2',
#  'Duck Hunt',
#  'FIFA 19',
#  'Fortnite',
#  'Grand Theft Auto IV',
#  'Grand Theft Auto V',
#  'Grand Theft Auto: San Andreas',
#  'Hearthstone',
#  'Just Chatting',
#  'Layers of Fear 2',
#  'League of Legends',
#  'Magic: The Gathering',
#  'Mario Kart DS',
#  'Mario Kart Wii',
#  'Minecraft',
#  'Modern Warfare 2',
#  'Music & Performing Arts',
#  'New Super Mario Bros.',
#  'New Super Mario Bros. Wii',
#  'Overwatch',
#  "PLAYERUNKNOWN'S BATTLEGROUNDS",
#  'Pokémon Gold/Silver',
#  'Pokémon Red/Blue',
#  'Slots',
#  'Splitgate: Arena Warfare',
#  'Super Mario Bros.',
#  'Super Mario World',
#  'Talk Shows & Podcasts',
#  'Tetris',
#  'The Elder Scrolls V: Skyrim',
#  "Tom Clancy's Rainbow Six: Siege",
#  'Total War: Three Kingdoms',
#  'Wii Play',
#  'Wii Sports',
#  'Wii Sports Resort',
#  'World of Warcraft'}

# %%
len(top_50_games)
# Out:
# 50

# %% [markdown]
# #  Same games selection, with norm_name

# %% [markdown]
# Extract the normalized name from "top_25_vgchartz" and store them in the final JSON Files. This is done because it will be easier to collect data because of the lack of punctuation characters

# %%
top_50_games_n = set(top_25_vgchartz['norm_name'])
len(top_50_games_n)
# Out:
# 25

# %% [markdown]
# Keep adding games from the twitch DF, ordered by avgViewers, until 50 games are stored

# %%
top_twitch_df.head()
# Out:
#       avgViewers                name           norm_name  twitch_id  \
# 0  126368.478125            Fortnite            fortnite      33214
# 1  117746.633333   League of Legends   league of legends      21779
# 2   94222.248958  Grand Theft Auto V  grand theft auto v      32982
# 3   79284.045833       Just Chatting       just chatting     509658
# 4   68005.006250              Dota 2             dota ii      29595
#
#            unary_name
# 0            fortnite
# 1   league of legends
# 2  grand theft auto v
# 3       just chatting
# 4             dota ii

# %%
index = 0
while len(top_50_games_n) < 50:
    game = top_twitch_df.loc[index]
    top_50_games_n.add(game['norm_name'])
    index += 1

# %%
top_50_games_n
# Out:
# {'apex legends',
#  'auto chess',
#  'bio inc. redemption',
#  'call of duty advanced warfare',
#  'call of duty black ops',
#  'call of duty black ops ii',
#  'call of duty black ops iii',
#  'call of duty black ops iv',
#  'call of duty ghosts',
#  'call of duty modern warfare iii',
#  'clam man',
#  'counter-strike global offensive',
#  'dead by daylight',
#  'death stranding',
#  'dota ii',
#  'duck hunt',
#  'fifa xix',
#  'fortnite',
#  'grand theft auto iv',
#  'grand theft auto san andreas',
#  'grand theft auto v',
#  'hearthstone',
#  'just chatting',
#  'layers of fear ii',
#  'league of legends',
#  'magic the gathering',
#  'mario kart ds',
#  'mario kart wii',
#  'minecraft',
#  'modern warfare ii',
#  'music & performing arts',
#  'new super mario bros.',
#  'new super mario bros. wii',
#  'overwatch',
#  "playerunknown's battlegrounds",
#  'pokémon gold/silver',
#  'pokémon red/blue',
#  'slots',
#  'splitgate arena warfare',
#  'super mario bros.',
#  'super mario world',
#  'talk shows & podcasts',
#  'tetris',
#  'the elder scrolls v skyrim',
#  "tom clancy's rainbow six siege",
#  'total war three kingdoms',
#  'wii play',
#  'wii sports',
#  'wii sports resort',
#  'world of warcraft'}

# %%
len(top_50_games_n)
# Out:
# 50

# %% [markdown]
# ## Let's store the list as a JSON file

# %%
import json

# %%
top50_json = {
                "selected_top_50_games": {
                    "name": list(top_50_games), 
                    "norm_name": list(top_50_games_n)
                 }
             }

# %%
with open("../top_50_games_to_monitor.json", "w") as filehandler:
    json.dump(top50_json, filehandler)

# %% [markdown]
# # Adding Norm_name to vgsales dataset

# %%
vgchartz_odf = pd.read_csv('../dataset/vgsales.csv')

# %%
vgchartz_odf.head()
# Out:
#    Rank                           Name Platform    Year  \
# 0     1                     Wii Sports      Wii  2006.0
# 1     2              Super Mario Bros.      NES  1985.0
# 2     3                 Mario Kart Wii      Wii  2008.0
# 3     4  PLAYERUNKNOWN'S BATTLEGROUNDS       PC  2017.0
# 4     5              Wii Sports Resort      Wii  2009.0
#
#                                           href_Genre           Publisher  \
# 0  http://www.vgchartz.com/game/2667/wii-sports/?...          Nintendo
# 1  http://www.vgchartz.com/game/6455/super-mario-...          Nintendo
# 2  http://www.vgchartz.com/game/6968/mario-kart-w...          Nintendo
# 3  http://www.vgchartz.com/game/215988/playerunkn...  PUBG Corporation
# 4  http://www.vgchartz.com/game/24656/wii-sports-...          Nintendo
#
#             Developer  Critic_Score  User_Score  NA_Sales  PAL_Sales  \
# 0      Nintendo EAD             7.7         NaN     41.36      29.02
# 1      Nintendo EAD            10.0         8.2     29.08       3.58
# 2      Nintendo EAD             8.2         9.1     15.91      12.92
# 3  PUBG Corporation             NaN         NaN       NaN        NaN
# 4      Nintendo EAD             8.0         8.8     15.61      10.99
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.51         82.65
# 1      6.81         0.77         40.24
# 2      3.80         3.35         35.98
# 3       NaN          NaN           NaN
# 4      3.29         3.02         32.90

# %%
vgchartz_odf['Norm_name'] = vgchartz_odf['Name'].apply(uniformer.uniform)

# %%
vgchartz_odf.head()
# Out:
#    Rank                           Name Platform    Year  \
# 0     1                     Wii Sports      Wii  2006.0
# 1     2              Super Mario Bros.      NES  1985.0
# 2     3                 Mario Kart Wii      Wii  2008.0
# 3     4  PLAYERUNKNOWN'S BATTLEGROUNDS       PC  2017.0
# 4     5              Wii Sports Resort      Wii  2009.0
#
#                                           href_Genre           Publisher  \
# 0  http://www.vgchartz.com/game/2667/wii-sports/?...          Nintendo
# 1  http://www.vgchartz.com/game/6455/super-mario-...          Nintendo
# 2  http://www.vgchartz.com/game/6968/mario-kart-w...          Nintendo
# 3  http://www.vgchartz.com/game/215988/playerunkn...  PUBG Corporation
# 4  http://www.vgchartz.com/game/24656/wii-sports-...          Nintendo
#
#             Developer  Critic_Score  User_Score  NA_Sales  PAL_Sales  \
# 0      Nintendo EAD             7.7         NaN     41.36      29.02
# 1      Nintendo EAD            10.0         8.2     29.08       3.58
# 2      Nintendo EAD             8.2         9.1     15.91      12.92
# 3  PUBG Corporation             NaN         NaN       NaN        NaN
# 4      Nintendo EAD             8.0         8.8     15.61      10.99
#
#    JP_Sales  Other_Sales  Global_Sales                      Norm_name
# 0      3.77         8.51         82.65                     wii sports
# 1      6.81         0.77         40.24              super mario bros.
# 2      3.80         3.35         35.98                 mario kart wii
# 3       NaN          NaN           NaN  playerunknown's battlegrounds
# 4      3.29         3.02         32.90              wii sports resort

# %%
for i in vgchartz_odf.index:
    n = vgchartz_odf.loc[i]['Name']
    m = vgchartz_df[vgchartz_df['Name'] == n]['Norm_name_vgchartz'].values
    if len(m) > 0:
        #print(i, n, vgchartz_df[vgchartz_df['Name'] == n]['Norm_name_vgchartz'].values[0])
        vgchartz_odf.at[i, 'Norm_name'] = m[0]

# %%
vgchartz_odf.head()
# Out:
#    Rank                           Name Platform    Year  \
# 0     1                     Wii Sports      Wii  2006.0
# 1     2              Super Mario Bros.      NES  1985.0
# 2     3                 Mario Kart Wii      Wii  2008.0
# 3     4  PLAYERUNKNOWN'S BATTLEGROUNDS       PC  2017.0
# 4     5              Wii Sports Resort      Wii  2009.0
#
#                                           href_Genre           Publisher  \
# 0  http://www.vgchartz.com/game/2667/wii-sports/?...          Nintendo
# 1  http://www.vgchartz.com/game/6455/super-mario-...          Nintendo
# 2  http://www.vgchartz.com/game/6968/mario-kart-w...          Nintendo
# 3  http://www.vgchartz.com/game/215988/playerunkn...  PUBG Corporation
# 4  http://www.vgchartz.com/game/24656/wii-sports-...          Nintendo
#
#             Developer  Critic_Score  User_Score  NA_Sales  PAL_Sales  \
# 0      Nintendo EAD             7.7         NaN     41.36      29.02
# 1      Nintendo EAD            10.0         8.2     29.08       3.58
# 2      Nintendo EAD             8.2         9.1     15.91      12.92
# 3  PUBG Corporation             NaN         NaN       NaN        NaN
# 4      Nintendo EAD             8.0         8.8     15.61      10.99
#
#    JP_Sales  Other_Sales  Global_Sales                      Norm_name
# 0      3.77         8.51         82.65                     wii sports
# 1      6.81         0.77         40.24              super mario bros.
# 2      3.80         3.35         35.98                 mario kart wii
# 3       NaN          NaN           NaN  playerunknown's battlegrounds
# 4      3.29         3.02         32.90              wii sports resort

# %%
vgchartz_odf[vgchartz_odf['Norm_name'].str.contains('pokémon red')]
# Out:
#    Rank                                Name Platform    Year  \
# 5     6  Pokémon Red / Green / Blue Version       GB  1998.0
#
#                                           href_Genre   Publisher  \
# 5  http://www.vgchartz.com/game/4030/pokemon-red-...  Nintendo
#
#       Developer  Critic_Score  User_Score  NA_Sales  PAL_Sales  JP_Sales  \
# 5  Game Freak             9.4         NaN     11.27       8.89     10.22
#
#    Other_Sales  Global_Sales         Norm_name
# 5          1.0         31.37  pokémon red/blue

# %%
vgchartz_odf.to_csv('../dataset/vgsales_n.csv')
