# %%
import datetime
import json
import requests
import time
import pandas as pd

# %%
keys = json.loads(open("keys.json").read())

# %% [markdown]
# # Twitch

# %%
twitch_client_ID = keys['Twitch']['Client-ID']

# %%
header = {'Client-ID': twitch_client_ID}

# %% [markdown]
# ## Previous Functions

# %%
def print_response(response, start = 0):
    '''
    prints the response in a more readable way.
    'start' specifies the first number of the list
    '''
    for i in range(len(response.json()['data'])):
        print('{:2d} {:6s} :  {}'.format(i + 1 + start, 
                                      response.json()['data'][i]['id'],
                                      response.json()['data'][i]['name']))

# %%
def print_games_list(l):
    '''
    l must be a list of games dicts, with keys "name" and "id".
    the function prints l.
    '''
    for i in range(len(l)):
            print('{:2d} {:6s} :  {}'.format(i + 1, l[i]['id'], l[i]['name']))

# %%
def res_pag(response):
    '''
    returns pagination cursor of a response
    '''
    return response.json()['pagination']['cursor']

# %%
# old version with less control on numer of games

def get_n_top_games_OLD(n, header):
    '''
    returns the ordered list of top games (dicts), with length between n and (n + 99)
    headers is the header of the request (specifying the Client-ID)
    '''
    responses = [] # list of games
    
    res = requests.get('https://api.twitch.tv/helix/games/top?first=100', headers=header)
    responses.extend(res.json()['data'])
           
    while len(responses) < n:
        res = requests.get('https://api.twitch.tv/helix/games/top?after={}&first=100'.format(res_pag(res)), headers=header)
        responses.extend(res.json()['data'])
    
    return responses

# %%
# I wrote the try - except thing in case errors occur (e.g. 'too many requests'), in which case 
# 'res.json()['data'] does not exist

def get_views(game_id, n = 100):
    '''
    returns total number of view for game which id is game_id, for the top n <= 100 streams
    '''
    res = requests.get('https://api.twitch.tv/helix/streams?game_id={}&first={}'.format(game_id, n), headers=header)
    try:
        df = pd.DataFrame(res.json()['data'])
        s = sum(df['viewer_count'])
        #s = sum([res.json()['data'][i]['viewer_count'] for i in range(len(res.json()['data']))])
    except: 
        s = res.json()
    return s, res

# %%
# newer version, possibly we could make it better by making it wait if we surpass the 30 requests per minute limit
# for some reason if n <= 15 it returns one more game

def get_n_top_games(n, header, exactly_n = False):
    '''
    returns the ordered list of top n-1 games (dicts)
    headers is the header of the request (specifying the Client-ID)
    if exactly_n == True, the function returns the list of top n games
        by default this is false as it performs one additional request just to get a single game
    '''
    responses = [] # list of games
    
    m = n // 100
    q = n % 100
        
    if m == 0:
        # if n is less than or equal to 100, just gets the first n games
        res = requests.get(
            'https://api.twitch.tv/helix/games/top?first={}'.format(n),
            headers=header)
        responses.extend(res.json()['data'])
    else:
        # get the first 99 games:
        res = requests.get(
            'https://api.twitch.tv/helix/games/top?first=100',
            headers=header)
        responses.extend(res.json()['data']) 

        # loop to get the remaining (m-1)*100 games
        m -= 1
        while m > 0:
            res = requests.get(
                'https://api.twitch.tv/helix/games/top?after={}&first=100'.format(res_pag(res)),
                headers=header)
            responses.extend(res.json()['data'])
            m -= 1

        # now m = 0, we get the last q games if q > 0
        if q > 0:
            res = requests.get(
                'https://api.twitch.tv/helix/games/top?after={}&first={}'.format(res_pag(res), q),
                headers=header)
            responses.extend(res.json()['data'])

    if exactly_n:
        # get the last game
        res = requests.get(
            'https://api.twitch.tv/helix/games/top?after={}&first={}'.format(res_pag(res), 1),
            headers=header)
        responses.extend(res.json()['data'])
    
    return responses

# %%
# I wrote the try - except thing in case errors occur (e.g. 'too many requests'), in which case 
# 'res.json()['data'] does not exist

def get_views(game_id, n = 100):
    '''
    returns total number of view for game which id is game_id, for the top n <= 100 streams
    '''
    res = requests.get('https://api.twitch.tv/helix/streams?game_id={}&first={}'.format(game_id, n), headers=header)
    try:
        df = pd.DataFrame(res.json()['data'])
        s = sum(df['viewer_count'])
        #s = sum([res.json()['data'][i]['viewer_count'] for i in range(len(res.json()['data']))])
    except: 
        s = res.json()
    return s, res

# %%
# If we make too many requests (the limit is 30 per minute), the function waits a minute

def integrate_view_count(game_list, print_progress = False):
    '''
    integrates the list outputted by the function get_n_top_games() with the number of views for each game
    if print_progress = True it prints the progress
    '''
    len_game_list = len(game_list)
    for i in range(len_game_list):
        res = get_views(game_list[i]['id'], 100)
        game_list[i]['view_count'] = res[0]
        
        games_left = len_game_list - i - 1
        limit = int(res[1].headers['Ratelimit-Remaining'])
        if print_progress: print('Games left: {}\tPoints left: {}'.format(games_left, limit))
        
        if (limit == 0) and (games_left != 0):
            if print_progress: print('Processed {} games.\nHave to wait a minute...'.format(i+1))
            for j in range(60):
                if print_progress: print(60 - j)
                time.sleep(1)

# %% [markdown]
# ## Get all games (new APIs)

# %%
def get_all_top_games(header, print_progress = False):
    '''
    returns list of all games streamed on twitch, sorted by viewers
    if print_progress = True it prints the progress
    '''
    responses = [] # list of games
    
    # first request 
    res = requests.get(
            'https://api.twitch.tv/helix/games/top?first=100',
            headers=header)
    responses.extend(res.json()['data']) 
    
    games_processed = len(res.json()['data'])
    
    # ask for games until there are no games left
    while len(res.json()['data']) > 0:
        res = requests.get(
                'https://api.twitch.tv/helix/games/top?after={}&first=100'
            .format(res_pag(res)),
                headers=header)
        responses.extend(res.json()['data'])
        
        games_processed += len(res.json()['data'])
        limit = int(res.headers['Ratelimit-Remaining'])
        
        if print_progress:
            print('games_processed: {}, remaining points = {}'.format(games_processed, limit))
             
        if limit == 0:
            if print_progress: print('Have to wait a minute...')
            for j in range(60):
                if print_progress: print(60 - j)
                time.sleep(1)
    
    if print_progress: print('Done!')
    return responses

# %%
all_top_games = get_all_top_games(header, print_progress = True)
# Out:
# games_processed: 199, remaining points = 28
# games_processed: 299, remaining points = 27
# games_processed: 399, remaining points = 26
# games_processed: 499, remaining points = 25
# games_processed: 599, remaining points = 24
# games_processed: 699, remaining points = 23
# games_processed: 799, remaining points = 22
# games_processed: 899, remaining points = 22
# games_processed: 999, remaining points = 21
# games_processed: 1099, remaining points = 20
# games_processed: 1199, remaining points = 19
# games_processed: 1299, remaining points = 18
# games_processed: 1399, remaining points = 17
# games_processed: 1499, remaining points = 16
# games_processed: 1599, remaining points = 16
# games_processed: 1699, remaining points = 15
# games_processed: 1797, remaining points = 14
# games_processed: 1842, remaining points = 13
# games_processed: 1842, remaining points = 12
# Done!

# %%
atgdf = pd.DataFrame(all_top_games)

# %%
pd.options.display.max_colwidth = 120 # to display the complete box_art_url column

# %%
atgdf.head()
# Out:
#                                                                                box_art_url  \
# 0       https://static-cdn.jtvnw.net/ttv-boxart/League%20of%20Legends-{width}x{height}.jpg
# 1                    https://static-cdn.jtvnw.net/ttv-boxart/Dota%202-{width}x{height}.jpg
# 2                    https://static-cdn.jtvnw.net/ttv-boxart/Fortnite-{width}x{height}.jpg
# 3  https://static-cdn.jtvnw.net/ttv-boxart/TrackMania%C2%B2%20Stadium-{width}x{height}.jpg
# 4             https://static-cdn.jtvnw.net/ttv-boxart/Just%20Chatting-{width}x{height}.jpg
#
#        id                 name
# 0   21779    League of Legends
# 1   29595               Dota 2
# 2   33214             Fortnite
# 3   79231  TrackMania² Stadium
# 4  509658        Just Chatting

# %%
atgdf.index += 1 # to make index = order of games by views

# %%
atgdf.head()
# Out:
#                                                                                box_art_url  \
# 1       https://static-cdn.jtvnw.net/ttv-boxart/League%20of%20Legends-{width}x{height}.jpg
# 2                    https://static-cdn.jtvnw.net/ttv-boxart/Dota%202-{width}x{height}.jpg
# 3                    https://static-cdn.jtvnw.net/ttv-boxart/Fortnite-{width}x{height}.jpg
# 4  https://static-cdn.jtvnw.net/ttv-boxart/TrackMania%C2%B2%20Stadium-{width}x{height}.jpg
# 5             https://static-cdn.jtvnw.net/ttv-boxart/Just%20Chatting-{width}x{height}.jpg
#
#        id                 name
# 1   21779    League of Legends
# 2   29595               Dota 2
# 3   33214             Fortnite
# 4   79231  TrackMania² Stadium
# 5  509658        Just Chatting

# %% [markdown]
# In case we ever need the box art for the games (maybe for some part of visualization?), we get the full url with the following (width and height are the ones used by twitch)

# %%
atgdf['box_art_url'] = atgdf['box_art_url'].apply(lambda x : x.format(width = 285, height = 380))

# %%
atgdf.head()
# Out:
#                                                                       box_art_url  \
# 1       https://static-cdn.jtvnw.net/ttv-boxart/League%20of%20Legends-285x380.jpg
# 2                    https://static-cdn.jtvnw.net/ttv-boxart/Dota%202-285x380.jpg
# 3                    https://static-cdn.jtvnw.net/ttv-boxart/Fortnite-285x380.jpg
# 4  https://static-cdn.jtvnw.net/ttv-boxart/TrackMania%C2%B2%20Stadium-285x380.jpg
# 5             https://static-cdn.jtvnw.net/ttv-boxart/Just%20Chatting-285x380.jpg
#
#        id                 name
# 1   21779    League of Legends
# 2   29595               Dota 2
# 3   33214             Fortnite
# 4   79231  TrackMania² Stadium
# 5  509658        Just Chatting

# %% [markdown]
# Looking for duplicate rows

# %%
atgdf.sort_values('name', inplace = True) # create a copy of the df, sorted by name

# %%
atgdf.head()
# Out:
#                                                                           box_art_url  \
# 1398  https://static-cdn.jtvnw.net/ttv-boxart/.hack//G.U.%20Last%20Recode-285x380.jpg
# 942            https://static-cdn.jtvnw.net/ttv-boxart/./007:%20Nightfire-285x380.jpg
# 1713           https://static-cdn.jtvnw.net/ttv-boxart/./24:%20The%20Game-285x380.jpg
# 1383              https://static-cdn.jtvnw.net/ttv-boxart/60%20Parsecs%21-285x380.jpg
# 1268              https://static-cdn.jtvnw.net/ttv-boxart/60%20Parsecs%21-285x380.jpg
#
#           id                     name
# 1398  497460  .hack//G.U. Last Recode
# 942     6081           007: Nightfire
# 1713   12580             24: The Game
# 1383  502317              60 Parsecs!
# 1268  502317              60 Parsecs!

# %%
# look for duplicates 
# (checks if two following rows have the same name:
# if so, appends the df index of the row to the first list.
# and the implicit index of the sorted df to the second list)

duplicates = list()
duplicates_implicit = list()
for i in range(len(atgdf)-1):
    if atgdf['name'].iloc[i] == atgdf['name'].iloc[i+1]:
        duplicates.append(atgdf.iloc[i].name)
        duplicates_implicit.append(i)
len(duplicates), len(duplicates_implicit)
# Out:
# (262, 262)

# %%
atgdf.loc[duplicates]
# Out:
#                                                                                                    box_art_url  \
# 1383                                       https://static-cdn.jtvnw.net/ttv-boxart/60%20Parsecs%21-285x380.jpg
# 1697                                      https://static-cdn.jtvnw.net/ttv-boxart/9-1-1%20Operator-285x380.jpg
# 1728                        https://static-cdn.jtvnw.net/ttv-boxart/A%20Story%20About%20My%20Uncle-285x380.jpg
# 1009                                              https://static-cdn.jtvnw.net/ttv-boxart/Absolver-285x380.jpg
# 1434                                                https://static-cdn.jtvnw.net/ttv-boxart/Action-285x380.jpg
# 1618                       https://static-cdn.jtvnw.net/ttv-boxart/./Age%20of%20Conan:%20Unchained-285x380.jpg
# 1422                              https://static-cdn.jtvnw.net/ttv-boxart/Age%20of%20Empires%20III-285x380.jpg
# 1296                              https://static-cdn.jtvnw.net/ttv-boxart/Age%20of%20Empires%20III-285x380.jpg
# 697                                https://static-cdn.jtvnw.net/ttv-boxart/Alone%20in%20the%20Dark-285x380.jpg
# 650                                       https://static-cdn.jtvnw.net/ttv-boxart/Ape%20Escape%203-285x380.jpg
# 1828                                              https://static-cdn.jtvnw.net/ttv-boxart/Aquarium-285x380.jpg
# 976                                                https://static-cdn.jtvnw.net/ttv-boxart/Armello-285x380.jpg
# 1280                       https://static-cdn.jtvnw.net/ttv-boxart/./Art%20of%20War:%20Red%20Tides-285x380.jpg
# 1810                                       https://static-cdn.jtvnw.net/ttv-boxart/Ashes%20Cricket-285x380.jpg
# 1748                                       https://static-cdn.jtvnw.net/ttv-boxart/Ashes%20Cricket-285x380.jpg
# 794                                        https://static-cdn.jtvnw.net/ttv-boxart/Assetto%20Corsa-285x380.jpg
# 980   https://static-cdn.jtvnw.net/ttv-boxart/./Atelier%20Meruru:%20The%20Apprentice%20of%20Arland-285x380.jpg
# 1156                                       https://static-cdn.jtvnw.net/ttv-boxart/Atlas%20Reactor-285x380.jpg
# 1480                                    https://static-cdn.jtvnw.net/ttv-boxart/Atomic%20Bomberman-285x380.jpg
# 1420                                            https://static-cdn.jtvnw.net/ttv-boxart/Automation-285x380.jpg
# 1082                                         https://static-cdn.jtvnw.net/ttv-boxart/Banjo-Kazooie-285x380.jpg
# 1299                                     https://static-cdn.jtvnw.net/ttv-boxart/Battle%20Traverse-285x380.jpg
# 1295                                https://static-cdn.jtvnw.net/ttv-boxart/Battlefield%20Hardline-285x380.jpg
# 800                                             https://static-cdn.jtvnw.net/ttv-boxart/Battlerite-285x380.jpg
# 890                                               https://static-cdn.jtvnw.net/ttv-boxart/Beholder-285x380.jpg
# 1605                  https://static-cdn.jtvnw.net/ttv-boxart/./Ys%20VIII:%20Lacrimosa%20of%20Dana-285x380.jpg
# 1254             https://static-cdn.jtvnw.net/ttv-boxart/Yu-Gi-Oh%21%20Legacy%20of%20the%20Duelist-285x380.jpg
# 1470                  https://static-cdn.jtvnw.net/ttv-boxart/Yu-Gi-Oh%21%20Nightmare%20Troubadour-285x380.jpg
# 1457  https://static-cdn.jtvnw.net/ttv-boxart/./Zone%20of%20the%20Enders:%20The%20Fist%20of%20Mars-285x380.jpg
# 1706                              https://static-cdn.jtvnw.net/ttv-boxart/else%20Heart.Break%28%29-285x380.jpg
#
#           id                                      name
# 1383  502317                               60 Parsecs!
# 1697  493317                            9-1-1 Operator
# 1728   67895                    A Story About My Uncle
# 1009  494591                                  Absolver
# 1434   25749                                    Action
# 1618    8841                   Age of Conan: Unchained
# 1422    7830                        Age of Empires III
# 1296    7830                        Age of Empires III
# 697     2846                         Alone in the Dark
# 650    17747                              Ape Escape 3
# 1828   19401                                  Aquarium
# 976    68063                                   Armello
# 1280  494851                     Art of War: Red Tides
# 1810  500181                             Ashes Cricket
# 1748  500181                             Ashes Cricket
# 794   313197                             Assetto Corsa
# 980    31012  Atelier Meruru: The Apprentice of Arland
# 1156  491479                             Atlas Reactor
# 1480     936                          Atomic Bomberman
# 1420   33581                                Automation
# 1082   10033                             Banjo-Kazooie
# 1299  507774                           Battle Traverse
# 1295  417791                      Battlefield Hardline
# 800   493277                                Battlerite
# 890   493890                                  Beholder
# 811    65950                         Beyond: Two Souls
# 1030  493135                  BioShock: The Collection
# 985   504766                       Black Desert Mobile
# 1516  510100                           Blade & Sorcery
# 1111   28251                       Bloodline Champions
# ...      ...                                       ...
# 1217  313445                                 Tropico 5
# 1667   21939                                   Tv star
# 1772   21939                                   Tv star
# 949   502918                        Two Point Hospital
# 576     1999                  Ultimate Mortal Kombat 3
# 1634    4659          Uncharted Waters 2: New Horizons
# 1195  494558                Uncharted: The Lost Legacy
# 1115  489791    Uncharted: The Nathan Drake Collection
# 337   461529                              VA-11 HALL-A
# 1746  418004                                   Vagante
# 1719   15062      Vampire: The Masquerade - Bloodlines
# 1658   15062      Vampire: The Masquerade - Bloodlines
# 1804   25173                               Victoria II
# 1623  506173                                Volcanoids
# 1638  492889                                  WWE 2K17
# 1059  497545                                  WWE 2K18
# 1519   18381            Warcraft II: Tides of Darkness
# 1492  504449                            WarioWare Gold
# 1547  504846                         Warriors Orochi 4
# 1726  505780                         Wizard's Symphony
# 1249    2712                                      XIII
# 1161   24307                      Xenoblade Chronicles
# 1381  489591                              Yooka-Laylee
# 1267  489591                              Yooka-Laylee
# 1211  505717                         Youtubers Clicker
# 1605  476439                Ys VIII: Lacrimosa of Dana
# 1254  489794           Yu-Gi-Oh! Legacy of the Duelist
# 1470   19943            Yu-Gi-Oh! Nightmare Troubadour
# 1457   17881      Zone of the Enders: The Fist of Mars
# 1706  490856                        else Heart.Break()
#
# [262 rows x 3 columns]

# %%
atgdf.sort_index(inplace = True) # go back to order by views

# %%
atgdf.head()
# Out:
#                                                                       box_art_url  \
# 1       https://static-cdn.jtvnw.net/ttv-boxart/League%20of%20Legends-285x380.jpg
# 2                    https://static-cdn.jtvnw.net/ttv-boxart/Dota%202-285x380.jpg
# 3                    https://static-cdn.jtvnw.net/ttv-boxart/Fortnite-285x380.jpg
# 4  https://static-cdn.jtvnw.net/ttv-boxart/TrackMania%C2%B2%20Stadium-285x380.jpg
# 5             https://static-cdn.jtvnw.net/ttv-boxart/Just%20Chatting-285x380.jpg
#
#        id                 name
# 1   21779    League of Legends
# 2   29595               Dota 2
# 3   33214             Fortnite
# 4   79231  TrackMania² Stadium
# 5  509658        Just Chatting

# %% [markdown]
# ## Get all games (API v5)

# %%
header_v5 = {
    'Accept': 'application/vnd.twitchtv.v5+json',
    'Client-ID': twitch_client_ID,
}

# %%
def print_games_list_v5(l):
    '''
    l must be a list of games dicts, with keys "name" and "id".
    the function prints l.
    '''
    for i in range(len(l)):
            print('{:2d} {:6d} :  {:40s} {} '.format(i + 1, l[i]['game']['_id'], l[i]['game']['name'], l[i]['viewers']))

# %%
def get_all_top_games_v5(header, print_progress = False):
    '''
    returns list of all games streamed on twitch, sorted by viewers
    if print_progress = True it prints the progress
    '''
    responses = [] # list of games
    
    # first request 
    res = requests.get('https://api.twitch.tv/kraken/games/top?limit=100', headers=header)
    responses.extend(res.json()['top'])
    
    games_processed = len(res.json()['top'])
    
    # ask for games until there are no games left
    
    # ask for games until there are no games left (in which case, the twitch api returns an error)
    # essentially, it loops requests until twitch returns an error, in which case the loops breaks
    # not the best solution, but I do not know if there is a better way to do this
    while True:
        try:
            res = requests.get('https://api.twitch.tv/kraken/games/top?limit=100&offset={}'.format(len(responses)), headers=header)
            responses.extend(res.json()['top'])
            
            games_processed += len(res.json()['top'])
        
            if print_progress:
                print('games_processed: {}'.format(games_processed)) 
            
        except Exception:
            if print_progress: print('Done!')
            break
            
    return responses

# %%
v5_all = get_all_top_games_v5(header_v5, print_progress = True)
# Out:
# games_processed: 199
# games_processed: 299
# games_processed: 399
# games_processed: 499
# games_processed: 599
# games_processed: 699
# games_processed: 799
# games_processed: 899
# games_processed: 999
# games_processed: 1099
# games_processed: 1199
# games_processed: 1299
# games_processed: 1399
# games_processed: 1498
# games_processed: 1597
# games_processed: 1696
# games_processed: 1795
# games_processed: 1834
# games_processed: 1845
# games_processed: 1846
# Done!

# %%
v5_all_df = pd.DataFrame(v5_all)

# %%
v5_all_df.head()
# Out:
#    channels  \
# 0      2244
# 1       857
# 2      8743
# 3        27
# 4      1099
#
#                                                                                                                       game  \
# 0  {'name': 'League of Legends', 'popularity': 451586, '_id': 21779, 'giantbomb_id': 24024, 'box': {'large': 'https://s...
# 1  {'name': 'Dota 2', 'popularity': 188746, '_id': 29595, 'giantbomb_id': 32887, 'box': {'large': 'https://static-cdn.j...
# 2  {'name': 'Fortnite', 'popularity': 88708, '_id': 33214, 'giantbomb_id': 37030, 'box': {'large': 'https://static-cdn....
# 3  {'name': 'TrackMania² Stadium', 'popularity': 49055, '_id': 79231, 'giantbomb_id': 40347, 'box': {'large': 'https://...
# 4  {'name': 'Just Chatting', 'popularity': 62125, '_id': 509658, 'giantbomb_id': 0, 'box': {'large': 'https://static-cd...
#
#    viewers
# 0   384312
# 1   213073
# 2    93392
# 3    84775
# 4    76581

# %%
from pandas.io.json import json_normalize

# %%
# to unnest the game info

v5_all_df = json_normalize(data=v5_all)
v5_all_df.index += 1
v5_all_df = v5_all_df[['game._id', 'game.name', 'game.localized_name', 'channels', 'viewers', 'game.popularity', 'game.box.large', 'game.logo.large']]

# %%
v5_all_df.head()
# Out:
#    game._id            game.name  game.localized_name  channels  viewers  \
# 1     21779    League of Legends    League of Legends      2244   384312
# 2     29595               Dota 2               Dota 2       857   213073
# 3     33214             Fortnite             Fortnite      8743    93392
# 4     79231  TrackMania² Stadium  TrackMania² Stadium        27    84775
# 5    509658        Just Chatting        Just Chatting      1099    76581
#
#    game.popularity  \
# 1           451586
# 2           188746
# 3            88708
# 4            49055
# 5            62125
#
#                                                                    game.box.large  \
# 1       https://static-cdn.jtvnw.net/ttv-boxart/League%20of%20Legends-272x380.jpg
# 2                    https://static-cdn.jtvnw.net/ttv-boxart/Dota%202-272x380.jpg
# 3                    https://static-cdn.jtvnw.net/ttv-boxart/Fortnite-272x380.jpg
# 4  https://static-cdn.jtvnw.net/ttv-boxart/TrackMania%C2%B2%20Stadium-272x380.jpg
# 5             https://static-cdn.jtvnw.net/ttv-boxart/Just%20Chatting-272x380.jpg
#
#                                                                    game.logo.large
# 1       https://static-cdn.jtvnw.net/ttv-logoart/League%20of%20Legends-240x144.jpg
# 2                    https://static-cdn.jtvnw.net/ttv-logoart/Dota%202-240x144.jpg
# 3                    https://static-cdn.jtvnw.net/ttv-logoart/Fortnite-240x144.jpg
# 4  https://static-cdn.jtvnw.net/ttv-logoart/TrackMania%C2%B2%20Stadium-240x144.jpg
# 5             https://static-cdn.jtvnw.net/ttv-logoart/Just%20Chatting-240x144.jpg

# %% [markdown]
# Looking for duplicates again

# %%
v5_all_df.sort_values('game.name', inplace=True)

# %%
v5_all_df.head()
# Out:
#       game._id                 game.name       game.localized_name  channels  \
# 1366    497460   .hack//G.U. Last Recode   .hack//G.U. Last Recode         1
# 1355     11045  .hack//MUTATION - Part 2  .hack//MUTATION - Part 2         1
# 1417     11045  .hack//MUTATION - Part 2  .hack//MUTATION - Part 2         1
# 925       6081            007: Nightfire            007: Nightfire         1
# 1215    502317               60 Parsecs!               60 Parsecs!         1
#
#       viewers  game.popularity  \
# 1366        2                2
# 1355        2                2
# 1417        2                1
# 925         6                7
# 1215        3                1
#
#                                                                           game.box.large  \
# 1366     https://static-cdn.jtvnw.net/ttv-boxart/.hack//G.U.%20Last%20Recode-272x380.jpg
# 1355  https://static-cdn.jtvnw.net/ttv-boxart/.hack//MUTATION%20-%20Part%202-272x380.jpg
# 1417  https://static-cdn.jtvnw.net/ttv-boxart/.hack//MUTATION%20-%20Part%202-272x380.jpg
# 925               https://static-cdn.jtvnw.net/ttv-boxart/./007:%20Nightfire-272x380.jpg
# 1215                 https://static-cdn.jtvnw.net/ttv-boxart/60%20Parsecs%21-272x380.jpg
#
#                                                                           game.logo.large
# 1366     https://static-cdn.jtvnw.net/ttv-logoart/.hack//G.U.%20Last%20Recode-240x144.jpg
# 1355  https://static-cdn.jtvnw.net/ttv-logoart/.hack//MUTATION%20-%20Part%202-240x144.jpg
# 1417  https://static-cdn.jtvnw.net/ttv-logoart/.hack//MUTATION%20-%20Part%202-240x144.jpg
# 925               https://static-cdn.jtvnw.net/ttv-logoart/./007:%20Nightfire-240x144.jpg
# 1215                 https://static-cdn.jtvnw.net/ttv-logoart/60%20Parsecs%21-240x144.jpg

# %% [markdown]
# We get duplicates again.

# %%
# look for duplicates 
# (checks if two following rows have the same name: if so, appends the df index of the row to the list)

duplicates_v5 = list()
duplicates_implicit_v5 = list()

for i in range(len(v5_all_df)-1):
    if v5_all_df['game.name'].iloc[i] == v5_all_df['game.name'].iloc[i+1]:
        duplicates_implicit_v5.append(i)
        duplicates_v5.append(v5_all_df.iloc[i].name)

len(duplicates_v5), len(duplicates_implicit_v5)
# Out:
# (251, 251)

# %%
v5_all_df.loc[duplicates_v5]
# Out:
#       game._id                                 game.name  \
# 1355     11045                  .hack//MUTATION - Part 2
# 1621    458060                              A Bird Story
# 1033    494591                                  Absolver
# 1480      8841                   Age of Conan: Unchained
# 677     349609           America's Army: Proving Grounds
# 1778     14192                                      Ants
# 1102    511554                                 Arknights
# 1460     20988                   Ascension to the Throne
# 1557     20988                   Ascension to the Throne
# 1617    500181                             Ashes Cricket
# 1628    461339                   Assassin's Creed: Rogue
# 1576    509786                  Astro Bot Rescue Mission
# 1570    492234                                   Avorion
# 1646     20651                               Bard's Tale
# 1421    507774                           Battle Traverse
# 705      24394                             Battlefield 3
# 1216    417791                      Battlefield Hardline
# 985     509146                         Battlerite Royale
# 1060     18933                                 Bayonetta
# 1120    488842                                   Besiege
# 996        104                                 Blackjack
# 1201      2740                              Boulder Dash
# 1109     18934                                     Braid
# 1758     19006                Call of Duty: World at War
# 591       7778  Capcom vs. SNK 2: Mark of the Millennium
# 1715     18401                                Cave Story
# 1246    498044                 CityBattle: Virtual Earth
# 1101     16580            Command & Conquer: Red Alert 2
# 1515     18881            Command & Conquer: Red Alert 3
# 1770    497586                             Community Inc
# ...        ...                                       ...
# 199     493069         Totally Accurate Battle Simulator
# 1049    313142                          Tower of Saviors
# 699     458656                            Tree of Savior
# 1837    497462                                 Tropico 6
# 1266     31799                                 TypeRacer
# 970       5288                             Ultima Online
# 1283    500518                Ultimate Fishing Simulator
# 1774    509868                         Under Development
# 1050     16183                                    Unreal
# 1561     12189                    Unreal Tournament 2004
# 1724     25173                               Victoria II
# 1843     25173                               Victoria II
# 1014     30045                                  WarGames
# 1424    508798                                 Warhammer
# 1759    502825                          We Were Here Too
# 1487    502495                                      Weed
# 1693    502495                                      Weed
# 1708    369259                Wolfenstein: The New Order
# 1817    493927                    World of Final Fantasy
# 709      32083                        World of Warplanes
# 1478     34267                                     Wrack
# 1400      2712                                      XIII
# 1275      2712                                      XIII
# 1127     24307                      Xenoblade Chronicles
# 1213    495061                    Xenoblade Chronicles 2
# 997                                                          https://static-cdn.jtvnw.net/ttv-logoart/b-240x144.jpg
#
# [251 rows x 8 columns]

# %% [markdown]
# At least with the old apis we imediately get the viewers.

# %%
v5_all_df.sort_index(inplace = True) # go back to the order by viewers

# %%
v5_all_df
# Out:
#       game._id                                      game.name  \
# 1        21779                              League of Legends
# 2        29595                                         Dota 2
# 3        33214                                       Fortnite
# 4        79231                            TrackMania² Stadium
# 5       509658                                  Just Chatting
# 6        32982                             Grand Theft Auto V
# 7        32399               Counter-Strike: Global Offensive
# 8       493057                  PLAYERUNKNOWN'S BATTLEGROUNDS
# 9       138585                                    Hearthstone
# 10      488552                                      Overwatch
# 11      509663                                 Special Events
# 12       18122                              World of Warcraft
# 13      511224                                   Apex Legends
# 14      506103                                        FIFA 19
# 15        5831                  Mega Man Network Transmission
# 16      511748                                     Auto Chess
# 17       29307                                  Path of Exile
# 18      497456                                      Days Gone
# 19      498859                                        Mordhau
# 20      510578                               Mortal Kombat 11
# 21      497761                                           Frog
# 22       27471                                      Minecraft
# 23      491487                               Dead by Daylight
# 24      417752                          Talk Shows & Podcasts
# 25      460630                Tom Clancy's Rainbow Six: Siege
# 26        2748                           Magic: The Gathering
# 27       12924                Warcraft III: The Frozen Throne
# 28      488615                               Street Fighter V
# 29      504463                    Tom Clancy's The Division 2
# 30      509660                                            Art
# ...        ...                                            ...
# 1817    493927                         World of Final Fantasy
# 1818      6590                                         Galcon
# 1819     16440            Final Fantasy I & II: Dawn of Souls
# 1820     12453                               Grand Theft Auto
# 1821    490921                       The Jackbox Party Pack 2
# 1822    488296                                      Oculus VR
# 1823     94884                  Hotline Miami 2: Wrong Number
# 1824      3290  Dragon Quest VIII: Journey of the Cursed King
# 1825    510118                                      Deltarune
# 1826     25173                                    Victoria II
# 1827      2519                                  New York City
# 1828      6947                                       Folklore
# 1829     12004                              DmC Devil May Cry
# 1830     32178                        Octodad: Dadliest Catch
# 1831    494264                                          Resin
# 1832    496474                                    Crackdown 3
# 1833    493588                       Styx: Shards of Darkness
# 1834    495180                             Next Day: Survival
# 1835     19761        The King of Fighters '98 Ultimate Match
# 1836    505121                               Mother Simulator
# 1837    497462                                      Tropico 6
# 1838    489542      MegaTagmension Blanc + Neptune VS Zombies
# 1839    511433                                    Half Dead 2
# 1840    368936                         Batman: Arkham Origins
# 1841     12430                        The Godfather: The Game
# 1842    491228                                Country Friends
# 1843     25173                                    Victoria II
# 1844     32307                                          Saint
# 1845    493588                       Styx: Shards of Darkness
# 1846    496142                                      Pavlov VR
#
#                                 game.localized_name  channels  viewers  \
# 1                                 League of Legends      2244   384312
# 2                                            Dota 2       857   213073
# 3                                          Fortnite      8743    93392
# 4                               TrackMania² Stadium        27    84775
# 5                                     Just Chatting      1099    76581
# 6                                Grand Theft Auto V       751    72662
# 7                  Counter-Strike: Global Offensive      1123    46692
# 8                     PLAYERUNKNOWN'S BATTLEGROUNDS      1365    30651
# 9                                       Hearthstone       251    28411
# 10                                        Overwatch       880    24390
# 11                                   Special Events        37    20991
