# %%
from bson.son import SON
from pymongo import MongoClient
import re
import sys

import pandas as pd
import numpy as np

# %%
sys.path.insert(0, '../scripts')

# %%
import uniformer

# %%
client = MongoClient('localhost', 27017)

# %%
db = client.twitch_60

# %%
games_coll = db.games

# %% [markdown]
# ## Top N games on twitch (collected between 28/05 and 30/05)

# %% [markdown]
# Just to check: how many times data from twitch has been collected between 28 and 30 May. We gather all the timestamps

# %%
pipeline = [{ "$match" : {'$and' : [
                {'timestamp' : {'$gt' : '2019-05-28'}},
                {'timestamp' : {'$lt' : '2019-05-30'}}
            ]}}, {"$project":
             {'_id': 0,
              'time':'$timestamp'} }]

# %%
tsmps = list(db.games.aggregate(pipeline))

# %%
tsmps[:10]
# Out:
# [{'time': '2019-05-28 00:01:08.972371'},
#  {'time': '2019-05-28 00:04:08.980665'},
#  {'time': '2019-05-28 00:07:08.973388'},
#  {'time': '2019-05-28 00:10:08.981706'},
#  {'time': '2019-05-28 00:13:08.974376'},
#  {'time': '2019-05-28 00:16:08.978220'},
#  {'time': '2019-05-28 00:19:08.970934'},
#  {'time': '2019-05-28 00:22:08.979262'},
#  {'time': '2019-05-28 00:25:08.971894'},
#  {'time': '2019-05-28 00:28:08.980090'}]

# %%
tsmps[-10:]
# Out:
# [{'time': '2019-05-29 23:31:08.967758'},
#  {'time': '2019-05-29 23:34:08.980275'},
#  {'time': '2019-05-29 23:37:08.973006'},
#  {'time': '2019-05-29 23:40:08.981344'},
#  {'time': '2019-05-29 23:43:08.974079'},
#  {'time': '2019-05-29 23:46:08.982401'},
#  {'time': '2019-05-29 23:49:08.966718'},
#  {'time': '2019-05-29 23:52:08.975052'},
#  {'time': '2019-05-29 23:55:08.967763'},
#  {'time': '2019-05-29 23:58:08.976069'}]

# %%
len(tsmps)/ 48
# Out:
# 20.0

# %% [markdown]
# Data has been collected every 3 minutes, so 20 times each hour is correct.

# %%
pipeline = [{"$unwind": "$data"},
            { "$match" : {'$and' : [
                {'timestamp' : {'$gt' : '2019-05-28'}},
                {'timestamp' : {'$lt' : '2019-05-30'}}
            ]}},
            { "$group": {"_id": {"name": "$data.game.name",
                                 "norm_name" : "$data.game.norm_name",
                                 "unary_name" : "$data.game.unary_name",
                                 "twitch_id" : "$data.game._id"},
                         "avgViewers": { "$avg": '$data.viewers'}}},
           {"$sort": SON([("avgViewers", -1), ("_id", -1)])}]

# %%
top_twitch = list(db.games.aggregate(pipeline))

# %%
top_twitch[0:3]
# Out:
# [{'_id': {'name': 'Fortnite',
#    'norm_name': 'fortnite',
#    'unary_name': 'fortnite',
#    'twitch_id': 33214},
#   'avgViewers': 126368.478125},
#  {'_id': {'name': 'League of Legends',
#    'norm_name': 'league of legends',
#    'unary_name': 'league of legends',
#    'twitch_id': 21779},
#   'avgViewers': 117746.63333333333},
#  {'_id': {'name': 'Grand Theft Auto V',
#    'norm_name': 'grand theft auto v',
#    'unary_name': 'grand theft auto v',
#    'twitch_id': 32982},
#   'avgViewers': 94222.24895833334}]

# %%
top_twitch = [
    {'name' : elem['_id']['name'],
     'norm_name' : elem['_id']['norm_name'],
     'unary_name' : elem['_id']['unary_name'],
     'twitch_id' : elem['_id']['twitch_id'],
     'avgViewers' : elem['avgViewers']
    } for elem in top_twitch
]

# %%
top_twitch[0:3]
# Out:
# [{'name': 'Fortnite',
#   'norm_name': 'fortnite',
#   'unary_name': 'fortnite',
#   'twitch_id': 33214,
#   'avgViewers': 126368.478125},
#  {'name': 'League of Legends',
#   'norm_name': 'league of legends',
#   'unary_name': 'league of legends',
#   'twitch_id': 21779,
#   'avgViewers': 117746.63333333333},
#  {'name': 'Grand Theft Auto V',
#   'norm_name': 'grand theft auto v',
#   'unary_name': 'grand theft auto v',
#   'twitch_id': 32982,
#   'avgViewers': 94222.24895833334}]

# %%
top_twitch_df = pd.DataFrame(top_twitch)

# %% [markdown]
# # Top N games on Vgchartz

# %%
vgsales = pd.read_csv("../dataset/vgsales.csv")

# %% [markdown]
# We want the top N games by sales.
# Vgcharts has different rows for the same game depending on the platform, but I guess we are interested in the top N games by sales on all platforms...

# %%
# e.g.
vgsales[vgsales['Name'] == 'Grand Theft Auto V']
# Out:
#      Rank                Name Platform    Year  \
# 19     20  Grand Theft Auto V      PS3  2013.0
# 20     21  Grand Theft Auto V      PS4  2014.0
# 33     34  Grand Theft Auto V     X360  2013.0
# 62     63  Grand Theft Auto V       PC  2015.0
# 107   108  Grand Theft Auto V     XOne  2014.0
#
#                                             href_Genre         Publisher  \
# 19   http://www.vgchartz.com/game/65884/grand-theft...  Rockstar Games
# 20   http://www.vgchartz.com/game/83196/grand-theft...  Rockstar Games
# 33   http://www.vgchartz.com/game/65883/grand-theft...  Rockstar Games
# 62   http://www.vgchartz.com/game/83197/grand-theft...  Rockstar Games
# 107  http://www.vgchartz.com/game/73074/grand-theft...  Rockstar Games
#
#             Developer  Critic_Score  User_Score  NA_Sales  PAL_Sales  \
# 19   Rockstar North             9.4         NaN      6.37       9.85
# 20   Rockstar North             9.7         NaN      6.06       9.71
# 33   Rockstar North             NaN         NaN      9.06       5.33
# 62   Rockstar North             NaN         NaN      0.48       0.76
# 107  Rockstar North             9.0         9.0      4.70       3.25
#
#      JP_Sales  Other_Sales  Global_Sales
# 19       0.99         3.12         20.32
# 20       0.60         3.02         19.39
# 33       0.06         1.42         15.86
# 62        NaN         0.10          1.33
# 107      0.01         0.76          8.72

# %%
platform = vgsales.groupby('Name')['Platform'].apply(', '.join)

# %%
cr_score = vgsales.groupby('Name')['Critic_Score'].mean()

# %%
sales = vgsales.groupby('Name')['Global_Sales'].sum()

# %%
u_score  = vgsales.groupby('Name')['User_Score'].mean()

# %%
pub = vgsales.groupby('Name')['Publisher'].apply(', '.join)

# %%
dev = vgsales.groupby('Name')['Developer'].apply(', '.join)

# %%
df = pd.DataFrame({'Name' : sales.index, 'Global_Sales': sales,
                   'Platform': platform,  'Critic_Score' : cr_score, 'User_Score' : u_score,
                  'Publisher' : pub, 'Developer' : dev})

# %%
df = df.reset_index(drop = 1)

# %%
df[df['Name'] == 'Grand Theft Auto V']
# Out:
#                      Name  Global_Sales                  Platform  \
# 12801  Grand Theft Auto V         65.62  PS3, PS4, X360, PC, XOne
#
#        Critic_Score  User_Score  \
# 12801      9.366667         9.0
#
#                                                Publisher  \
# 12801  Rockstar Games  , Rockstar Games  , Rockstar G...
#
#                                                Developer
# 12801  Rockstar North  , Rockstar North  , Rockstar N...

# %%
top_vgchartz = df.sort_values('Global_Sales', ascending = 0).reset_index(drop = 1)

# %%
top_vgchartz.loc[0:10]
# Out:
#                                   Name  Global_Sales  \
# 0                           Wii Sports         82.65
# 1                   Grand Theft Auto V         65.62
# 2                    Super Mario Bros.         40.24
# 3                       Mario Kart Wii         35.98
# 4                               Tetris         35.84
# 5                            Minecraft         33.83
# 6                    Wii Sports Resort         32.90
# 7   Pokémon Red / Green / Blue Version         31.37
# 8              Call of Duty: Black Ops         30.99
# 9       Call of Duty: Modern Warfare 3         30.71
# 10               New Super Mario Bros.         29.85
#
#                                              Platform  Critic_Score  \
# 0                                                 Wii      7.700000
# 1                            PS3, PS4, X360, PC, XOne      9.366667
# 2                                  NES, VC, WiiU, 3DS      9.500000
# 3                                                 Wii      8.200000
# 4                                    GB, NES, WS, PSN      7.500000
# 5   PC, X360, PS4, PS3, XOne, PSV, NS, WiiU, 3DS, ...      8.160000
# 6                                                 Wii      8.000000
# 7                                                  GB      9.400000
# 8                    X360, PS3, PC, Wii, DS, XBL, PSN      8.285714
# 9                                  X360, PS3, PC, Wii      7.500000
# 10                                                 DS      9.100000
#
#     User_Score                                          Publisher  \
# 0          NaN                                         Nintendo
# 1          9.0  Rockstar Games  , Rockstar Games  , Rockstar G...
# 2          8.2     Nintendo  , Nintendo  , Nintendo  , Nintendo
# 3          9.1                                         Nintendo
# 4          NaN  Nintendo  , Nintendo  , Vanguard  , Electronic...
# 5          NaN  Mojang  , Microsoft Studios  , Sony Computer E...
# 6          8.8                                         Nintendo
# 7          NaN                                         Nintendo
# 8          NaN  Activision  , Activision  , Activision  , Acti...
# 9          NaN  Activision  , Activision  , Activision  , Acti...
# 10         8.1                                         Nintendo
#
#                                             Developer
# 0                                      Nintendo EAD
# 1   Rockstar North  , Rockstar North  , Rockstar N...
# 2   Nintendo EAD  , Nintendo EAD  , Unknown  , Unk...
# 3                                      Nintendo EAD
# 4   Bullet Proof Software  , Nintendo  , Vanguard ...
# 5   Mojang AB  , Mojang  , Mojang  , Mojang  , Moj...
# 6                                      Nintendo EAD
# 7                                        Game Freak
# 8   Treyarch  , Treyarch  , Treyarch  , Treyarch  ...
# 9   Infinity Ward  , Infinity Ward  , Infinity War...
# 10                                     Nintendo EAD

# %% [markdown]
# # From Vgchartz to Twitch

# %%
top_vgchartz['Norm_name'] = top_vgchartz['Name'].apply(lambda x: uniformer.uniform(x))

# %%
merged_df = pd.merge(top_vgchartz, top_twitch_df,  left_on = 'Norm_name', right_on = 'norm_name', how = 'outer').loc[0:50]

# %%
merged_df
# Out:
#                                             Name  Global_Sales  \
# 0                                     Wii Sports         82.65
# 1                             Grand Theft Auto V         65.62
# 2                              Super Mario Bros.         40.24
# 3                                 Mario Kart Wii         35.98
# 4                                         Tetris         35.84
# 5                                      Minecraft         33.83
# 6                              Wii Sports Resort         32.90
# 7             Pokémon Red / Green / Blue Version         31.37
# 8                        Call of Duty: Black Ops         30.99
# 9                 Call of Duty: Modern Warfare 3         30.71
# 10                         New Super Mario Bros.         29.85
# 11                    Call of Duty: Black Ops II         29.59
# 12                                      Wii Play         28.92
# 13                          Call of Duty: Ghosts         28.80
# 14                     New Super Mario Bros. Wii         28.51
# 15                                     Duck Hunt         28.31
# 16                     Call of Duty: Black Ops 3         26.72
# 17                Call of Duty: Modern Warfare 2         25.02
# 18                                    Nintendogs         24.68
# 19                 Grand Theft Auto: San Andreas         23.87
# 20                                 Mario Kart DS         23.26
# 21                 Pokémon Gold / Silver Version         23.10
# 22                                       Wii Fit         22.70
# 23                           Grand Theft Auto IV         22.53
# 24                            Kinect Adventures!         22.10
# 25                                  Wii Fit Plus         21.81
# 26                Call of Duty: Advanced Warfare         21.78
# 27                             Super Mario World         20.61
# 28                   The Elder Scrolls V: Skyrim         20.51
# 29  Brain Age: Train Your Brain in Minutes a Day         20.16
# 30                            Call of Duty: WWII         19.82
# 31                         Red Dead Redemption 2         19.71
# 32                Call of Duty 4: Modern Warfare         18.33
# 33               Pokémon Diamond / Pearl Version         18.25
# 34                              Super Mario Land         18.14
# 35                                       FIFA 15         18.03
# 36                                 Battlefield 3         17.32
# 37                                       FIFA 14         17.31
# 38                           Super Mario Bros. 3         17.28
# 39                                       FIFA 17         17.02
# 40                                       FIFA 18         16.92
# 41              Guitar Hero III: Legends of Rock         16.38
# 42                   Grand Theft Auto: Vice City         16.19
# 43                                   Pokémon X/Y         16.13
# 44                    Call of Duty: World at War         15.94
# 45               Pokémon Ruby / Sapphire Version         15.85
# 46                                       FIFA 16         15.82
# 47                                  Mario Kart 7         15.49
# 48                                       FIFA 13         15.36
# 49             LEGO Star Wars: The Complete Saga         15.33
# 50   Brain Age 2: More Training in Minutes a Day         15.29
#
#                                              Platform  Critic_Score  \
# 0                                                 Wii      7.700000
# 1                            PS3, PS4, X360, PC, XOne      9.366667
# 2                                  NES, VC, WiiU, 3DS      9.500000
# 3                                                 Wii      8.200000
# 4                                    GB, NES, WS, PSN      7.500000
# 5   PC, X360, PS4, PS3, XOne, PSV, NS, WiiU, 3DS, ...      8.160000
# 6                                                 Wii      8.000000
# 7                                                  GB      9.400000
# 8                    X360, PS3, PC, Wii, DS, XBL, PSN      8.285714
# 9                                  X360, PS3, PC, Wii      7.500000
# 10                                                 DS      9.100000
# 11                                X360, PS3, PC, WiiU      8.600000
# 12                                                Wii      5.900000
# 13                     X360, PS3, PS4, XOne, PC, WiiU      7.833333
# 14                                                Wii      8.600000
# 15                                                NES           NaN
# 16                           PS4, XOne, X360, PS3, PC           NaN
# 17                            X360, PS3, PC, XBL, PSN      9.333333
# 18                                                 DS      8.400000
# 19              PS2, XB, PC, XBL, PS3, OSX, WinP, And      9.366667
# 20                                           DS, WiiU      9.100000
# 21                                                 GB      9.200000
# 22                                                Wii      7.900000
# 23                                 X360, PS3, PC, XBL      9.733333
# 24                                               X360      6.700000
# 25                                                Wii      8.000000
# 26                           PS4, XOne, X360, PS3, PC      8.720000
# 27                                           SNES, VC      8.500000
# 28                                  X360, PS3, PC, NS      9.025000
# 29                                                 DS      8.100000
# 30                                      PS4, XOne, PC      8.000000
# 31                                          PS4, XOne      9.800000
# 32                        X360, PS3, PC, DS, XBL, PSN      8.925000
# 33                                                 DS      8.600000
# 34                                            GB, 3DS      7.500000
# 35            PS4, PS3, X360, XOne, PSV, Wii, 3DS, PC      7.360000
# 36                                      X360, PS3, PC      8.633333
# 37  PS3, X360, PS4, XOne, PSV, Wii, PC, 3DS, PSP, ...           NaN
# 38                                 NES, VC, 3DS, WiiU      9.500000
# 39                           PS4, XOne, PS3, X360, PC      8.850000
# 40                       PS4, XOne, NS, PS3, X360, PC      7.525000
# 41                            PS2, Wii, X360, PS3, PC      8.425000
# 42                                            PS2, PC      9.300000
# 43                                                3DS      8.900000
# 44                             X360, PS3, Wii, DS, PC      8.200000
# 45                                                GBA      8.800000
# 46                           PS4, XOne, PS3, X360, PC      8.700000
# 47                                                3DS      8.200000
# 48            PS3, X360, Wii, WiiU, PSP, PC, 3DS, PS2      7.000000
# 49                   Wii, DS, X360, PS3, XBL, OSX, PC      7.933333
# 50                                                 DS      8.000000
#
#     User_Score                                          Publisher  \
# 0          NaN                                         Nintendo
# 1         9.00  Rockstar Games  , Rockstar Games  , Rockstar G...
# 2         8.20     Nintendo  , Nintendo  , Nintendo  , Nintendo
# 3         9.10                                         Nintendo
# 4          NaN  Nintendo  , Nintendo  , Vanguard  , Electronic...
# 5          NaN  Mojang  , Microsoft Studios  , Sony Computer E...
# 6         8.80                                         Nintendo
# 7          NaN                                         Nintendo
# 8          NaN  Activision  , Activision  , Activision  , Acti...
# 9          NaN  Activision  , Activision  , Activision  , Acti...
# 10        8.10                                         Nintendo
# 11         NaN  Activision  , Activision  , Activision  , Acti...
# 12        4.50                                         Nintendo
# 13         NaN  Activision  , Activision  , Activision  , Acti...
# 14        9.20                                         Nintendo
# 15         NaN                                         Nintendo
# 16         NaN  Activision  , Activision  , Activision  , Acti...
# 17        9.00  Activision  , Activision  , Activision  , Acti...
# 18         NaN                                         Nintendo
# 19         NaN  Rockstar Games  , Rockstar Games  , Rockstar G...
# 20        9.40                             Nintendo  , Nintendo
# 21         NaN                                         Nintendo
# 22         NaN                                         Nintendo
# 23        9.00  Rockstar Games  , Rockstar Games  , Rockstar G...
# 24         NaN                           Microsoft Game Studios
# 25         NaN                                         Nintendo
# 26         NaN  Activision  , Activision  , Activision  , Acti...
# 27         NaN                             Nintendo  , Nintendo
# 28        9.10  Bethesda Softworks  , Bethesda Softworks  , Be...
# 29         NaN                                         Nintendo
# 30         NaN           Activision  , Activision  , Activision
# 31         NaN                 Rockstar Games  , Rockstar Games
# 32        9.30  Activision  , Activision  , Activision  , Acti...
# 33         NaN                                         Nintendo
# 34         NaN                             Nintendo  , Nintendo
# 35         NaN  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 36         NaN  Electronic Arts  , Electronic Arts  , Electron...
# 37         NaN  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 38         NaN     Nintendo  , Nintendo  , Nintendo  , Nintendo
# 39         NaN  Electronic Arts  , Electronic Arts  , Electron...
# 40        9.10  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 41        8.00  RedOctane  , RedOctane  , RedOctane  , RedOcta...
# 42         NaN                 Rockstar Games  , Rockstar Games
# 43        9.70                                         Nintendo
# 44        8.35  Activision  , Activision  , Activision  , Acti...
# 45         NaN                                         Nintendo
# 46         NaN  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 47         NaN                                         Nintendo
# 48         NaN  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 49         NaN  LucasArts  , LucasArts  , LucasArts  , LucasAr...
# 50         NaN                                         Nintendo
#
#                                             Developer  \
# 0                                      Nintendo EAD
# 1   Rockstar North  , Rockstar North  , Rockstar N...
# 2   Nintendo EAD  , Nintendo EAD  , Unknown  , Unk...
# 3                                      Nintendo EAD
# 4   Bullet Proof Software  , Nintendo  , Vanguard ...
# 5   Mojang AB  , Mojang  , Mojang  , Mojang  , Moj...
# 6                                      Nintendo EAD
# 7                                        Game Freak
# 8   Treyarch  , Treyarch  , Treyarch  , Treyarch  ...
# 9   Infinity Ward  , Infinity Ward  , Infinity War...
# 10                                     Nintendo EAD
# 11     Treyarch  , Treyarch  , Treyarch  , Treyarch
# 12                                     Nintendo EAD
# 13  Infinity Ward  , Infinity Ward  , Infinity War...
# 14                                     Nintendo EAD
# 15                                    Nintendo R&D1
# 16  Treyarch  , Treyarch  , Treyarch  , Treyarch  ...
# 17  Infinity Ward  , Infinity Ward  , Infinity War...
# 18                                     Nintendo EAD
# 19  Rockstar North  , Rockstar North  , Rockstar N...
# 20                     Nintendo EAD  , Nintendo EAD
# 21                                       Game Freak
# 22                                     Nintendo EAD
# 23  Rockstar North  , Rockstar North  , Rockstar T...
# 24                              Good Science Studio
# 25                                     Nintendo EAD
# 26  Sledgehammer Games  , Sledgehammer Games  , Hi...
# 27                     Nintendo EAD  , Nintendo EAD
# 28  Bethesda Game Studios  , Bethesda Game Studios...
# 29                                     Nintendo SDD
# 30  Sledgehammer Games  , Sledgehammer Games  , Sl...
# 31                 Rockstar Games  , Rockstar Games
# 32  Infinity Ward  , Infinity Ward  , Infinity War...
# 33                                       Game Freak
# 34                   Nintendo R&D1  , Nintendo R&D1
# 35  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 36                             Dice  , Dice  , Dice
# 37  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 38  Nintendo R&D2  , Nintendo R&D2  , Unknown  , U...
# 39  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 40  EA Vancouver  , EA Vancouver  , EA Vancouver  ...
# 41  BudCat Creations  , Vicarious Visions  , Never...
# 42                 Rockstar North  , Rockstar North
# 43                                       Game Freak
# 44  Treyarch  , Treyarch  , EXAKT Entertainment  ,...
# 45                                       Game Freak
# 46  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 47                     Nintendo EAD / Retro Studios
# 48  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 49  Traveller's Tales  , Traveller's Tales  , Trav...
# 50                                     Nintendo SDD
#
#                                       Norm_name    avgViewers  \
# 0                                    wii sports      4.881188
# 1                            grand theft auto v  94222.248958
# 2                             super mario bros.     49.296454
# 3                                mario kart wii     93.326776
# 4                                        tetris     50.957424
# 5                                     minecraft  12378.073958
# 6                             wii sports resort      1.351852
# 7            pokémon red / green / blue version           NaN
# 8                        call of duty black ops    394.394931
# 9               call of duty modern warfare iii     29.654709
# 10                        new super mario bros.     16.794595
# 11                    call of duty black ops ii    630.080851
# 12                                     wii play      0.833333
# 13                          call of duty ghosts     20.071879
# 14                    new super mario bros. wii     10.728448
# 15                                    duck hunt      1.000000
# 16                   call of duty black ops iii    244.281381
# 17               call of duty modern warfare ii           NaN
# 18                                   nintendogs           NaN
# 19                 grand theft auto san andreas    434.606092
# 20                                mario kart ds      0.909091
# 21                pokémon gold / silver version           NaN
# 22                                      wii fit           NaN
# 23                          grand theft auto iv     25.548611
# 24                           kinect adventures!           NaN
# 25                                 wii fit plus           NaN
# 26                call of duty advanced warfare      9.041176
# 27                            super mario world   1263.823591
# 28                   the elder scrolls v skyrim   3966.290928
# 29  brain age train your brain in minutes a day           NaN
# 30                            call of duty wwii     63.221985
# 31                       red dead redemption ii    658.664234
# 32                call of duty 4 modern warfare     27.126836
# 33              pokémon diamond / pearl version           NaN
# 34                             super mario land      0.000000
# 35                                      fifa xv     93.448649
# 36                              battlefield iii     19.742012
# 37                                     fifa xiv      0.000000
# 38                        super mario bros. iii    100.775713
# 39                                    fifa xvii    203.572939
# 40                                   fifa xviii     28.109560
# 41              guitar hero iii legends of rock    152.962726
# 42                   grand theft auto vice city    209.540323
# 43                                  pokémon x/y     36.430556
# 44                    call of duty world at war      6.363929
# 45              pokémon ruby / sapphire version           NaN
# 46                                     fifa xvi      1.835821
# 47                               mario kart vii      3.415842
# 48                                    fifa xiii           NaN
# 49             lego star wars the complete saga     25.105943
# 50   brain age 2 more training in minutes a day           NaN
#
#                                  name                         norm_name  \
# 0                          Wii Sports                        wii sports
# 1                  Grand Theft Auto V                grand theft auto v
# 2                   Super Mario Bros.                 super mario bros.
# 3                      Mario Kart Wii                    mario kart wii
# 4                              Tetris                            tetris
# 5                           Minecraft                         minecraft
# 6                   Wii Sports Resort                 wii sports resort
# 7                                 NaN                               NaN
# 8             Call of Duty: Black Ops            call of duty black ops
# 9      Call of Duty: Modern Warfare 3   call of duty modern warfare iii
# 10              New Super Mario Bros.             new super mario bros.
# 11         Call of Duty: Black Ops II         call of duty black ops ii
# 12                           Wii Play                          wii play
# 13               Call of Duty: Ghosts               call of duty ghosts
# 14          New Super Mario Bros. Wii         new super mario bros. wii
# 15                          Duck Hunt                         duck hunt
# 16        Call of Duty: Black Ops III        call of duty black ops iii
# 17                                NaN                               NaN
# 18                                NaN                               NaN
# 19      Grand Theft Auto: San Andreas      grand theft auto san andreas
# 20                      Mario Kart DS                     mario kart ds
# 21                                NaN                               NaN
# 22                                NaN                               NaN
# 23                Grand Theft Auto IV               grand theft auto iv
# 24                                NaN                               NaN
# 25                                NaN                               NaN
# 26     Call of Duty: Advanced Warfare     call of duty advanced warfare
# 27                  Super Mario World                 super mario world
# 28        The Elder Scrolls V: Skyrim        the elder scrolls v skyrim
# 29                                NaN                               NaN
# 30                 Call of Duty: WWII                 call of duty wwii
# 31              Red Dead Redemption 2            red dead redemption ii
# 32     Call of Duty 4: Modern Warfare     call of duty 4 modern warfare
# 33                                NaN                               NaN
# 34                   Super Mario Land                  super mario land
# 35                            FIFA 15                           fifa xv
# 36                      Battlefield 3                   battlefield iii
# 37                            FIFA 14                          fifa xiv
# 38                Super Mario Bros. 3             super mario bros. iii
# 39                            FIFA 17                         fifa xvii
# 40                            FIFA 18                        fifa xviii
# 41   Guitar Hero III: Legends of Rock   guitar hero iii legends of rock
# 42        Grand Theft Auto: Vice City        grand theft auto vice city
# 43                        Pokémon X/Y                       pokémon x/y
# 44         Call of Duty: World at War         call of duty world at war
# 45                                NaN                               NaN
# 46                            FIFA 16                          fifa xvi
# 47                       Mario Kart 7                    mario kart vii
# 48                                NaN                               NaN
# 49  LEGO Star Wars: The Complete Saga  lego star wars the complete saga
# 50                                NaN                               NaN
#
#     twitch_id                        unary_name
# 0     12232.0                        wii sports
# 1     32982.0                grand theft auto v
# 2    509508.0                 super mario bros.
# 3     18871.0                    mario kart wii
# 4      1736.0                            tetris
# 5     27471.0                         minecraft
# 6     19259.0                 wii sports resort
# 7         NaN                               NaN
# 8     23894.0            call of duty black ops
# 9     31551.0   call of duty modern warfare iii
# 10     7534.0             new super mario bros.
# 11    34134.0         call of duty black ops ii
# 12     8660.0                          wii play
# 13   118200.0               call of duty ghosts
# 14    24238.0         new super mario bros. wii
# 15     2530.0                         duck hunt
# 16   489401.0        call of duty black ops iii
# 17        NaN                               NaN
# 18        NaN                               NaN
# 19     6521.0      grand theft auto san andreas
# 20     5993.0                     mario kart ds
# 21        NaN                               NaN
# 22        NaN                               NaN
# 23    18707.0               grand theft auto iv
# 24        NaN                               NaN
# 25        NaN                               NaN
# 26   417973.0     call of duty advanced warfare
# 27     1229.0                 super mario world
# 28    30028.0        the elder scrolls v skyrim
# 29        NaN                               NaN
# 30   496712.0                 call of duty wwii
# 31   493959.0            red dead redemption ii
# 32     1964.0     call of duty 4 modern warfare
# 33        NaN                               NaN
# 34    18146.0                  super mario land
# 35   460402.0              fifa iiiiiiiiiiiiiii
# 36    24394.0                   battlefield iii
# 37   369095.0               fifa iiiiiiiiiiiiii
# 38     9455.0             super mario bros. iii
# 39   493091.0            fifa iiiiiiiiiiiiiiiii
# 40   495589.0           fifa iiiiiiiiiiiiiiiiii
# 41     3682.0   guitar hero iii legends of rock
# 42    15631.0        grand theft auto vice city
# 43   103828.0                       pokémon x/y
# 44    19006.0         call of duty world at war
# 45        NaN                               NaN
# 46   489608.0             fifa iiiiiiiiiiiiiiii
# 47    28588.0                mario kart iiiiiii
# 48        NaN                               NaN
# 49    10209.0  lego star wars the complete saga
# 50        NaN                               NaN

# %% [markdown]
# Let's check which matches are missing:

# %%
merged_df[merged_df['name'].isna()]
# Out:
#                                             Name  Global_Sales  \
# 7             Pokémon Red / Green / Blue Version         31.37
# 17                Call of Duty: Modern Warfare 2         25.02
# 18                                    Nintendogs         24.68
# 21                 Pokémon Gold / Silver Version         23.10
# 22                                       Wii Fit         22.70
# 24                            Kinect Adventures!         22.10
# 25                                  Wii Fit Plus         21.81
# 29  Brain Age: Train Your Brain in Minutes a Day         20.16
# 33               Pokémon Diamond / Pearl Version         18.25
# 45               Pokémon Ruby / Sapphire Version         15.85
# 48                                       FIFA 13         15.36
# 50   Brain Age 2: More Training in Minutes a Day         15.29
#
#                                    Platform  Critic_Score  User_Score  \
# 7                                        GB      9.400000         NaN
# 17                  X360, PS3, PC, XBL, PSN      9.333333         9.0
# 18                                       DS      8.400000         NaN
# 21                                       GB      9.200000         NaN
# 22                                      Wii      7.900000         NaN
# 24                                     X360      6.700000         NaN
# 25                                      Wii      8.000000         NaN
# 29                                       DS      8.100000         NaN
# 33                                       DS      8.600000         NaN
# 45                                      GBA      8.800000         NaN
# 48  PS3, X360, Wii, WiiU, PSP, PC, 3DS, PS2      7.000000         NaN
# 50                                       DS      8.000000         NaN
#
#                                             Publisher  \
# 7                                          Nintendo
# 17  Activision  , Activision  , Activision  , Acti...
# 18                                         Nintendo
# 21                                         Nintendo
# 22                                         Nintendo
# 24                           Microsoft Game Studios
# 25                                         Nintendo
# 29                                         Nintendo
# 33                                         Nintendo
# 45                                         Nintendo
# 48  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 50                                         Nintendo
#
#                                             Developer  \
# 7                                        Game Freak
# 17  Infinity Ward  , Infinity Ward  , Infinity War...
# 18                                     Nintendo EAD
# 21                                       Game Freak
# 22                                     Nintendo EAD
# 24                              Good Science Studio
# 25                                     Nintendo EAD
# 29                                     Nintendo SDD
# 33                                       Game Freak
# 45                                       Game Freak
# 48  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 50                                     Nintendo SDD
#
#                                       Norm_name  avgViewers name norm_name  \
# 7            pokémon red / green / blue version         NaN  NaN       NaN
# 17               call of duty modern warfare ii         NaN  NaN       NaN
# 18                                   nintendogs         NaN  NaN       NaN
# 21                pokémon gold / silver version         NaN  NaN       NaN
# 22                                      wii fit         NaN  NaN       NaN
# 24                           kinect adventures!         NaN  NaN       NaN
# 25                                 wii fit plus         NaN  NaN       NaN
# 29  brain age train your brain in minutes a day         NaN  NaN       NaN
# 33              pokémon diamond / pearl version         NaN  NaN       NaN
# 45              pokémon ruby / sapphire version         NaN  NaN       NaN
# 48                                    fifa xiii         NaN  NaN       NaN
# 50   brain age 2 more training in minutes a day         NaN  NaN       NaN
#
#     twitch_id unary_name
# 7         NaN        NaN
# 17        NaN        NaN
# 18        NaN        NaN
# 21        NaN        NaN
# 22        NaN        NaN
# 24        NaN        NaN
# 25        NaN        NaN
# 29        NaN        NaN
# 33        NaN        NaN
# 45        NaN        NaN
# 48        NaN        NaN
# 50        NaN        NaN

# %% [markdown]
# - nintendogs is not on twitch
# - wii fit/ wii fit plus are not on twitch
# - knect adventures is not on twitch
# - brain age/ brain age 2 are not on twitch

# %% [markdown]
# Solving the remaining discrepancies:

# %%
top_vgchartz.at[45, 'Norm_name'] = 'pokémon ruby/sapphire'

# %%
top_vgchartz.at[33, 'Norm_name'] = 'pokémon diamond/pearl'

# %%
top_vgchartz.at[21, 'Norm_name'] = 'pokémon gold/silver'

# %%
top_vgchartz.at[7, 'Norm_name'] = 'pokémon red/blue'

# %%
top_vgchartz.at[17, 'Norm_name'] = 'modern warfare ii'

# %%
top_vgchartz.at[48, 'Norm_name'] = 'fifa soccer xiii'

# %%
merged_df = pd.merge(top_vgchartz, top_twitch_df,  left_on = 'Norm_name', right_on = 'norm_name', how = 'outer').loc[0:50]

# %%
merged_df
# Out:
#                                             Name  Global_Sales  \
# 0                                     Wii Sports         82.65
# 1                             Grand Theft Auto V         65.62
# 2                              Super Mario Bros.         40.24
# 3                                 Mario Kart Wii         35.98
# 4                                         Tetris         35.84
# 5                                      Minecraft         33.83
# 6                              Wii Sports Resort         32.90
# 7             Pokémon Red / Green / Blue Version         31.37
# 8                        Call of Duty: Black Ops         30.99
# 9                 Call of Duty: Modern Warfare 3         30.71
# 10                         New Super Mario Bros.         29.85
# 11                    Call of Duty: Black Ops II         29.59
# 12                                      Wii Play         28.92
# 13                          Call of Duty: Ghosts         28.80
# 14                     New Super Mario Bros. Wii         28.51
# 15                                     Duck Hunt         28.31
# 16                     Call of Duty: Black Ops 3         26.72
# 17                Call of Duty: Modern Warfare 2         25.02
# 18                                    Nintendogs         24.68
# 19                 Grand Theft Auto: San Andreas         23.87
# 20                                 Mario Kart DS         23.26
# 21                 Pokémon Gold / Silver Version         23.10
# 22                                       Wii Fit         22.70
# 23                           Grand Theft Auto IV         22.53
# 24                            Kinect Adventures!         22.10
# 25                                  Wii Fit Plus         21.81
# 26                Call of Duty: Advanced Warfare         21.78
# 27                             Super Mario World         20.61
# 28                   The Elder Scrolls V: Skyrim         20.51
# 29  Brain Age: Train Your Brain in Minutes a Day         20.16
# 30                            Call of Duty: WWII         19.82
# 31                         Red Dead Redemption 2         19.71
# 32                Call of Duty 4: Modern Warfare         18.33
# 33               Pokémon Diamond / Pearl Version         18.25
# 34                              Super Mario Land         18.14
# 35                                       FIFA 15         18.03
# 36                                 Battlefield 3         17.32
# 37                                       FIFA 14         17.31
# 38                           Super Mario Bros. 3         17.28
# 39                                       FIFA 17         17.02
# 40                                       FIFA 18         16.92
# 41              Guitar Hero III: Legends of Rock         16.38
# 42                   Grand Theft Auto: Vice City         16.19
# 43                                   Pokémon X/Y         16.13
# 44                    Call of Duty: World at War         15.94
# 45               Pokémon Ruby / Sapphire Version         15.85
# 46                                       FIFA 16         15.82
# 47                                  Mario Kart 7         15.49
# 48                                       FIFA 13         15.36
# 49                                FIFA Soccer 13          0.46
# 50             LEGO Star Wars: The Complete Saga         15.33
#
#                                              Platform  Critic_Score  \
# 0                                                 Wii      7.700000
# 1                            PS3, PS4, X360, PC, XOne      9.366667
# 2                                  NES, VC, WiiU, 3DS      9.500000
# 3                                                 Wii      8.200000
# 4                                    GB, NES, WS, PSN      7.500000
# 5   PC, X360, PS4, PS3, XOne, PSV, NS, WiiU, 3DS, ...      8.160000
# 6                                                 Wii      8.000000
# 7                                                  GB      9.400000
# 8                    X360, PS3, PC, Wii, DS, XBL, PSN      8.285714
# 9                                  X360, PS3, PC, Wii      7.500000
# 10                                                 DS      9.100000
# 11                                X360, PS3, PC, WiiU      8.600000
# 12                                                Wii      5.900000
# 13                     X360, PS3, PS4, XOne, PC, WiiU      7.833333
# 14                                                Wii      8.600000
# 15                                                NES           NaN
# 16                           PS4, XOne, X360, PS3, PC           NaN
# 17                            X360, PS3, PC, XBL, PSN      9.333333
# 18                                                 DS      8.400000
# 19              PS2, XB, PC, XBL, PS3, OSX, WinP, And      9.366667
# 20                                           DS, WiiU      9.100000
# 21                                                 GB      9.200000
# 22                                                Wii      7.900000
# 23                                 X360, PS3, PC, XBL      9.733333
# 24                                               X360      6.700000
# 25                                                Wii      8.000000
# 26                           PS4, XOne, X360, PS3, PC      8.720000
# 27                                           SNES, VC      8.500000
# 28                                  X360, PS3, PC, NS      9.025000
# 29                                                 DS      8.100000
# 30                                      PS4, XOne, PC      8.000000
# 31                                          PS4, XOne      9.800000
# 32                        X360, PS3, PC, DS, XBL, PSN      8.925000
# 33                                                 DS      8.600000
# 34                                            GB, 3DS      7.500000
# 35            PS4, PS3, X360, XOne, PSV, Wii, 3DS, PC      7.360000
# 36                                      X360, PS3, PC      8.633333
# 37  PS3, X360, PS4, XOne, PSV, Wii, PC, 3DS, PSP, ...           NaN
# 38                                 NES, VC, 3DS, WiiU      9.500000
# 39                           PS4, XOne, PS3, X360, PC      8.850000
# 40                       PS4, XOne, NS, PS3, X360, PC      7.525000
# 41                            PS2, Wii, X360, PS3, PC      8.425000
# 42                                            PS2, PC      9.300000
# 43                                                3DS      8.900000
# 44                             X360, PS3, Wii, DS, PC      8.200000
# 45                                                GBA      8.800000
# 46                           PS4, XOne, PS3, X360, PC      8.700000
# 47                                                3DS      8.200000
# 48            PS3, X360, Wii, WiiU, PSP, PC, 3DS, PS2      7.000000
# 49                                                PSV           NaN
# 50                   Wii, DS, X360, PS3, XBL, OSX, PC      7.933333
#
#     User_Score                                          Publisher  \
# 0          NaN                                         Nintendo
# 1         9.00  Rockstar Games  , Rockstar Games  , Rockstar G...
# 2         8.20     Nintendo  , Nintendo  , Nintendo  , Nintendo
# 3         9.10                                         Nintendo
# 4          NaN  Nintendo  , Nintendo  , Vanguard  , Electronic...
# 5          NaN  Mojang  , Microsoft Studios  , Sony Computer E...
# 6         8.80                                         Nintendo
# 7          NaN                                         Nintendo
# 8          NaN  Activision  , Activision  , Activision  , Acti...
# 9          NaN  Activision  , Activision  , Activision  , Acti...
# 10        8.10                                         Nintendo
# 11         NaN  Activision  , Activision  , Activision  , Acti...
# 12        4.50                                         Nintendo
# 13         NaN  Activision  , Activision  , Activision  , Acti...
# 14        9.20                                         Nintendo
# 15         NaN                                         Nintendo
# 16         NaN  Activision  , Activision  , Activision  , Acti...
# 17        9.00  Activision  , Activision  , Activision  , Acti...
# 18         NaN                                         Nintendo
# 19         NaN  Rockstar Games  , Rockstar Games  , Rockstar G...
# 20        9.40                             Nintendo  , Nintendo
# 21         NaN                                         Nintendo
# 22         NaN                                         Nintendo
# 23        9.00  Rockstar Games  , Rockstar Games  , Rockstar G...
# 24         NaN                           Microsoft Game Studios
# 25         NaN                                         Nintendo
# 26         NaN  Activision  , Activision  , Activision  , Acti...
# 27         NaN                             Nintendo  , Nintendo
# 28        9.10  Bethesda Softworks  , Bethesda Softworks  , Be...
# 29         NaN                                         Nintendo
# 30         NaN           Activision  , Activision  , Activision
# 31         NaN                 Rockstar Games  , Rockstar Games
# 32        9.30  Activision  , Activision  , Activision  , Acti...
# 33         NaN                                         Nintendo
# 34         NaN                             Nintendo  , Nintendo
# 35         NaN  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 36         NaN  Electronic Arts  , Electronic Arts  , Electron...
# 37         NaN  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 38         NaN     Nintendo  , Nintendo  , Nintendo  , Nintendo
# 39         NaN  Electronic Arts  , Electronic Arts  , Electron...
# 40        9.10  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 41        8.00  RedOctane  , RedOctane  , RedOctane  , RedOcta...
# 42         NaN                 Rockstar Games  , Rockstar Games
# 43        9.70                                         Nintendo
# 44        8.35  Activision  , Activision  , Activision  , Acti...
# 45         NaN                                         Nintendo
# 46         NaN  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 47         NaN                                         Nintendo
# 48         NaN  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 49         NaN                                        EA Sports
# 50         NaN  LucasArts  , LucasArts  , LucasArts  , LucasAr...
#
#                                             Developer  \
# 0                                      Nintendo EAD
# 1   Rockstar North  , Rockstar North  , Rockstar N...
# 2   Nintendo EAD  , Nintendo EAD  , Unknown  , Unk...
# 3                                      Nintendo EAD
# 4   Bullet Proof Software  , Nintendo  , Vanguard ...
# 5   Mojang AB  , Mojang  , Mojang  , Mojang  , Moj...
# 6                                      Nintendo EAD
# 7                                        Game Freak
# 8   Treyarch  , Treyarch  , Treyarch  , Treyarch  ...
# 9   Infinity Ward  , Infinity Ward  , Infinity War...
# 10                                     Nintendo EAD
# 11     Treyarch  , Treyarch  , Treyarch  , Treyarch
# 12                                     Nintendo EAD
# 13  Infinity Ward  , Infinity Ward  , Infinity War...
# 14                                     Nintendo EAD
# 15                                    Nintendo R&D1
# 16  Treyarch  , Treyarch  , Treyarch  , Treyarch  ...
# 17  Infinity Ward  , Infinity Ward  , Infinity War...
# 18                                     Nintendo EAD
# 19  Rockstar North  , Rockstar North  , Rockstar N...
# 20                     Nintendo EAD  , Nintendo EAD
# 21                                       Game Freak
# 22                                     Nintendo EAD
# 23  Rockstar North  , Rockstar North  , Rockstar T...
# 24                              Good Science Studio
# 25                                     Nintendo EAD
# 26  Sledgehammer Games  , Sledgehammer Games  , Hi...
# 27                     Nintendo EAD  , Nintendo EAD
# 28  Bethesda Game Studios  , Bethesda Game Studios...
# 29                                     Nintendo SDD
# 30  Sledgehammer Games  , Sledgehammer Games  , Sl...
# 31                 Rockstar Games  , Rockstar Games
# 32  Infinity Ward  , Infinity Ward  , Infinity War...
# 33                                       Game Freak
# 34                   Nintendo R&D1  , Nintendo R&D1
# 35  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 36                             Dice  , Dice  , Dice
# 37  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 38  Nintendo R&D2  , Nintendo R&D2  , Unknown  , U...
# 39  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 40  EA Vancouver  , EA Vancouver  , EA Vancouver  ...
# 41  BudCat Creations  , Vicarious Visions  , Never...
# 42                 Rockstar North  , Rockstar North
# 43                                       Game Freak
# 44  Treyarch  , Treyarch  , EXAKT Entertainment  ,...
# 45                                       Game Freak
# 46  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 47                     Nintendo EAD / Retro Studios
# 48  EA Canada  , EA Canada  , EA Canada  , EA Cana...
# 49                                        EA Canada
# 50  Traveller's Tales  , Traveller's Tales  , Trav...
#
#                                       Norm_name    avgViewers  \
# 0                                    wii sports      4.881188
# 1                            grand theft auto v  94222.248958
# 2                             super mario bros.     49.296454
# 3                                mario kart wii     93.326776
# 4                                        tetris     50.957424
# 5                                     minecraft  12378.073958
# 6                             wii sports resort      1.351852
# 7                              pokémon red/blue     31.339560
# 8                        call of duty black ops    394.394931
# 9               call of duty modern warfare iii     29.654709
# 10                        new super mario bros.     16.794595
# 11                    call of duty black ops ii    630.080851
# 12                                     wii play      0.833333
# 13                          call of duty ghosts     20.071879
# 14                    new super mario bros. wii     10.728448
# 15                                    duck hunt      1.000000
# 16                   call of duty black ops iii    244.281381
# 17                            modern warfare ii    165.033684
# 18                                   nintendogs           NaN
# 19                 grand theft auto san andreas    434.606092
# 20                                mario kart ds      0.909091
# 21                          pokémon gold/silver     30.186462
# 22                                      wii fit           NaN
# 23                          grand theft auto iv     25.548611
# 24                           kinect adventures!           NaN
# 25                                 wii fit plus           NaN
# 26                call of duty advanced warfare      9.041176
# 27                            super mario world   1263.823591
# 28                   the elder scrolls v skyrim   3966.290928
# 29  brain age train your brain in minutes a day           NaN
# 30                            call of duty wwii     63.221985
# 31                       red dead redemption ii    658.664234
# 32                call of duty 4 modern warfare     27.126836
# 33                        pokémon diamond/pearl     17.008197
# 34                             super mario land      0.000000
# 35                                      fifa xv     93.448649
# 36                              battlefield iii     19.742012
# 37                                     fifa xiv      0.000000
# 38                        super mario bros. iii    100.775713
# 39                                    fifa xvii    203.572939
# 40                                   fifa xviii     28.109560
# 41              guitar hero iii legends of rock    152.962726
# 42                   grand theft auto vice city    209.540323
# 43                                  pokémon x/y     36.430556
# 44                    call of duty world at war      6.363929
# 45                        pokémon ruby/sapphire    100.829940
# 46                                     fifa xvi      1.835821
# 47                               mario kart vii      3.415842
# 48                             fifa soccer xiii      2.666667
# 49                             fifa soccer xiii      2.666667
# 50             lego star wars the complete saga     25.105943
#
#                                  name                         norm_name  \
# 0                          Wii Sports                        wii sports
# 1                  Grand Theft Auto V                grand theft auto v
# 2                   Super Mario Bros.                 super mario bros.
# 3                      Mario Kart Wii                    mario kart wii
# 4                              Tetris                            tetris
# 5                           Minecraft                         minecraft
# 6                   Wii Sports Resort                 wii sports resort
# 7                    Pokémon Red/Blue                  pokémon red/blue
# 8             Call of Duty: Black Ops            call of duty black ops
# 9      Call of Duty: Modern Warfare 3   call of duty modern warfare iii
# 10              New Super Mario Bros.             new super mario bros.
# 11         Call of Duty: Black Ops II         call of duty black ops ii
# 12                           Wii Play                          wii play
# 13               Call of Duty: Ghosts               call of duty ghosts
# 14          New Super Mario Bros. Wii         new super mario bros. wii
# 15                          Duck Hunt                         duck hunt
# 16        Call of Duty: Black Ops III        call of duty black ops iii
# 17                   Modern Warfare 2                 modern warfare ii
# 18                                NaN                               NaN
# 19      Grand Theft Auto: San Andreas      grand theft auto san andreas
# 20                      Mario Kart DS                     mario kart ds
# 21                Pokémon Gold/Silver               pokémon gold/silver
# 22                                NaN                               NaN
# 23                Grand Theft Auto IV               grand theft auto iv
# 24                                NaN                               NaN
# 25                                NaN                               NaN
# 26     Call of Duty: Advanced Warfare     call of duty advanced warfare
# 27                  Super Mario World                 super mario world
# 28        The Elder Scrolls V: Skyrim        the elder scrolls v skyrim
# 29                                NaN                               NaN
# 30                 Call of Duty: WWII                 call of duty wwii
# 31              Red Dead Redemption 2            red dead redemption ii
# 32     Call of Duty 4: Modern Warfare     call of duty 4 modern warfare
# 33              Pokémon Diamond/Pearl             pokémon diamond/pearl
# 34                   Super Mario Land                  super mario land
# 35                            FIFA 15                           fifa xv
# 36                      Battlefield 3                   battlefield iii
# 37                            FIFA 14                          fifa xiv
# 38                Super Mario Bros. 3             super mario bros. iii
# 39                            FIFA 17                         fifa xvii
# 40                            FIFA 18                        fifa xviii
# 41   Guitar Hero III: Legends of Rock   guitar hero iii legends of rock
# 42        Grand Theft Auto: Vice City        grand theft auto vice city
# 43                        Pokémon X/Y                       pokémon x/y
# 44         Call of Duty: World at War         call of duty world at war
# 45              Pokémon Ruby/Sapphire             pokémon ruby/sapphire
# 46                            FIFA 16                          fifa xvi
# 47                       Mario Kart 7                    mario kart vii
# 48                     FIFA Soccer 13                  fifa soccer xiii
# 49                     FIFA Soccer 13                  fifa soccer xiii
# 50  LEGO Star Wars: The Complete Saga  lego star wars the complete saga
#
#     twitch_id                        unary_name
# 0     12232.0                        wii sports
# 1     32982.0                grand theft auto v
# 2    509508.0                 super mario bros.
# 3     18871.0                    mario kart wii
# 4      1736.0                            tetris
# 5     27471.0                         minecraft
# 6     19259.0                 wii sports resort
# 7      3623.0                  pokémon red/blue
# 8     23894.0            call of duty black ops
# 9     31551.0   call of duty modern warfare iii
# 10     7534.0             new super mario bros.
# 11    34134.0         call of duty black ops ii
# 12     8660.0                          wii play
# 13   118200.0               call of duty ghosts
# 14    24238.0         new super mario bros. wii
# 15     2530.0                         duck hunt
# 16   489401.0        call of duty black ops iii
# 17    22393.0                 modern warfare ii
# 18        NaN                               NaN
# 19     6521.0      grand theft auto san andreas
# 20     5993.0                     mario kart ds
# 21     7528.0               pokémon gold/silver
# 22        NaN                               NaN
# 23    18707.0               grand theft auto iv
# 24        NaN                               NaN
# 25        NaN                               NaN
# 26   417973.0     call of duty advanced warfare
# 27     1229.0                 super mario world
# 28    30028.0        the elder scrolls v skyrim
# 29        NaN                               NaN
# 30   496712.0                 call of duty wwii
# 31   493959.0            red dead redemption ii
# 32     1964.0     call of duty 4 modern warfare
# 33     2993.0             pokémon diamond/pearl
# 34    18146.0                  super mario land
# 35   460402.0              fifa iiiiiiiiiiiiiii
# 36    24394.0                   battlefield iii
# 37   369095.0               fifa iiiiiiiiiiiiii
# 38     9455.0             super mario bros. iii
# 39   493091.0            fifa iiiiiiiiiiiiiiiii
# 40   495589.0           fifa iiiiiiiiiiiiiiiiii
# 41     3682.0   guitar hero iii legends of rock
# 42    15631.0        grand theft auto vice city
# 43   103828.0                       pokémon x/y
# 44    19006.0         call of duty world at war
# 45     9287.0             pokémon ruby/sapphire
# 46   489608.0             fifa iiiiiiiiiiiiiiii
# 47    28588.0                mario kart iiiiiii
# 48    32443.0         fifa soccer iiiiiiiiiiiii
# 49    32443.0         fifa soccer iiiiiiiiiiiii
# 50    10209.0  lego star wars the complete saga

# %% [markdown]
# Remainig missing matches:

# %%
merged_df[merged_df['name'].isna()]
# Out:
#                                             Name  Global_Sales Platform  \
# 18                                    Nintendogs         24.68       DS
# 22                                       Wii Fit         22.70      Wii
# 24                            Kinect Adventures!         22.10     X360
# 25                                  Wii Fit Plus         21.81      Wii
# 29  Brain Age: Train Your Brain in Minutes a Day         20.16       DS
#
#     Critic_Score  User_Score                 Publisher              Developer  \
# 18           8.4         NaN                Nintendo           Nintendo EAD
# 22           7.9         NaN                Nintendo           Nintendo EAD
# 24           6.7         NaN  Microsoft Game Studios    Good Science Studio
# 25           8.0         NaN                Nintendo           Nintendo EAD
# 29           8.1         NaN                Nintendo           Nintendo SDD
#
#                                       Norm_name  avgViewers name norm_name  \
# 18                                   nintendogs         NaN  NaN       NaN
# 22                                      wii fit         NaN  NaN       NaN
# 24                           kinect adventures!         NaN  NaN       NaN
# 25                                 wii fit plus         NaN  NaN       NaN
# 29  brain age train your brain in minutes a day         NaN  NaN       NaN
#
#     twitch_id unary_name
# 18        NaN        NaN
# 22        NaN        NaN
# 24        NaN        NaN
# 25        NaN        NaN
# 29        NaN        NaN

# %% [markdown]
# # From twitch to vgchartz

# %%
top_50_twitch_df = top_twitch_df.sort_values('avgViewers', ascending = False).loc[0:50]

# %%
merged_df2 = pd.merge(top_twitch_df,  top_vgchartz, left_on = 'norm_name', right_on = 'Norm_name', how = 'outer').loc[0:50]

# %%
merged_df2
# Out:
#        avgViewers                                    name  \
# 0   126368.478125                                Fortnite
# 1   117746.633333                       League of Legends
# 2    94222.248958                      Grand Theft Auto V
# 3    79284.045833                           Just Chatting
# 4    68005.006250                                  Dota 2
# 5    65221.743750                       World of Warcraft
# 6    38391.845833        Counter-Strike: Global Offensive
# 7    34578.984375           PLAYERUNKNOWN'S BATTLEGROUNDS
# 8    34578.984375           PLAYERUNKNOWN'S BATTLEGROUNDS
# 9    25637.785417                             Hearthstone
# 10   19756.038542                               Overwatch
# 11   17626.662139                         Death Stranding
# 12   17199.918750                              Auto Chess
# 13   15865.169792                        Layers of Fear 2
# 14   14402.557292                            Apex Legends
# 15   14045.714583               Total War: Three Kingdoms
# 16   13694.844792               Call of Duty: Black Ops 4
# 17   13481.285417                Splitgate: Arena Warfare
# 18   12378.073958                               Minecraft
# 19   10825.623958                        Dead by Daylight
# 20   10706.221875         Tom Clancy's Rainbow Six: Siege
# 21   10657.876042                                 FIFA 19
# 22   10517.815385                     Bio Inc. Redemption
# 23   10151.255208                   Talk Shows & Podcasts
# 24    9536.554167                                   Slots
# 25    8504.015625                 Music & Performing Arts
# 26    8453.771429                                Clam Man
# 27    8161.347917                    Magic: The Gathering
# 28    7443.458333                               Dauntless
# 29    6672.100000                      Escape From Tarkov
# 30    6097.379310                              Trivia 101
# 31    6065.195833                The Elder Scrolls Online
# 32    5977.111458                               Destiny 2
# 33    5964.107292                                     Art
# 34    5865.000000                Mashed: Drive to Survive
# 35    5727.392708                    Old School RuneScape
# 36    5462.906054                          Battalion 1944
# 37    5362.680000                       Conan Unconquered
# 38    5209.022917                            StarCraft II
# 39    5044.423958             Diablo III: Reaper of Souls
# 40    4556.683716                          XERA: Survival
# 41    4361.121212                     TrackMania² Stadium
# 42    4239.220949                             Worms W.M.D
# 43    4179.004167                                    ASMR
# 44    3966.290928             The Elder Scrolls V: Skyrim
# 45    3886.046875                          World of Tanks
# 46    3764.351042                FINAL FANTASY XIV Online
# 47    3647.997917                                   Poker
# 48    3574.294792                                NBA 2K19
# 49    3570.486966                              Dark Souls
# 50    3530.190000  Change: A Homeless Survival Experience
#
#                                 norm_name  twitch_id  \
# 0                                fortnite    33214.0
# 1                       league of legends    21779.0
# 2                      grand theft auto v    32982.0
# 3                           just chatting   509658.0
# 4                                 dota ii    29595.0
# 5                       world of warcraft    18122.0
# 6         counter-strike global offensive    32399.0
# 7           playerunknown's battlegrounds   493057.0
# 8           playerunknown's battlegrounds   493057.0
# 9                             hearthstone   138585.0
# 10                              overwatch   488552.0
# 11                        death stranding   494364.0
# 12                             auto chess   511748.0
# 13                      layers of fear ii   510090.0
# 14                           apex legends   511224.0
# 15               total war three kingdoms   502377.0
# 16              call of duty black ops iv   504462.0
# 17                splitgate arena warfare   499310.0
# 18                              minecraft    27471.0
# 19                       dead by daylight   491487.0
# 20         tom clancy's rainbow six siege   460630.0
# 21                               fifa xix   506103.0
# 22                    bio inc. redemption   497530.0
# 23                  talk shows & podcasts   417752.0
# 24                                  slots   498566.0
# 25                music & performing arts    26936.0
# 26                               clam man   512727.0
# 27                    magic the gathering     2748.0
# 28                              dauntless   494536.0
# 29                     escape from tarkov   491931.0
# 30                              trivia ci     1026.0
# 31               the elder scrolls online    65654.0
# 32                             destiny ii   497057.0
# 33                                    art   509660.0
# 34                mashed drive to survive    13040.0
# 35                   old school runescape   459931.0
# 36                      battalion mcmxliv   491704.0
# 37                      conan unconquered   510602.0
# 38                           starcraft ii   490422.0
# 39             diablo iii reaper of souls   313558.0
# 40                          xera survival   494531.0
# 41                    trackmania² stadium    79231.0
# 42                            worms w.m.d   493036.0
# 43                                   asmr   509659.0
# 44             the elder scrolls v skyrim    30028.0
# 45                         world of tanks    27546.0
# 46               final fantasy xiv online    24241.0
# 47                                  poker   488190.0
# 48                               nba 2k19   506383.0
# 49                             dark souls    29433.0
# 50  change a homeless survival experience   510671.0
#
#                                            unary_name  \
# 0                                            fortnite
# 1                                   league of legends
# 2                                  grand theft auto v
# 3                                       just chatting
# 4                                             dota ii
# 5                                   world of warcraft
# 6                     counter-strike global offensive
# 7                       playerunknown's battlegrounds
# 8                       playerunknown's battlegrounds
# 9                                         hearthstone
# 10                                          overwatch
# 11                                    death stranding
# 12                                         auto chess
# 13                                  layers of fear ii
# 14                                       apex legends
# 15                           total war three kingdoms
# 16                        call of duty black ops iiii
# 17                            splitgate arena warfare
# 18                                          minecraft
# 19                                   dead by daylight
# 20                     tom clancy's rainbow six siege
# 21                           fifa iiiiiiiiiiiiiiiiiii
# 22                                bio inc. redemption
# 23                              talk shows & podcasts
# 24                                              slots
# 25                            music & performing arts
# 26                                           clam man
# 27                                magic the gathering
# 28                                          dauntless
# 29                                 escape from tarkov
# 30  trivia iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 31                           the elder scrolls online
# 32                                         destiny ii
# 33                                                art
# 34                            mashed drive to survive
# 35                               old school runescape
# 36  battalion iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...
# 37                                  conan unconquered
# 38                                       starcraft ii
# 39                         diablo iii reaper of souls
# 40                                      xera survival
# 41                                trackmania² stadium
# 42                                        worms w.m.d
# 43                                               asmr
# 44                         the elder scrolls v skyrim
# 45                                     world of tanks
# 46                           final fantasy xiv online
# 47                                              poker
# 48                                           nba 2k19
# 49                                         dark souls
# 50              change a homeless survival experience
#
#                                 Name  Global_Sales  \
# 0                           Fortnite          2.37
# 1                  League of Legends          0.00
# 2                 Grand Theft Auto V         65.62
# 3                                NaN           NaN
# 4                             Dota 2          0.00
# 5                  World of Warcraft          6.35
# 6   Counter-Strike: Global Offensive          0.00
# 7      PlayerUnknown's Battlegrounds          2.50
# 8      PLAYERUNKNOWN'S BATTLEGROUNDS          0.00
# 9                                NaN           NaN
# 10                         Overwatch          8.18
# 11                   Death Stranding          0.00
# 12                               NaN           NaN
# 13                               NaN           NaN
# 14                      Apex Legends          0.00
# 15         Total War: Three Kingdoms          0.00
# 16                               NaN           NaN
# 17          Splitgate: Arena Warfare          0.00
# 18                         Minecraft         33.83
# 19                  Dead by Daylight          0.34
# 20   Tom Clancy's Rainbow Six: Siege          7.37
# 21                           FIFA 19         12.22
# 22                               NaN           NaN
# 23                               NaN           NaN
# 24                             Slots          0.00
# 25                               NaN           NaN
# 26                               NaN           NaN
# 27              Magic: The Gathering          0.00
# 28                         Dauntless          0.00
# 29                               NaN           NaN
# 30                               NaN           NaN
# 31          The Elder Scrolls Online          1.02
# 32                         Destiny 2          6.65
# 33                               NaN           NaN
# 34                               NaN           NaN
# 35                               NaN           NaN
# 36                               NaN           NaN
# 37                               NaN           NaN
# 38                               NaN           NaN
# 39       Diablo III: Reaper of Souls          0.00
# 40                               NaN           NaN
# 41               TrackMania² Stadium          0.00
# 42                               NaN           NaN
# 43                               NaN           NaN
# 44       The Elder Scrolls V: Skyrim         20.51
# 45                    World of Tanks          0.31
# 46          Final Fantasy XIV Online          2.45
# 47                               NaN           NaN
# 48                          NBA 2K19          4.67
# 49                        Dark Souls          3.04
# 50                               NaN           NaN
#
#                                              Platform  Critic_Score  \
# 0                                   PS4, XOne, NS, PC      8.500000
# 1                                             PC, OSX      8.000000
# 2                            PS3, PS4, X360, PC, XOne      9.366667
# 3                                                 NaN           NaN
# 4                                      PC, OSX, Linux           NaN
# 5                                             PC, OSX      9.200000
# 6                                   PC, XBL, PSN, OSX           NaN
# 7                                           XOne, PS4           NaN
# 8                                                  PC           NaN
# 9                                                 NaN           NaN
# 10                                      PS4, XOne, PC      9.000000
# 11                                                PS4           NaN
# 12                                                NaN           NaN
# 13                                                NaN           NaN
# 14                                      XOne, PC, PS4           NaN
# 15                                                 PC           NaN
# 16                                                NaN           NaN
# 17                                                 PC           NaN
# 18  PC, X360, PS4, PS3, XOne, PSV, NS, WiiU, 3DS, ...      8.160000
# 19                                  PS4, XOne, PC, NS           NaN
# 20                                      PS4, XOne, PC           NaN
# 21                       PS4, XOne, NS, X360, PS3, PC      5.900000
# 22                                                NaN           NaN
# 23                                                NaN           NaN
# 24                                               2600           NaN
# 25                                                NaN           NaN
# 26                                                NaN           NaN
# 27                                             PC, DC           NaN
# 28                                  PC, PS4, XOne, NS           NaN
# 29                                                NaN           NaN
# 30                                                NaN           NaN
# 31                                            PC, OSX           NaN
# 32                                      PS4, XOne, PC           NaN
# 33                                                NaN           NaN
# 34                                                NaN           NaN
# 35                                                NaN           NaN
# 36                                                NaN           NaN
# 37                                                NaN           NaN
# 38                                                NaN           NaN
# 39                                                 PC           NaN
# 40                                                NaN           NaN
# 41                                                 PC           NaN
# 42                                                NaN           NaN
# 43                                                NaN           NaN
# 44                                  X360, PS3, PC, NS      9.025000
# 45                                           PC, X360      7.800000
# 46                                            PC, PS3      5.300000
# 47                                                NaN           NaN
# 48                                  PS4, XOne, NS, PC           NaN
# 49                                          PS3, X360      9.050000
# 50                                                NaN           NaN
#
#     User_Score                                          Publisher  \
# 0          NaN  Gearbox Software  , Gearbox Software  , Warner...
# 1          NaN                                THQ  , Riot Games
# 2          9.0  Rockstar Games  , Rockstar Games  , Rockstar G...
# 3          NaN                                                NaN
# 4          NaN  Valve Corporation  , Valve Corporation  , Valv...
# 5          8.0  Blizzard Entertainment  , Blizzard Entertainme...
# 6          NaN  Valve  , Valve Corporation  , Valve Corporatio...
# 7          NaN  Microsoft Studios  , Sony Interactive Entertai...
# 8          NaN                                 PUBG Corporation
# 9          NaN                                                NaN
# 10         NaN  Blizzard Entertainment  , Blizzard Entertainme...
# 11         NaN                   Sony Interactive Entertainment
# 12         NaN                                                NaN
# 13         NaN                                                NaN
# 14         NaN  Electronic Arts  , Electronic Arts  , Electron...
# 15         NaN                                             Sega
# 16         NaN                                                NaN
# 17         NaN                                          Unknown
# 18         NaN  Mojang  , Microsoft Studios  , Sony Computer E...
# 19         NaN  505 Games  , 505 Games  , Starbreeze Studios  ...
# 20         NaN                    Ubisoft  , Ubisoft  , Ubisoft
# 21         NaN  Electronic Arts  , Electronic Arts  , Electron...
# 22         NaN                                                NaN
# 23         NaN                                                NaN
# 24         NaN                                           Sears
# 25         NaN                                                NaN
# 26         NaN                                                NaN
# 27         NaN                                    Atari  , Sega
# 28         NaN  Phoenix Labs  , Phoenix Labs  , Phoenix Labs  ...
# 29         NaN                                                NaN
# 30         NaN                                                NaN
# 31         NaN         Bethesda Softworks  , Bethesda Softworks
# 32         NaN           Activision  , Activision  , Activision
# 33         NaN                                                NaN
# 34         NaN                                                NaN
# 35         NaN                                                NaN
# 36         NaN                                                NaN
# 37         NaN                                                NaN
# 38         NaN                                                NaN
# 39         NaN                           Blizzard Entertainment
# 40         NaN                                                NaN
# 41         NaN                                          Ubisoft
# 42         NaN                                                NaN
# 43         NaN                                                NaN
# 44         9.1  Bethesda Softworks  , Bethesda Softworks  , Be...
# 45         NaN                   Wargaming.net  , Wargaming.net
# 46         NaN                       Square Enix  , Square Enix
# 47         NaN                                                NaN
# 48         NaN  2K Sports  , 2K Sports  , 2K Sports  , 2K Spor...
# 49         NaN                     Namco Bandai  , Namco Bandai
# 50         NaN                                                NaN
#
#                                             Developer  \
# 0   Epic Games  , Epic Games  , Epic Games  , Epic...
# 1                          Riot Games  , Riot Games
# 2   Rockstar North  , Rockstar North  , Rockstar N...
# 3                                                 NaN
# 4                           Valve  , Valve  , Valve
# 5                 Blizzard Entertainment  , Unknown
# 6   Valve Corporation  , Valve Corporation  , Valv...
# 7              PUBG Corporation  , PUBG Corporation
# 8                                  PUBG Corporation
# 9                                                 NaN
# 10  Blizzard Entertainment  , Blizzard Entertainme...
# 11                               Kojima Productions
# 12                                                NaN
# 13                                                NaN
# 14  Respawn Entertainment  , Respawn Entertainment...
# 15                                Creative Assembly
# 16                                                NaN
# 17                                       1047 Games
# 18  Mojang AB  , Mojang  , Mojang  , Mojang  , Moj...
# 19  Behaviour Interactive Inc.  , Behaviour Intera...
# 20  Ubisoft Montreal  , Ubisoft Montreal  , Ubisof...
# 21  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 22                                                NaN
# 23                                                NaN
# 24                                        Telegames
# 25                                                NaN
# 26                                                NaN
# 27                               MicroProse  , Sega
# 28  Phoenix Labs  , Phoenix Labs  , Phoenix Labs  ...
# 29                                                NaN
# 30                                                NaN
# 31  ZeniMax Online Studios  , Bethesda Game Studios
# 32                       Bungie  , Bungie  , Bungie
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                           Blizzard Entertainment
# 40                                                NaN
# 41                                          Unknown
# 42                                                NaN
# 43                                                NaN
# 44  Bethesda Game Studios  , Bethesda Game Studios...
# 45                  Wargaming.net  , Wargaming West
# 46                       Square Enix  , Square Enix
# 47                                                NaN
# 48  Visual Concepts  , Visual Concepts  , Visual C...
# 49                   From Software  , From Software
# 50                                                NaN
#
#                           Norm_name
# 0                          fortnite
# 1                 league of legends
# 2                grand theft auto v
# 3                               NaN
# 4                           dota ii
# 5                 world of warcraft
# 6   counter-strike global offensive
# 7     playerunknown's battlegrounds
# 8     playerunknown's battlegrounds
# 9                               NaN
# 10                        overwatch
# 11                  death stranding
# 12                              NaN
# 13                              NaN
# 14                     apex legends
# 15         total war three kingdoms
# 16                              NaN
# 17          splitgate arena warfare
# 18                        minecraft
# 19                 dead by daylight
# 20   tom clancy's rainbow six siege
# 21                         fifa xix
# 22                              NaN
# 23                              NaN
# 24                            slots
# 25                              NaN
# 26                              NaN
# 27              magic the gathering
# 28                        dauntless
# 29                              NaN
# 30                              NaN
# 31         the elder scrolls online
# 32                       destiny ii
# 33                              NaN
# 34                              NaN
# 35                              NaN
# 36                              NaN
# 37                              NaN
# 38                              NaN
# 39       diablo iii reaper of souls
# 40                              NaN
# 41              trackmania² stadium
# 42                              NaN
# 43                              NaN
# 44       the elder scrolls v skyrim
# 45                   world of tanks
# 46         final fantasy xiv online
# 47                              NaN
# 48                         nba 2k19
# 49                       dark souls
# 50                              NaN

# %% [markdown]
# Let us check which matches are missing:

# %%
merged_df2[merged_df2['Name'].isna()]
# Out:
#       avgViewers                                    name  \
# 3   79284.045833                           Just Chatting
# 9   25637.785417                             Hearthstone
# 12  17199.918750                              Auto Chess
# 13  15865.169792                        Layers of Fear 2
# 16  13694.844792               Call of Duty: Black Ops 4
# 22  10517.815385                     Bio Inc. Redemption
# 23  10151.255208                   Talk Shows & Podcasts
# 25   8504.015625                 Music & Performing Arts
# 26   8453.771429                                Clam Man
# 29   6672.100000                      Escape From Tarkov
# 30   6097.379310                              Trivia 101
# 33   5964.107292                                     Art
# 34   5865.000000                Mashed: Drive to Survive
# 35   5727.392708                    Old School RuneScape
# 36   5462.906054                          Battalion 1944
# 37   5362.680000                       Conan Unconquered
# 38   5209.022917                            StarCraft II
# 40   4556.683716                          XERA: Survival
# 42   4239.220949                             Worms W.M.D
# 43   4179.004167                                    ASMR
# 47   3647.997917                                   Poker
# 50   3530.190000  Change: A Homeless Survival Experience
#
#                                 norm_name  twitch_id  \
# 3                           just chatting   509658.0
# 9                             hearthstone   138585.0
# 12                             auto chess   511748.0
# 13                      layers of fear ii   510090.0
# 16              call of duty black ops iv   504462.0
# 22                    bio inc. redemption   497530.0
# 23                  talk shows & podcasts   417752.0
# 25                music & performing arts    26936.0
# 26                               clam man   512727.0
# 29                     escape from tarkov   491931.0
# 30                              trivia ci     1026.0
# 33                                    art   509660.0
# 34                mashed drive to survive    13040.0
# 35                   old school runescape   459931.0
# 36                      battalion mcmxliv   491704.0
# 37                      conan unconquered   510602.0
# 38                           starcraft ii   490422.0
# 40                          xera survival   494531.0
# 42                            worms w.m.d   493036.0
# 43                                   asmr   509659.0
# 47                                  poker   488190.0
# 50  change a homeless survival experience   510671.0
#
#                                            unary_name Name  Global_Sales  \
# 3                                       just chatting  NaN           NaN
# 9                                         hearthstone  NaN           NaN
# 12                                         auto chess  NaN           NaN
# 13                                  layers of fear ii  NaN           NaN
# 16                        call of duty black ops iiii  NaN           NaN
# 22                                bio inc. redemption  NaN           NaN
# 23                              talk shows & podcasts  NaN           NaN
# 25                            music & performing arts  NaN           NaN
# 26                                           clam man  NaN           NaN
# 29                                 escape from tarkov  NaN           NaN
# 30  trivia iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...  NaN           NaN
# 33                                                art  NaN           NaN
# 34                            mashed drive to survive  NaN           NaN
# 35                               old school runescape  NaN           NaN
# 36  battalion iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...  NaN           NaN
# 37                                  conan unconquered  NaN           NaN
# 38                                       starcraft ii  NaN           NaN
# 40                                      xera survival  NaN           NaN
# 42                                        worms w.m.d  NaN           NaN
# 43                                               asmr  NaN           NaN
# 47                                              poker  NaN           NaN
# 50              change a homeless survival experience  NaN           NaN
#
#    Platform  Critic_Score  User_Score Publisher Developer Norm_name
# 3       NaN           NaN         NaN       NaN       NaN       NaN
# 9       NaN           NaN         NaN       NaN       NaN       NaN
# 12      NaN           NaN         NaN       NaN       NaN       NaN
# 13      NaN           NaN         NaN       NaN       NaN       NaN
# 16      NaN           NaN         NaN       NaN       NaN       NaN
# 22      NaN           NaN         NaN       NaN       NaN       NaN
# 23      NaN           NaN         NaN       NaN       NaN       NaN
# 25      NaN           NaN         NaN       NaN       NaN       NaN
# 26      NaN           NaN         NaN       NaN       NaN       NaN
# 29      NaN           NaN         NaN       NaN       NaN       NaN
# 30      NaN           NaN         NaN       NaN       NaN       NaN
# 33      NaN           NaN         NaN       NaN       NaN       NaN
# 34      NaN           NaN         NaN       NaN       NaN       NaN
# 35      NaN           NaN         NaN       NaN       NaN       NaN
# 36      NaN           NaN         NaN       NaN       NaN       NaN
# 37      NaN           NaN         NaN       NaN       NaN       NaN
# 38      NaN           NaN         NaN       NaN       NaN       NaN
# 40      NaN           NaN         NaN       NaN       NaN       NaN
# 42      NaN           NaN         NaN       NaN       NaN       NaN
# 43      NaN           NaN         NaN       NaN       NaN       NaN
# 47      NaN           NaN         NaN       NaN       NaN       NaN
# 50      NaN           NaN         NaN       NaN       NaN       NaN

# %% [markdown]
# - just chatting is not a game (and the same goes for 'ASMR', 'art', ecc.)
# - auto chess is not vgchartz
# - Layers of Fear 2	is not in vgchartz
# - Bio Inc. Redemption	is not in vgchartz
# - Clam Man is not in vgchartz
# -  Escape From Tarkov	 is not in vgchartz
# - Old School RuneScape	 is not in vgchartz
# - Battalion 1944	 is not in vgchartz
# - Conan Unconquered	 is not in vgchartz
# - XERA: Survival	is not in vgchartz
# - ASMR is not in vgchartz
# - Poker is not in vgchartz
# - Change: A Homeless Survival Experience is not in vgchartz

# %% [markdown]
# Solving the remaining discrepancies:

# %%
top_vgchartz[top_vgchartz['Name'] == 'Hearthstone: Heroes of Warcraft']
# Out:
#                                   Name  Global_Sales Platform  Critic_Score  \
# 36581  Hearthstone: Heroes of Warcraft           0.0  OSX, PC           NaN
#
#        User_Score                                          Publisher  \
# 36581         NaN  Blizzard Entertainment  , Blizzard Entertainme...
#
#                   Developer                       Norm_name
# 36581  Unknown  , Unknown    hearthstone heroes of warcraft

# %%
top_vgchartz.at[36581, 'Norm_name'] = 'hearthstone'

# %%
top_vgchartz[top_vgchartz['Name'] == 'Call of Duty: Black Ops IIII']
# Out:
#                             Name  Global_Sales       Platform  Critic_Score  \
# 58  Call of Duty: Black Ops IIII          14.3  PS4, XOne, PC           NaN
#
#     User_Score                                 Publisher  \
# 58         NaN  Activision  , Activision  , Activision
#
#                              Developer                    Norm_name
# 58  Treyarch  , Treyarch  , Treyarch    call of duty black ops iiii

# %%
top_vgchartz.at[58, 'Norm_name'] = 'call of duty black ops iv'

# %%
top_vgchartz[top_vgchartz['Name'] == 'Drive to Survive']
# Out:
#                    Name  Global_Sales Platform  Critic_Score  User_Score  \
# 25837  Drive to Survive           0.0      PS2           NaN         NaN
#
#         Publisher     Developer         Norm_name
# 25837  VU Games    Supersonic    drive to survive

# %%
top_vgchartz.at[25837, 'Norm_name'] = 'mashed drive to survive'

# %%
top_vgchartz[top_vgchartz['Name'] == 'StarCraft II: Wings of Liberty']
# Out:
#                                Name  Global_Sales Platform  Critic_Score  \
# 383  StarCraft II: Wings of Liberty          4.86  PC, OSX           9.3
#
#      User_Score                                          Publisher  \
# 383         NaN  Blizzard Entertainment  , Blizzard Entertainme...
#
#                                Developer                      Norm_name
# 383  Blizzard Entertainment  , Unknown    starcraft ii wings of liberty

# %%
top_vgchartz.at[383, 'Norm_name'] = 'starcraft ii'

# %%
top_vgchartz[top_vgchartz['Name'] == 'Worms: WMD']
# Out:
#             Name  Global_Sales           Platform  Critic_Score  User_Score  \
# 8822  Worms: WMD          0.07  PC, PS4, XOne, NS           NaN         NaN
#
#                                               Publisher  \
# 8822  Team17 Digital Ltd  , Team17 Digital Ltd  , Te...
#
#                                               Developer  Norm_name
# 8822  Team17 Digital Ltd  , Team17 Digital Ltd  , Te...  worms wmd

# %%
top_vgchartz.at[8822, 'Norm_name'] = 'worms w.m.d'

# %%
merged_df2 = pd.merge(top_twitch_df,  top_vgchartz, left_on = 'norm_name', right_on = 'Norm_name', how = 'outer').loc[0:50]

# %% [markdown]
# Remainig missing matches:

# %%
merged_df2[merged_df2['Norm_name'].isna()]
# Out:
#       avgViewers                                    name  \
# 3   79284.045833                           Just Chatting
# 12  17199.918750                              Auto Chess
# 13  15865.169792                        Layers of Fear 2
# 22  10517.815385                     Bio Inc. Redemption
# 23  10151.255208                   Talk Shows & Podcasts
# 25   8504.015625                 Music & Performing Arts
# 26   8453.771429                                Clam Man
# 29   6672.100000                      Escape From Tarkov
# 30   6097.379310                              Trivia 101
# 33   5964.107292                                     Art
# 35   5727.392708                    Old School RuneScape
# 36   5462.906054                          Battalion 1944
# 37   5362.680000                       Conan Unconquered
# 40   4556.683716                          XERA: Survival
# 43   4179.004167                                    ASMR
# 47   3647.997917                                   Poker
# 50   3530.190000  Change: A Homeless Survival Experience
#
#                                 norm_name  twitch_id  \
# 3                           just chatting   509658.0
# 12                             auto chess   511748.0
# 13                      layers of fear ii   510090.0
# 22                    bio inc. redemption   497530.0
# 23                  talk shows & podcasts   417752.0
# 25                music & performing arts    26936.0
# 26                               clam man   512727.0
# 29                     escape from tarkov   491931.0
# 30                              trivia ci     1026.0
# 33                                    art   509660.0
# 35                   old school runescape   459931.0
# 36                      battalion mcmxliv   491704.0
# 37                      conan unconquered   510602.0
# 40                          xera survival   494531.0
# 43                                   asmr   509659.0
# 47                                  poker   488190.0
# 50  change a homeless survival experience   510671.0
#
#                                            unary_name Name  Global_Sales  \
# 3                                       just chatting  NaN           NaN
# 12                                         auto chess  NaN           NaN
# 13                                  layers of fear ii  NaN           NaN
# 22                                bio inc. redemption  NaN           NaN
# 23                              talk shows & podcasts  NaN           NaN
# 25                            music & performing arts  NaN           NaN
# 26                                           clam man  NaN           NaN
# 29                                 escape from tarkov  NaN           NaN
# 30  trivia iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...  NaN           NaN
# 33                                                art  NaN           NaN
# 35                               old school runescape  NaN           NaN
# 36  battalion iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii...  NaN           NaN
# 37                                  conan unconquered  NaN           NaN
# 40                                      xera survival  NaN           NaN
# 43                                               asmr  NaN           NaN
# 47                                              poker  NaN           NaN
# 50              change a homeless survival experience  NaN           NaN
#
#    Platform  Critic_Score  User_Score Publisher Developer Norm_name
# 3       NaN           NaN         NaN       NaN       NaN       NaN
# 12      NaN           NaN         NaN       NaN       NaN       NaN
# 13      NaN           NaN         NaN       NaN       NaN       NaN
# 22      NaN           NaN         NaN       NaN       NaN       NaN
# 23      NaN           NaN         NaN       NaN       NaN       NaN
# 25      NaN           NaN         NaN       NaN       NaN       NaN
# 26      NaN           NaN         NaN       NaN       NaN       NaN
# 29      NaN           NaN         NaN       NaN       NaN       NaN
# 30      NaN           NaN         NaN       NaN       NaN       NaN
# 33      NaN           NaN         NaN       NaN       NaN       NaN
# 35      NaN           NaN         NaN       NaN       NaN       NaN
# 36      NaN           NaN         NaN       NaN       NaN       NaN
# 37      NaN           NaN         NaN       NaN       NaN       NaN
# 40      NaN           NaN         NaN       NaN       NaN       NaN
# 43      NaN           NaN         NaN       NaN       NaN       NaN
# 47      NaN           NaN         NaN       NaN       NaN       NaN
# 50      NaN           NaN         NaN       NaN       NaN       NaN

# %% [markdown]
# ## Getting all games

# %%
final = pd.concat([merged_df, merged_df2], axis = 0, sort=True)

# %%
# delete the rows with missing values in norm_name or Norm_name (i.e., the ones that have not been matched)
# Or maybe we want to keep them anyway?
final = final[final['Norm_name'].notna() & final['norm_name'].notna()].sort_values('Norm_name').reset_index(drop =1)

# %%
dup_idx = final.duplicated(subset = 'Norm_name', keep = 'last')

# %%
# remove duplicate rows (e.g., GTA 5 was found in both Vgchartz and twitch)
final = final[-dup_idx].reset_index(drop = 1)

# %%
# these two columns are not necessary
final = final.drop(['Name', 'Norm_name'], axis = 1)

# %%
# reorder columns
final = final[['twitch_id', 'name', 'Global_Sales', 'avgViewers', 'Platform',
               'Publisher', 'Developer', 'Critic_Score',
               'User_Score', 'norm_name', 'unary_name']]

# %%
final['Global_Sales'] = final['Global_Sales'].replace(0, np.nan)

# %%
final = final.sort_values('avgViewers', ascending = 0)

# %% [markdown]
# #### (adding alternative names)

# %%
# alt_names = []

# %%
#for name in final['name']:
#    print(name)
#    alt_name = input()
#    if alt_name == '':
#        alt_name = np.nan
#    alt_names.append(alt_name)

# %%
# alt_names

# %% [markdown]
# (Saving the list just in case we use it...)

# %%
nan = np.nan

# %% [markdown]
# [nan,
#  'LoL',
#  'GTAV, GTA5',
#  nan,
#  'WoW',
#  'CSGO',
#  'PUGB',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'COD Black Ops 4, COD Black Ops IV',
#  nan,
#  nan,
#  nan,
#  'Rainbow Six Siege',
#  'FIFA XIX',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'SCII, SC2, SC II, SC 2, StarCraft 2',
#  nan,
#  nan,
#  'Worms WMD',
#  'Skyrim',
#  nan,
#  'FF XIV, FFXIV, FF 14, FF14',
#  'NBA 2019, NBA 19',
#  nan,
#  nan,
#  nan,
#  'COD Black Ops 2, COD Black Ops II',
#  'GTA San Andreas',
#  'COD Black Ops',
#  'Cod Black Ops 3, COD Black Ops III',
#  'GTA Vice City',
#  'FIFA XVII',
#  'COD MW2, COD MWII, COD Modern Warfare 2, COD Modern Warfare II',
#  'GHIII',
#  nan,
#  nan,
#  'FIFA XV',
#  nan,
#  'COD WWII',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'COD MW3, COD MWIII, COD Modern Warfare III, COD Modern Warfare 3',
#  'FIFA XVIII',
#  'COD IV Modern Warfare, COD IV MW, COD 4 MW, COD 4 Modern Warfare',
#  'GTAIV, GTA IV, GTA4, GTA 4',
#  nan,
#  'COD Ghosts',
#  nan,
#  nan,
#  nan,
#  nan,
#  'COD Advanced Warfare',
#  'COD World at War',
#  nan,
#  nan,
#  'FIFA 13, FIFA XIII',
#  'FIFA XVI',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'FIFA XIV']

# %%
alt_names = [nan, 'LoL', 'GTAV, GTA5', nan, 'WoW', 'CSGO', 'PUGB', nan, nan, nan, nan, nan, 'COD Black Ops 4, COD Black Ops IV', nan, nan, nan, 'Rainbow Six Siege', 'FIFA XIX', nan, nan, nan, nan, nan, nan, 'SCII, SC2, SC II, SC 2, StarCraft 2', nan, nan, 'Worms WMD', 'Skyrim', nan, 'FF XIV, FFXIV, FF 14, FF14', 'NBA 2019, NBA 19', nan, nan, nan, 'COD Black Ops 2, COD Black Ops II', 'GTA San Andreas', 'COD Black Ops', 'Cod Black Ops 3, COD Black Ops III', 'GTA Vice City', 'FIFA XVII', 'COD MW2, COD MWII, COD Modern Warfare 2, COD Modern Warfare II', 'GHIII', nan, nan, 'FIFA XV', nan, 'COD WWII', nan, nan, nan, nan, nan, 'COD MW3, COD MWIII, COD Modern Warfare III, COD Modern Warfare 3', 'FIFA XVIII', 'COD IV Modern Warfare, COD IV MW, COD 4 MW, COD 4 Modern Warfare', 'GTAIV, GTA IV, GTA4, GTA 4', nan, 'COD Ghosts', nan, nan, nan, nan, 'COD Advanced Warfare', 'COD World at War', nan, nan, 'FIFA 13, FIFA XIII', 'FIFA XVI', nan, nan, nan, nan, nan, 'FIFA XIV']

# %% [markdown]
# Adding the column of alternative names

# %%
final['Alt_names'] = alt_names

# %%
final
# Out:
#     twitch_id                               name  Global_Sales     avgViewers  \
# 29    33214.0                           Fortnite          2.37  126368.478125
# 36    21779.0                  League of Legends           NaN  117746.633333
# 32    32982.0                 Grand Theft Auto V         65.62   94222.248958
# 19    29595.0                             Dota 2           NaN   68005.006250
# 73    18122.0                  World of Warcraft          6.35   65221.743750
# 12    32399.0   Counter-Strike: Global Offensive           NaN   38391.845833
# 49   493057.0      PLAYERUNKNOWN'S BATTLEGROUNDS           NaN   34578.984375
# 35   138585.0                        Hearthstone           NaN   25637.785417
# 48   488552.0                          Overwatch          8.18   19756.038542
# 16   494364.0                    Death Stranding           NaN   17626.662139
# 0    511224.0                       Apex Legends           NaN   14402.557292
# 67   502377.0          Total War: Three Kingdoms           NaN   14045.714583
# 7    504462.0          Call of Duty: Black Ops 4         14.30   13694.844792
# 57   499310.0           Splitgate: Arena Warfare           NaN   13481.285417
# 43    27471.0                          Minecraft         33.83   12378.073958
# 15   491487.0                   Dead by Daylight          0.34   10825.623958
# 66   460630.0    Tom Clancy's Rainbow Six: Siege          7.37   10706.221875
# 23   506103.0                            FIFA 19         12.22   10657.876042
# 56   498566.0                              Slots           NaN    9536.554167
# 38     2748.0               Magic: The Gathering           NaN    8161.347917
# 14   494536.0                          Dauntless           NaN    7443.458333
# 64    65654.0           The Elder Scrolls Online          1.02    6065.195833
# 17   497057.0                          Destiny 2          6.65    5977.111458
# 42    13040.0           Mashed: Drive to Survive           NaN    5865.000000
# 58   490422.0                       StarCraft II          4.86    5209.022917
# 18   313558.0        Diablo III: Reaper of Souls           NaN    5044.423958
# 68    79231.0                TrackMania² Stadium           NaN    4361.121212
# 74   493036.0                        Worms W.M.D          0.07    4239.220949
# 65    30028.0        The Elder Scrolls V: Skyrim         20.51    3966.290928
# 72    27546.0                     World of Tanks          0.31    3886.046875
# ..        ...                                ...           ...            ...
# 24   460402.0                            FIFA 15         18.03      93.448649
# 41    18871.0                     Mario Kart Wii         35.98      93.326776
# 11   496712.0                 Call of Duty: WWII         19.82      63.221985
# 63     1736.0                             Tetris         35.84      50.957424
# 59   509508.0                  Super Mario Bros.         40.24      49.296454
# 54   103828.0                        Pokémon X/Y         16.13      36.430556
# 52     3623.0                   Pokémon Red/Blue         31.37      31.339560
# 51     7528.0                Pokémon Gold/Silver         23.10      30.186462
# 9     31551.0     Call of Duty: Modern Warfare 3         30.71      29.654709
# 27   495589.0                            FIFA 18         16.92      28.109560
# 2      1964.0     Call of Duty 4: Modern Warfare         18.33      27.126836
# 30    18707.0                Grand Theft Auto IV         22.53      25.548611
# 37    10209.0  LEGO Star Wars: The Complete Saga         15.33      25.105943
# 8    118200.0               Call of Duty: Ghosts         28.80      20.071879
# 1     24394.0                      Battlefield 3         17.32      19.742012
# 50     2993.0              Pokémon Diamond/Pearl         18.25      17.008197
# 46     7534.0              New Super Mario Bros.         29.85      16.794595
# 47    24238.0          New Super Mario Bros. Wii         28.51      10.728448
# 3    417973.0     Call of Duty: Advanced Warfare         21.78       9.041176
# 10    19006.0         Call of Duty: World at War         15.94       6.363929
# 70    12232.0                         Wii Sports         82.65       4.881188
# 40    28588.0                       Mario Kart 7         15.49       3.415842
# 21    32443.0                     FIFA Soccer 13         15.36       2.666667
# 25   489608.0                            FIFA 16         15.82       1.835821
# 71    19259.0                  Wii Sports Resort         32.90       1.351852
# 20     2530.0                          Duck Hunt         28.31       1.000000
# 39     5993.0                      Mario Kart DS         23.26       0.909091
# 69     8660.0                           Wii Play         28.92       0.833333
# 61    18146.0                   Super Mario Land         18.14       0.000000
# 22   369095.0                            FIFA 14         17.31       0.000000
#
#                                              Platform  \
# 29                                  PS4, XOne, NS, PC
# 36                                            PC, OSX
# 32                           PS3, PS4, X360, PC, XOne
# 19                                     PC, OSX, Linux
# 73                                            PC, OSX
# 12                                  PC, XBL, PSN, OSX
# 49                                                 PC
# 35                                            OSX, PC
# 48                                      PS4, XOne, PC
# 16                                                PS4
# 0                                       XOne, PC, PS4
# 67                                                 PC
# 7                                       PS4, XOne, PC
# 57                                                 PC
# 43  PC, X360, PS4, PS3, XOne, PSV, NS, WiiU, 3DS, ...
# 15                                  PS4, XOne, PC, NS
# 66                                      PS4, XOne, PC
# 23                       PS4, XOne, NS, X360, PS3, PC
# 56                                               2600
# 38                                             PC, DC
# 14                                  PC, PS4, XOne, NS
# 64                                            PC, OSX
# 17                                      PS4, XOne, PC
# 42                                                PS2
# 58                                            PC, OSX
# 18                                                 PC
# 68                                                 PC
# 74                                  PC, PS4, XOne, NS
# 65                                  X360, PS3, PC, NS
# 72                                           PC, X360
# ..                                                ...
# 24            PS4, PS3, X360, XOne, PSV, Wii, 3DS, PC
# 41                                                Wii
# 11                                      PS4, XOne, PC
# 63                                   GB, NES, WS, PSN
# 59                                 NES, VC, WiiU, 3DS
# 54                                                3DS
# 52                                                 GB
# 51                                                 GB
# 9                                  X360, PS3, PC, Wii
# 27                       PS4, XOne, NS, PS3, X360, PC
# 2                         X360, PS3, PC, DS, XBL, PSN
# 30                                 X360, PS3, PC, XBL
# 37                   Wii, DS, X360, PS3, XBL, OSX, PC
# 8                      X360, PS3, PS4, XOne, PC, WiiU
# 1                                       X360, PS3, PC
# 50                                                 DS
# 46                                                 DS
# 47                                                Wii
# 3                            PS4, XOne, X360, PS3, PC
# 10                             X360, PS3, Wii, DS, PC
# 70                                                Wii
# 40                                                3DS
# 21            PS3, X360, Wii, WiiU, PSP, PC, 3DS, PS2
# 25                           PS4, XOne, PS3, X360, PC
# 71                                                Wii
# 20                                                NES
# 39                                           DS, WiiU
# 69                                                Wii
# 61                                            GB, 3DS
# 22  PS3, X360, PS4, XOne, PSV, Wii, PC, 3DS, PSP, ...
#
#                                             Publisher  \
# 29  Gearbox Software  , Gearbox Software  , Warner...
# 36                                THQ  , Riot Games
# 32  Rockstar Games  , Rockstar Games  , Rockstar G...
# 19  Valve Corporation  , Valve Corporation  , Valv...
# 73  Blizzard Entertainment  , Blizzard Entertainme...
# 12  Valve  , Valve Corporation  , Valve Corporatio...
# 49                                 PUBG Corporation
# 35  Blizzard Entertainment  , Blizzard Entertainme...
# 48  Blizzard Entertainment  , Blizzard Entertainme...
# 16                   Sony Interactive Entertainment
# 0   Electronic Arts  , Electronic Arts  , Electron...
# 67                                             Sega
# 7            Activision  , Activision  , Activision
# 57                                          Unknown
# 43  Mojang  , Microsoft Studios  , Sony Computer E...
# 15  505 Games  , 505 Games  , Starbreeze Studios  ...
# 66                    Ubisoft  , Ubisoft  , Ubisoft
# 23  Electronic Arts  , Electronic Arts  , Electron...
# 56                                           Sears
# 38                                    Atari  , Sega
# 14  Phoenix Labs  , Phoenix Labs  , Phoenix Labs  ...
# 64         Bethesda Softworks  , Bethesda Softworks
# 17           Activision  , Activision  , Activision
# 42                                         VU Games
# 58  Blizzard Entertainment  , Blizzard Entertainme...
# 18                           Blizzard Entertainment
# 68                                          Ubisoft
# 74  Team17 Digital Ltd  , Team17 Digital Ltd  , Te...
# 65  Bethesda Softworks  , Bethesda Softworks  , Be...
# 72                   Wargaming.net  , Wargaming.net
# ..                                                ...
# 24  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 41                                         Nintendo
# 11           Activision  , Activision  , Activision
# 63  Nintendo  , Nintendo  , Vanguard  , Electronic...
# 59     Nintendo  , Nintendo  , Nintendo  , Nintendo
# 54                                         Nintendo
# 52                                         Nintendo
# 51                                         Nintendo
# 9   Activision  , Activision  , Activision  , Acti...
# 27  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 2   Activision  , Activision  , Activision  , Acti...
# 30  Rockstar Games  , Rockstar Games  , Rockstar G...
# 37  LucasArts  , LucasArts  , LucasArts  , LucasAr...
# 8   Activision  , Activision  , Activision  , Acti...
# 1   Electronic Arts  , Electronic Arts  , Electron...
# 50                                         Nintendo
# 46                                         Nintendo
# 47                                         Nintendo
# 3   Activision  , Activision  , Activision  , Acti...
# 10  Activision  , Activision  , Activision  , Acti...
# 70                                         Nintendo
# 40                                         Nintendo
# 21  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 25  EA Sports  , EA Sports  , EA Sports  , EA Spor...
# 71                                         Nintendo
# 20                                         Nintendo
# 39                             Nintendo  , Nintendo
# 69                                         Nintendo
# 61                             Nintendo  , Nintendo
# 22  EA Sports  , EA Sports  , EA Sports  , EA Spor...
#
#                                             Developer  Critic_Score  \
# 29  Epic Games  , Epic Games  , Epic Games  , Epic...      8.500000
# 36                         Riot Games  , Riot Games        8.000000
# 32  Rockstar North  , Rockstar North  , Rockstar N...      9.366667
# 19                          Valve  , Valve  , Valve             NaN
# 73                Blizzard Entertainment  , Unknown        9.200000
# 12  Valve Corporation  , Valve Corporation  , Valv...           NaN
# 49                                 PUBG Corporation             NaN
# 35                               Unknown  , Unknown             NaN
# 48  Blizzard Entertainment  , Blizzard Entertainme...      9.000000
# 16                               Kojima Productions             NaN
# 0   Respawn Entertainment  , Respawn Entertainment...           NaN
# 67                                Creative Assembly             NaN
# 7                  Treyarch  , Treyarch  , Treyarch             NaN
# 57                                       1047 Games             NaN
# 43  Mojang AB  , Mojang  , Mojang  , Mojang  , Moj...      8.160000
# 15  Behaviour Interactive Inc.  , Behaviour Intera...           NaN
# 66  Ubisoft Montreal  , Ubisoft Montreal  , Ubisof...           NaN
# 23  EA Sports  , EA Sports  , EA Sports  , EA Spor...      5.900000
# 56                                        Telegames             NaN
# 38                               MicroProse  , Sega             NaN
# 14  Phoenix Labs  , Phoenix Labs  , Phoenix Labs  ...           NaN
# 64  ZeniMax Online Studios  , Bethesda Game Studios             NaN
# 17                       Bungie  , Bungie  , Bungie             NaN
# 42                                       Supersonic             NaN
# 58                Blizzard Entertainment  , Unknown        9.300000
# 18                           Blizzard Entertainment             NaN
# 68                                          Unknown             NaN
# 74  Team17 Digital Ltd  , Team17 Digital Ltd  , Te...           NaN
# 65  Bethesda Game Studios  , Bethesda Game Studios...      9.025000
# 72                  Wargaming.net  , Wargaming West        7.800000
# ..                                                ...           ...
# 24  EA Canada  , EA Canada  , EA Canada  , EA Cana...      7.360000
# 41                                     Nintendo EAD        8.200000
# 11  Sledgehammer Games  , Sledgehammer Games  , Sl...      8.000000
# 63  Bullet Proof Software  , Nintendo  , Vanguard ...      7.500000
# 59  Nintendo EAD  , Nintendo EAD  , Unknown  , Unk...      9.500000
# 54                                       Game Freak        8.900000
# 52                                       Game Freak        9.400000
# 51                                       Game Freak        9.200000
# 9   Infinity Ward  , Infinity Ward  , Infinity War...      7.500000
# 27  EA Vancouver  , EA Vancouver  , EA Vancouver  ...      7.525000
# 2   Infinity Ward  , Infinity Ward  , Infinity War...      8.925000
# 30  Rockstar North  , Rockstar North  , Rockstar T...      9.733333
# 37  Traveller's Tales  , Traveller's Tales  , Trav...      7.933333
# 8   Infinity Ward  , Infinity Ward  , Infinity War...      7.833333
# 1                              Dice  , Dice  , Dice        8.633333
# 50                                       Game Freak        8.600000
# 46                                     Nintendo EAD        9.100000
# 47                                     Nintendo EAD        8.600000
# 3   Sledgehammer Games  , Sledgehammer Games  , Hi...      8.720000
# 10  Treyarch  , Treyarch  , EXAKT Entertainment  ,...      8.200000
# 70                                     Nintendo EAD        7.700000
# 40                     Nintendo EAD / Retro Studios        8.200000
# 21  EA Canada  , EA Canada  , EA Canada  , EA Cana...      7.000000
# 25  EA Canada  , EA Canada  , EA Canada  , EA Cana...      8.700000
# 71                                     Nintendo EAD        8.000000
# 20                                    Nintendo R&D1             NaN
# 39                     Nintendo EAD  , Nintendo EAD        9.100000
# 69                                     Nintendo EAD        5.900000
# 61                   Nintendo R&D1  , Nintendo R&D1        7.500000
# 22  EA Canada  , EA Canada  , EA Canada  , EA Cana...           NaN
#
#     User_Score                         norm_name  \
# 29         NaN                          fortnite
# 36         NaN                 league of legends
# 32        9.00                grand theft auto v
# 19         NaN                           dota ii
# 73        8.00                 world of warcraft
# 12         NaN   counter-strike global offensive
# 49         NaN     playerunknown's battlegrounds
# 35         NaN                       hearthstone
# 48         NaN                         overwatch
# 16         NaN                   death stranding
# 0          NaN                      apex legends
# 67         NaN          total war three kingdoms
# 7          NaN         call of duty black ops iv
# 57         NaN           splitgate arena warfare
# 43         NaN                         minecraft
# 15         NaN                  dead by daylight
# 66         NaN    tom clancy's rainbow six siege
# 23         NaN                          fifa xix
# 56         NaN                             slots
# 38         NaN               magic the gathering
# 14         NaN                         dauntless
# 64         NaN          the elder scrolls online
# 17         NaN                        destiny ii
# 42         NaN           mashed drive to survive
# 58         NaN                      starcraft ii
# 18         NaN        diablo iii reaper of souls
# 68         NaN               trackmania² stadium
# 74         NaN                       worms w.m.d
# 65        9.10        the elder scrolls v skyrim
# 72         NaN                    world of tanks
# ..         ...                               ...
# 24         NaN                           fifa xv
# 41        9.10                    mario kart wii
# 11         NaN                 call of duty wwii
# 63         NaN                            tetris
# 59        8.20                 super mario bros.
# 54        9.70                       pokémon x/y
# 52         NaN                  pokémon red/blue
# 51         NaN               pokémon gold/silver
# 9          NaN   call of duty modern warfare iii
# 27        9.10                        fifa xviii
# 2         9.30     call of duty 4 modern warfare
# 30        9.00               grand theft auto iv
# 37         NaN  lego star wars the complete saga
# 8          NaN               call of duty ghosts
# 1          NaN                   battlefield iii
# 50         NaN             pokémon diamond/pearl
# 46        8.10             new super mario bros.
# 47        9.20         new super mario bros. wii
# 3          NaN     call of duty advanced warfare
# 10        8.35         call of duty world at war
# 70         NaN                        wii sports
# 40         NaN                    mario kart vii
# 21         NaN                  fifa soccer xiii
# 25         NaN                          fifa xvi
# 71        8.80                 wii sports resort
# 20         NaN                         duck hunt
# 39        9.40                     mario kart ds
# 69        4.50                          wii play
# 61         NaN                  super mario land
# 22         NaN                          fifa xiv
#
#                           unary_name  \
# 29                          fortnite
# 36                 league of legends
# 32                grand theft auto v
# 19                           dota ii
# 73                 world of warcraft
# 12   counter-strike global offensive
# 49     playerunknown's battlegrounds
# 35                       hearthstone
# 48                         overwatch
# 16                   death stranding
# 0                       apex legends
# 67          total war three kingdoms
# 7        call of duty black ops iiii
# 57           splitgate arena warfare
# 43                         minecraft
# 15                  dead by daylight
# 66    tom clancy's rainbow six siege
# 23          fifa iiiiiiiiiiiiiiiiiii
# 56                             slots
# 38               magic the gathering
# 14                         dauntless
# 64          the elder scrolls online
# 17                        destiny ii
# 42           mashed drive to survive
# 58                      starcraft ii
# 18        diablo iii reaper of souls
# 68               trackmania² stadium
# 74                       worms w.m.d
# 65        the elder scrolls v skyrim
# 72                    world of tanks
# ..                               ...
# 24              fifa iiiiiiiiiiiiiii
# 41                    mario kart wii
# 11                 call of duty wwii
# 63                            tetris
# 59                 super mario bros.
# 54                       pokémon x/y
# 52                  pokémon red/blue
# 51               pokémon gold/silver
# 9    call of duty modern warfare iii
# 27           fifa iiiiiiiiiiiiiiiiii
# 2      call of duty 4 modern warfare
# 30               grand theft auto iv
# 37  lego star wars the complete saga
# 8                call of duty ghosts
# 1                    battlefield iii
# 50             pokémon diamond/pearl
# 46             new super mario bros.
# 47         new super mario bros. wii
# 3      call of duty advanced warfare
# 10         call of duty world at war
# 70                        wii sports
# 40                mario kart iiiiiii
# 21         fifa soccer iiiiiiiiiiiii
# 25             fifa iiiiiiiiiiiiiiii
# 71                 wii sports resort
# 20                         duck hunt
# 39                     mario kart ds
# 69                          wii play
# 61                  super mario land
# 22               fifa iiiiiiiiiiiiii
#
#                                             Alt_names
# 29                                                NaN
# 36                                                LoL
# 32                                         GTAV, GTA5
# 19                                                NaN
# 73                                                WoW
# 12                                               CSGO
# 49                                               PUGB
# 35                                                NaN
# 48                                                NaN
# 16                                                NaN
# 0                                                 NaN
# 67                                                NaN
# 7                   COD Black Ops 4, COD Black Ops IV
# 57                                                NaN
# 43                                                NaN
# 15                                                NaN
# 66                                  Rainbow Six Siege
# 23                                           FIFA XIX
# 56                                                NaN
# 38                                                NaN
# 14                                                NaN
# 64                                                NaN
# 17                                                NaN
# 42                                                NaN
# 58                SCII, SC2, SC II, SC 2, StarCraft 2
# 18                                                NaN
# 68                                                NaN
# 74                                          Worms WMD
# 65                                             Skyrim
# 72                                                NaN
# ..                                                ...
# 24                                            FIFA XV
# 41                                                NaN
# 11                                           COD WWII
# 63                                                NaN
# 59                                                NaN
# 54                                                NaN
# 52                                                NaN
# 51                                                NaN
# 9   COD MW3, COD MWIII, COD Modern Warfare III, CO...
# 27                                         FIFA XVIII
# 2   COD IV Modern Warfare, COD IV MW, COD 4 MW, CO...
# 30                         GTAIV, GTA IV, GTA4, GTA 4
# 37                                                NaN
# 8                                          COD Ghosts
# 1                                                 NaN
# 50                                                NaN
# 46                                                NaN
# 47                                                NaN
# 3                                COD Advanced Warfare
# 10                                   COD World at War
# 70                                                NaN
# 40                                                NaN
# 21                                 FIFA 13, FIFA XIII
# 25                                           FIFA XVI
# 71                                                NaN
# 20                                                NaN
# 39                                                NaN
# 69                                                NaN
# 61                                                NaN
# 22                                           FIFA XIV
#
# [75 rows x 12 columns]

# %%
# final.to_csv('../dataset/games_list.csv')
